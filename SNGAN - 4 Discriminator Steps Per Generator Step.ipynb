# %% [markdown]
# <a href="https://colab.research.google.com/github/Tien-Cheng/dele-generative-adversarial-networks/blob/main/SNGAN%20-%204%20Discriminator%20Steps%20Per%20Generator%20Step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Background
#
# ## Problem Statement
#
# My objective for this project is to attempt to create a GAN model that is able to generate realistic images based on information that is provided to it.
#
# Such a task generally falls under two categories:
#
# 1. Conditional Image Generation: Given a class (e.g. a car), generate an image of that class
# 2. Controllable Image Generation: Given some description of features of the image (e.g. The car should be red in color), generate an image with those features
#
# In this project, I hope to tackle the first category (Conditional Image Generation), with the view of eventually tackling the second category if time and resources permit.
#
# So, what would I consider to be a success? Well, I would preferably hope to be able to reliably generate images conditionally that look real enough, based on
#
# - Eye Power 🕵️
# - Metrics like FID (described later in the report)
#
# By real enough, I mean that I hope to get results that are close enough to some of the top GAN models out there, with minimal artifacts.

# %% [markdown]
# # Google Colab Setup
#
# Due to the heavy computational requirements for training a GAN, Google Colab is used as a compute platform. The dataset and utilty functions have been stored on a GitHub repository, and so we need to clone the Git repo. In addition, some additional libraries have to be installed.

# %%
! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp: # Repository Deploy Key
    fp.write("""
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
""")
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:Tien-Cheng/dele-generative-adversarial-networks.git
# %cd /content/dele-generative-adversarial-networks
# Out:
# # github.com:22 SSH-2.0-babeld-00610741
# Cloning into 'dele-generative-adversarial-networks'...
# Warning: Permanently added the RSA host key for IP address '140.82.121.3' to the list of known hosts.
# remote: Enumerating objects: 535, done.
# remote: Counting objects: 100% (535/535), done.
# remote: Compressing objects: 100% (358/358), done.
# remote: Total 535 (delta 332), reused 360 (delta 165), pack-reused 0
# Receiving objects: 100% (535/535), 518.73 KiB | 1.96 MiB/s, done.
# Resolving deltas: 100% (332/332), done.
# /content/dele-generative-adversarial-networks

# %%
# %%capture
# %pip install -U torch-fidelity wandb torch-summary pytorch-lightning

# %% [markdown]
# # Setup

# %% [markdown]
# ### Imports

# %%
import gc
from collections import OrderedDict
from typing import *

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch_fidelity
from pytorch_lightning import LightningModule, Trainer, seed_everything
from pytorch_lightning.callbacks import ModelCheckpoint, ModelSummary
from pytorch_lightning.loggers import WandbLogger
from torch import nn
from torch.nn import functional as F
from torch.nn.utils import spectral_norm
from torch.optim import Adam
from torch.optim.lr_scheduler import *

from torchvision import transforms as T

import wandb
from data.dataset import CIFAR10DataModule
from utils.DiffAugment_pytorch import (
    DiffAugment,
)  # Make use of the official implementation of DiffAugment

from utils.layers import (
    NormalizeInverse,
    ResidualBlockDiscriminator,
    ResidualBlockDiscriminatorHead,
    ResidualBlockGenerator,
)
from utils.loss import R1, HingeGANLossGenerator, HingeGANLossDiscriminator
from utils.visualize import visualize

# %% [markdown]
# ### Basic Hyperparameters
#
# The most important hyperparameter for the data loader is the batch size, which defines how many real images (and thus how many generated fake images) will be fed into the discriminator during training of either the generator or discriminator.
#
# It was found in Brock, Donahue, and Simonyan, “Large Scale GAN Training for High Fidelity Natural Image Synthesis.” that larger batch sizes could improve the overall quality of the GAN output, but would lead to more unstable training.
#
# > We begin by increasing the batch size for the baseline model, and immediately find tremendous benefits in doing so. Rows 1-4 of Table 1 show that simply increasing the batch size by a factor of 8 improves the state-of-the-art IS by 46%. We conjecture that this is a result of each batch covering more modes, providing better gradients for both networks. One notable side effect of this scaling is that our models reach better final performance in fewer iterations, but become unstable and undergo complete training collapse.
#
# As a result of their findings, I will try and use as large a batch size as possible, within the limitations of the GPU memory. To increase my batch size further, I can make use of gradient accumulation, which is helpfully implemented in PyTorch Lightning's Trainers, to accumulate the gradients from backprogagation over multiple batches, resulting in an increased effective batch size

# %%
# @title Basic Hyperparameters { run: "auto" }
DATA_DIR = "./data"  # @param {type:"string"}
BATCH_SIZE = 256  # @param {type:"integer"}
NUM_WORKERS = 2  # @param {type:"integer"}

# %% [markdown]
# # Data
#
# ## CIFAR-10
#
# CIFAR-10 is a labelled subset of the 80 million tiny images dataset. It consists of 60000 32x32 color images in 10 classes.
#
# - They are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
#
# There are 6000 images per class. CIFAR-10 splits data into 50000 training images, and 10000 test images. It is a common benchmark dataset, used to evaluate computer vision models. It is also commonly used as a benchmark for GAN training, as GAN training typically takes a long time, and so a smaller dataset like CIFAR with a lower resolution is easier to train, allowing GAN models to be more easily evaluated.

# %% [markdown]
# ## Data Ingestion and Preprocessing
#
# To make the set up of the dataset easier and consistent for multiple experiments, a PyTorch Lightning (PL) Data Module is defined as follows. A `LightningDataModule` is a custom class in PL, which defines a structure for defining a dataset, such that it can be easily loaded by a PL Trainer.
#
# ### Preprocessing
#
# A common preprocessing step when training a GAN is to normalize the dataset images such that they are within the range of -1 to 1. By performing feature scaling, I help the model to converge faster by gradient descent.
#
# ### Augmentation
#
# Data augmentation is common applied in deep learning as a technique for preventing overfitting of a model by randomly applying transformations to images to generate variations of it. In this case, we want to reduce overfitting in the discriminator, as an overfitting discriminator, as found in Karras et al., “Training Generative Adversarial Networks with Limited Data.” can lead to reduce quality of the generated images.
#
# > The distributions overlap initially but keep drifting apart as the discriminator becomes more and more confident, and the point where FID starts to deteriorate is consistent with the loss of sufficient overlap between distributions. This is a strong indication of overfitting, evidenced further by the drop in accuracy measured for a separate validation set. - Section 2, Overfitting in GANs
#
# When performing data augmentation in GAN training, there are some things to take note of:
#
# - Some augmentations are "leaky", meaning that the generator may learn to generate augmented images as it is unable to separate the augmentation from the data distribution.
#
# As a result, I will initially not apply any data augmentation, but will investigate safe data augmentation techniques to apply later on.

# %%
preprocessing = [T.ToTensor(), T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]

# %%
dm = CIFAR10DataModule(
    data_dir=DATA_DIR,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    transforms=preprocessing,
)

# %% [markdown]
# # Building an SNGAN with Projection Discriminator

# %% [markdown]
# ## Generator

# %%
class ResNetGenerator(nn.Module):
    def __init__(
        self,
        latent_dim: int = 128,
        num_filters: int = 256,
        num_classes: int = 10,
        activation: callable = F.relu,
        use_spectral_norm: bool = True,
    ):
        super().__init__()
        self.latent_dim = latent_dim
        self.num_filters = num_filters
        self.num_classes = num_classes
        self.use_spectral_norm = use_spectral_norm
        self.latent = nn.Linear(latent_dim, num_filters * 4 * 4)
        self.blocks = nn.ModuleList(
            [
                ResidualBlockGenerator(
                    in_ch=num_filters,
                    out_ch=num_filters,
                    activation=activation,
                    upsample=True,
                    num_classes=num_classes,
                    use_spectral_norm=use_spectral_norm,
                )
                for _ in range(3)  # Input: 4x4 | -> 8x8 -> 16x16 -> 32x32
            ]
        )
        self.output = [
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Conv2d(num_filters, 3, kernel_size=3, padding=1, stride=1),
            nn.Tanh(),
        ]
        if use_spectral_norm:
            self.output[2] = spectral_norm(self.output[2])

        self.output = nn.Sequential(*self.output)

    def forward(self, x, y):
        h = self.latent(x)
        h = h.view(h.shape[0], self.num_filters, 4, 4)
        for block in self.blocks:
            h = block(h, y)
        output = self.output(h)
        if not self.training:
            output = 255 * (output.clamp(-1, 1) * 0.5 + 0.5)
            output = output.to(torch.uint8)
        return output

# %% [markdown]
# ## Discriminator

# %%
class ResNetDiscriminator(nn.Module):
    def __init__(
        self,
        num_filters: int = 128,
        num_classes: int = 10,
        activation: callable = F.relu,
    ):
        """Implementation inspired by Projection Discriminator: https://github.com/pfnet-research/sngan_projection/blob/master/dis_models/snresnet_32.py

        :param num_filters: [description], defaults to 128
        :type num_filters: int, optional
        :param num_classes: [description], defaults to 10
        :type num_classes: int, optional
        :param activation: [description], defaults to F.relu
        :type activation: callable, optional
        """
        super().__init__()
        self.num_filters = num_filters
        self.num_classes = num_classes
        self.activation = activation
        self.blocks = nn.Sequential(
            ResidualBlockDiscriminatorHead(3, num_filters, activation=activation),
            ResidualBlockDiscriminator(
                num_filters, num_filters, activation=activation, downsample=True
            ),
            ResidualBlockDiscriminator(
                num_filters, num_filters, activation=activation, downsample=False
            ),
            ResidualBlockDiscriminator(
                num_filters, num_filters, activation=activation, downsample=False
            ),
        )
        self.classifier = spectral_norm(nn.Linear(num_filters, 1, bias=False))
        self.embed = spectral_norm(nn.Embedding(num_classes, num_filters))

    def forward(self, x, y):
        h = self.blocks(x)
        h = self.activation(h)
        h = h.mean([2, 3])  # Global Avg Pooling
        out = self.classifier(h)
        out = out + torch.sum(self.embed(y) * h, axis=1, keepdims=True)
        return out

# %% [markdown]
# ## Conditional DCGAN

# %%
class SNGAN(LightningModule):
    def __init__(
        self,
        latent_dim: int = 128,
        num_classes: int = 10,
        g_lr: float = 0.0002,
        d_lr: float = 0.0002,
        adam_betas: Tuple[float, float] = (0.0, 0.999),
        d_steps: int = 1,
        r1_gamma: Optional[float] = 0.2,
        w_init_policy: str = "ortho",
        **kwargs,
    ):
        super().__init__()

        self.latent_dim = latent_dim
        self.num_classes = num_classes
        self.g_lr = g_lr
        self.d_lr = d_lr
        self.betas = adam_betas
        self.d_steps = d_steps  # Number of Discriminator steps per Generator Step
        self.r1_gamma = r1_gamma
        self.w_init_policy = w_init_policy
        self.save_hyperparameters()

        self.G = ResNetGenerator(
            latent_dim=latent_dim,
            num_classes=num_classes,
        )

        self.D = ResNetDiscriminator(num_classes=num_classes)

        if w_init_policy == "normal":
            init_func = self._normal_weights_init
        elif w_init_policy == "ortho":
            init_func = self._ortho_weights_init
        else:
            raise ValueError("Unknown Weight Init Policy")
        self.G.apply(init_func)
        self.D.apply(init_func)

        self.generator_loss = HingeGANLossGenerator()
        self.discriminator_loss = HingeGANLossDiscriminator()
        self.regularization_loss = R1(r1_gamma)

        self.viz_z = torch.randn(64, self.latent_dim)
        self.viz_labels = torch.LongTensor(torch.randint(0, self.num_classes, (64,)))

        self.unnormalize = NormalizeInverse((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

    @staticmethod
    def _normal_weights_init(m):
        if (
            isinstance(m, nn.Linear)
            or isinstance(m, nn.Conv2d)
            or isinstance(m, nn.Embedding)
        ):
            torch.nn.init.normal_(m.weight, 0.0, 0.02)
        elif isinstance(m, nn.BatchNorm2d):
            torch.nn.init.normal_(m.weight, 1.0, 0.02)
            torch.nn.init.zeros_(m.bias)

    @staticmethod
    def _ortho_weights_init(m):
        if (
            isinstance(m, nn.Linear)
            or isinstance(m, nn.Conv2d)
            or isinstance(m, nn.Embedding)
        ):
            torch.nn.init.orthogonal_(m.weight)

    def forward(self, z, labels):
        return self.G(z, labels)

    # Alternating schedule for optimizer steps (i.e.: GANs)
    def optimizer_step(
        self,
        epoch,
        batch_idx,
        optimizer,
        optimizer_idx,
        optimizer_closure,
        on_tpu,
        using_native_amp,
        using_lbfgs,
    ):
        # update discriminator opt every step
        if optimizer_idx == 1:
            optimizer.step(closure=optimizer_closure)

        # update generator opt every 4 steps
        if optimizer_idx == 0:
            if (batch_idx + 1) % self.d_steps == 0:
                optimizer.step(closure=optimizer_closure)
            else:
                # call the closure by itself to run `training_step` + `backward` without an optimizer step
                optimizer_closure()

    def training_step(self, batch, batch_idx, optimizer_idx):
        imgs, labels = batch  # Get real images and corresponding labels

        # Generate Noise Vector z
        z = torch.randn(imgs.shape[0], self.latent_dim)
        z = z.type_as(imgs)  # Ensure z runs on the same device as the images
        self.fake_labels = torch.LongTensor(
            torch.randint(0, self.num_classes, (imgs.shape[0],))
        ).to(self.device)
        # Train Generator
        if optimizer_idx == 0:
            # Generate Images
            self.fakes = self.forward(z, self.fake_labels)

            # Classify Generated Images with Discriminator
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))

            # We want to penalize the Generator if the Discriminator predicts it as fake
            # Hence, set the target as a 1's vector
            g_loss = self.generator_loss(fake_preds)

            self.log(
                "train_gen_loss",
                g_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )  # Log Generator Loss
            tqdm_dict = {
                "g_loss": g_loss,
            }
            output = OrderedDict(
                {"loss": g_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

        # Train Discriminator
        if optimizer_idx == 1:
            # Train on Real Data
            imgs.requires_grad = True
            real_preds = torch.squeeze(self.D(imgs, labels))
            # Train on Generated Images
            self.fakes = self.forward(z, self.fake_labels)
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))
            d_loss = self.discriminator_loss(real_preds, fake_preds)
            if self.r1_gamma is not None:
                d_loss = d_loss + self.regularization_loss(real_preds, imgs)
            self.log(
                "train_discriminator_loss",
                d_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )
            tqdm_dict = {
                "d_loss": d_loss,
            }
            output = OrderedDict(
                {"loss": d_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

    def training_epoch_end(self, outputs):
        # Log Sampled Images
        sample_imgs = self.unnormalize(self.fakes[:64].detach()).cpu()
        sample_labels = self.fake_labels[:64].detach().cpu()
        num_rows = int(np.floor(np.sqrt(len(sample_imgs))))
        fig = visualize(sample_imgs, sample_labels, grid_shape=(num_rows, num_rows))
        self.logger.log_image(key="generated_images", images=[fig])
        plt.close(fig)
        del sample_imgs
        del sample_labels
        del fig
        gc.collect()

    def validation_step(self, batch, batch_idx):
        pass

    def validation_epoch_end(self, outputs):
        sample_imgs = (
            self.forward(self.viz_z.to(self.device), self.viz_labels.to(self.device))
            .cpu()
            .detach()
        )
        fig = visualize(sample_imgs, self.viz_labels.cpu().detach(), grid_shape=(8, 8))
        metrics = torch_fidelity.calculate_metrics(
            input1=torch_fidelity.GenerativeModelModuleWrapper(
                self.G, self.latent_dim, "normal", self.num_classes
            ),
            input1_model_num_samples=10000,
            input2="cifar10-val",
            isc=True,
            fid=True,
            kid=True,
        )
        self.logger.log_image(key="Validation Images", images=[fig])
        plt.close(fig)
        del sample_imgs
        del fig
        gc.collect()
        self.log("FID", metrics["frechet_inception_distance"], prog_bar=True)
        self.log("IS", metrics["inception_score_mean"], prog_bar=True)
        self.log("KID", metrics["kernel_inception_distance_mean"], prog_bar=True)

    def configure_optimizers(self):
        """Define the optimizers and schedulers for PyTorch Lightning

        :return: A tuple of two lists - a list of optimizers and a list of learning rate schedulers
        :rtype: Tuple[List, List]
        """
        opt_G = Adam(
            self.G.parameters(), lr=self.g_lr, betas=self.betas
        )  # optimizer_idx = 0
        opt_D = Adam(
            self.D.parameters(), lr=self.d_lr, betas=self.betas
        )  # optimizer_idx = 1
        return [opt_G, opt_D], []

# %% [markdown]
# ## Trainer

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
seed_everything(42)
wandb_logger = WandbLogger(
    project="DELE_CA2_GAN",
    log_model="all",
    tags=[
        "R1 Regularization",
        "SNGAN",
        "Hinge Loss",
        "Spectral Normalization",
        "cBN",
    ],
)
model = SNGAN(g_lr=0.0002, d_lr=0.0002, r1_gamma=0.2, d_steps=4)
trainer = Trainer(
    check_val_every_n_epoch=5,
    logger=wandb_logger,
    max_epochs=1000,
    callbacks=[
        ModelSummary(3),
    ],
    gpus=1,
)
# Out:
# Global seed set to 42
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
trainer.fit(model, dm)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: Currently logged in as: tiencheng (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/19kepjip" target="_blank">vibrant-brook-92</a></strong> to <a href="https://wandb.ai/tiencheng/DELE_CA2_GAN" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#    | Name                | Type                           | Params
# ------------------------------------------------------------------------
# 0  | G                   | ResNetGenerator                | 5.5 M
# 1  | G.latent            | Linear                         | 528 K
# 2  | G.blocks            | ModuleList                     | 4.9 M
# 3  | G.blocks.0          | ResidualBlockGenerator         | 1.6 M
# 4  | G.blocks.1          | ResidualBlockGenerator         | 1.6 M
# 5  | G.blocks.2          | ResidualBlockGenerator         | 1.6 M
# 6  | G.output            | Sequential                     | 7.4 K
# 7  | G.output.0          | BatchNorm2d                    | 512
# 8  | G.output.1          | ReLU                           | 0
# 9  | G.output.2          | Conv2d                         | 6.9 K
# 10 | G.output.3          | Tanh                           | 0
# 11 | D                   | ResNetDiscriminator            | 1.1 M
# 12 | D.blocks            | Sequential                     | 1.1 M
# 13 | D.blocks.0          | ResidualBlockDiscriminatorHead | 151 K
# 14 | D.blocks.1          | ResidualBlockDiscriminator     | 311 K
# 15 | D.blocks.2          | ResidualBlockDiscriminator     | 311 K
# 16 | D.blocks.3          | ResidualBlockDiscriminator     | 311 K
# 17 | D.classifier        | Linear                         | 128
# 18 | D.embed             | Embedding                      | 1.3 K
# 19 | generator_loss      | HingeGANLossGenerator          | 0
# 20 | discriminator_loss  | HingeGANLossDiscriminator      | 0
# 21 | regularization_loss | R1                             | 0
# 22 | unnormalize         | NormalizeInverse               | 0
# ------------------------------------------------------------------------
# 6.5 M     Trainable params
# 0         Non-trainable params
# 6.5 M     Total params
# 26.178    Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
#   0%|          | 0.00/91.2M [00:00<?, ?B/s]
# Extracting features from input1
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
# Processing samples:   1%|          | 64/10000 [00:00<00:15, 623.66samples/s]
# Processing samples:   1%|▏         | 128/10000 [00:00<00:15, 628.51samples/s]
# Processing samples:   3%|▎         | 256/10000 [00:00<00:14, 678.24samples/s]
# Processing samples:   4%|▍         | 384/10000 [00:00<00:13, 698.56samples/s]
# Processing samples:   5%|▌         | 512/10000 [00:00<00:13, 708.90samples/s]
# Processing samples:   6%|▋         | 640/10000 [00:00<00:13, 714.95samples/s]
# Processing samples:   8%|▊         | 768/10000 [00:01<00:12, 717.98samples/s]
# Processing samples:   9%|▉         | 896/10000 [00:01<00:12, 720.19samples/s]
# Processing samples:  10%|█         | 1024/10000 [00:01<00:12, 721.02samples/s]
# Processing samples:  12%|█▏        | 1152/10000 [00:01<00:12, 722.85samples/s]
# Processing samples:  13%|█▎        | 1280/10000 [00:01<00:12, 726.55samples/s]
# Processing samples:  14%|█▍        | 1408/10000 [00:01<00:11, 729.95samples/s]
# Processing samples:  15%|█▌        | 1536/10000 [00:02<00:11, 728.51samples/s]
# Processing samples:  17%|█▋        | 1664/10000 [00:02<00:11, 726.38samples/s]
# Processing samples:  18%|█▊        | 1792/10000 [00:02<00:11, 725.48samples/s]
# Processing samples:  19%|█▉        | 1920/10000 [00:02<00:11, 726.87samples/s]
# Processing samples:  20%|██        | 2048/10000 [00:02<00:10, 728.01samples/s]
# Processing samples:  22%|██▏       | 2176/10000 [00:03<00:10, 728.44samples/s]
# Processing samples:  23%|██▎       | 2304/10000 [00:03<00:10, 726.26samples/s]
# Processing samples:  24%|██▍       | 2432/10000 [00:03<00:10, 727.92samples/s]
# Processing samples:  26%|██▌       | 2560/10000 [00:03<00:10, 728.53samples/s]
# Processing samples:  27%|██▋       | 2688/10000 [00:03<00:10, 729.48samples/s]
# Processing samples:  28%|██▊       | 2816/10000 [00:03<00:09, 730.05samples/s]
# Processing samples:  29%|██▉       | 2944/10000 [00:04<00:09, 730.97samples/s]
# Processing samples:  31%|███       | 3072/10000 [00:04<00:09, 731.18samples/s]
# Processing samples:  32%|███▏      | 3200/10000 [00:04<00:09, 731.03samples/s]
# Processing samples:  33%|███▎      | 3328/10000 [00:04<00:09, 731.55samples/s]
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:08, 733.42samples/s]
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:08, 731.81samples/s]
# Processing samples:  37%|███▋      | 3712/10000 [00:05<00:08, 731.86samples/s]
# Processing samples:  38%|███▊      | 3840/10000 [00:05<00:08, 731.05samples/s]
# Processing samples:  40%|███▉      | 3968/10000 [00:05<00:08, 731.49samples/s]
# Processing samples:  41%|████      | 4096/10000 [00:05<00:08, 731.56samples/s]
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:07, 731.67samples/s]
# Processing samples:  44%|████▎     | 4352/10000 [00:06<00:07, 731.39samples/s]
# Processing samples:  45%|████▍     | 4480/10000 [00:06<00:07, 732.34samples/s]
# Processing samples:  46%|████▌     | 4608/10000 [00:06<00:07, 732.98samples/s]
# Processing samples:  47%|████▋     | 4736/10000 [00:06<00:07, 732.17samples/s]
# Processing samples:  49%|████▊     | 4864/10000 [00:06<00:07, 732.57samples/s]
# Processing samples:  50%|████▉     | 4992/10000 [00:06<00:06, 733.21samples/s]
# Processing samples:  51%|█████     | 5120/10000 [00:07<00:06, 730.77samples/s]
# Processing samples:  52%|█████▏    | 5248/10000 [00:07<00:06, 732.20samples/s]
# Processing samples:  54%|█████▍    | 5376/10000 [00:07<00:06, 730.38samples/s]
# Processing samples:  55%|█████▌    | 5504/10000 [00:07<00:06, 730.60samples/s]
# Processing samples:  56%|█████▋    | 5632/10000 [00:07<00:05, 730.83samples/s]
# Processing samples:  58%|█████▊    | 5760/10000 [00:07<00:05, 730.91samples/s]
# Processing samples:  59%|█████▉    | 5888/10000 [00:08<00:05, 730.73samples/s]
# Processing samples:  60%|██████    | 6016/10000 [00:08<00:05, 731.93samples/s]
# Processing samples:  61%|██████▏   | 6144/10000 [00:08<00:05, 732.16samples/s]
# Processing samples:  63%|██████▎   | 6272/10000 [00:08<00:05, 733.40samples/s]
# Processing samples:  64%|██████▍   | 6400/10000 [00:08<00:04, 733.11samples/s]
# Processing samples:  65%|██████▌   | 6528/10000 [00:08<00:04, 732.14samples/s]
# Processing samples:  67%|██████▋   | 6656/10000 [00:09<00:04, 732.17samples/s]
# Processing samples:  68%|██████▊   | 6784/10000 [00:09<00:04, 732.46samples/s]
# Processing samples:  69%|██████▉   | 6912/10000 [00:09<00:04, 732.18samples/s]
# Processing samples:  70%|███████   | 7040/10000 [00:09<00:04, 731.59samples/s]
# Processing samples:  72%|███████▏  | 7168/10000 [00:09<00:03, 731.25samples/s]
# Processing samples:  73%|███████▎  | 7296/10000 [00:10<00:03, 730.96samples/s]
# Processing samples:  74%|███████▍  | 7424/10000 [00:10<00:03, 729.28samples/s]
# Processing samples:  76%|███████▌  | 7552/10000 [00:10<00:03, 728.38samples/s]
# Processing samples:  77%|███████▋  | 7680/10000 [00:10<00:03, 727.50samples/s]
# Processing samples:  78%|███████▊  | 7808/10000 [00:10<00:03, 727.89samples/s]
# Processing samples:  79%|███████▉  | 7936/10000 [00:10<00:02, 727.52samples/s]
# Processing samples:  81%|████████  | 8064/10000 [00:11<00:02, 728.00samples/s]
# Processing samples:  82%|████████▏ | 8192/10000 [00:11<00:02, 729.52samples/s]
# Processing samples:  83%|████████▎ | 8320/10000 [00:11<00:02, 729.94samples/s]
# Processing samples:  84%|████████▍ | 8448/10000 [00:11<00:02, 729.93samples/s]
# Processing samples:  86%|████████▌ | 8576/10000 [00:11<00:01, 728.27samples/s]
# Processing samples:  87%|████████▋ | 8704/10000 [00:11<00:01, 728.85samples/s]
# Processing samples:  88%|████████▊ | 8832/10000 [00:12<00:01, 727.06samples/s]
# Processing samples:  90%|████████▉ | 8960/10000 [00:12<00:01, 725.35samples/s]
# Processing samples:  91%|█████████ | 9088/10000 [00:12<00:01, 725.84samples/s]
# Processing samples:  92%|█████████▏| 9216/10000 [00:12<00:01, 726.98samples/s]
# Processing samples:  93%|█████████▎| 9344/10000 [00:12<00:00, 726.95samples/s]
# Processing samples:  95%|█████████▍| 9472/10000 [00:13<00:00, 728.36samples/s]
# Processing samples:  96%|█████████▌| 9600/10000 [00:13<00:00, 728.68samples/s]
# Processing samples:  97%|█████████▋| 9728/10000 [00:13<00:00, 729.73samples/s]
# Processing samples:  99%|█████████▊| 9856/10000 [00:13<00:00, 730.39samples/s]
# Processing samples: 100%|█████████▉| 9984/10000 [00:13<00:00, 729.25samples/s]
#                                                                               Processing samples
# Extracting features from input2
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.cache/torch/fidelity_datasets/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /root/.cache/torch/fidelity_datasets/cifar-10-python.tar.gz to /root/.cache/torch/fidelity_datasets
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
# Processing samples:   1%|          | 64/10000 [00:00<00:38, 257.29samples/s]
# Processing samples:   2%|▏         | 192/10000 [00:00<00:19, 509.53samples/s]
# Processing samples:   3%|▎         | 320/10000 [00:00<00:15, 632.74samples/s]
# Processing samples:   4%|▍         | 448/10000 [00:00<00:13, 706.67samples/s]
# Processing samples:   6%|▌         | 576/10000 [00:00<00:12, 752.10samples/s]
# Processing samples:   7%|▋         | 704/10000 [00:01<00:11, 781.17samples/s]
# Processing samples:   8%|▊         | 832/10000 [00:01<00:11, 802.21samples/s]
# Processing samples:  10%|▉         | 960/10000 [00:01<00:11, 814.02samples/s]
# Processing samples:  11%|█         | 1088/10000 [00:01<00:10, 824.15samples/s]
# Processing samples:  12%|█▏        | 1216/10000 [00:01<00:10, 832.10samples/s]
# Processing samples:  13%|█▎        | 1344/10000 [00:01<00:10, 836.71samples/s]
# Processing samples:  15%|█▍        | 1472/10000 [00:01<00:10, 840.69samples/s]
# Processing samples:  16%|█▌        | 1600/10000 [00:02<00:09, 843.12samples/s]
# Processing samples:  17%|█▋        | 1728/10000 [00:02<00:09, 843.97samples/s]
# Processing samples:  19%|█▊        | 1856/10000 [00:02<00:09, 844.51samples/s]
# Processing samples:  20%|█▉        | 1984/10000 [00:02<00:09, 844.98samples/s]
# Processing samples:  21%|██        | 2112/10000 [00:02<00:09, 845.27samples/s]
# Processing samples:  22%|██▏       | 2240/10000 [00:02<00:09, 846.11samples/s]
# Processing samples:  24%|██▎       | 2368/10000 [00:02<00:09, 846.47samples/s]
# Processing samples:  25%|██▍       | 2496/10000 [00:03<00:08, 844.71samples/s]
# Processing samples:  26%|██▌       | 2624/10000 [00:03<00:08, 844.31samples/s]
# Processing samples:  28%|██▊       | 2752/10000 [00:03<00:08, 843.60samples/s]
# Processing samples:  29%|██▉       | 2880/10000 [00:03<00:08, 842.57samples/s]
# Processing samples:  30%|███       | 3008/10000 [00:03<00:08, 842.26samples/s]
# Processing samples:  31%|███▏      | 3136/10000 [00:03<00:08, 841.90samples/s]
# Processing samples:  33%|███▎      | 3264/10000 [00:04<00:08, 841.40samples/s]
# Processing samples:  34%|███▍      | 3392/10000 [00:04<00:07, 841.05samples/s]
# Processing samples:  35%|███▌      | 3520/10000 [00:04<00:07, 840.17samples/s]
# Processing samples:  36%|███▋      | 3648/10000 [00:04<00:07, 840.23samples/s]
# Processing samples:  38%|███▊      | 3776/10000 [00:04<00:07, 843.43samples/s]
# Processing samples:  39%|███▉      | 3904/10000 [00:04<00:07, 844.30samples/s]
# Processing samples:  40%|████      | 4032/10000 [00:04<00:07, 844.14samples/s]
# Processing samples:  42%|████▏     | 4160/10000 [00:05<00:06, 842.66samples/s]
# Processing samples:  43%|████▎     | 4288/10000 [00:05<00:06, 843.43samples/s]
# Processing samples:  44%|████▍     | 4416/10000 [00:05<00:06, 843.75samples/s]
# Processing samples:  45%|████▌     | 4544/10000 [00:05<00:06, 845.00samples/s]
# Processing samples:  47%|████▋     | 4672/10000 [00:05<00:06, 845.60samples/s]
# Processing samples:  48%|████▊     | 4800/10000 [00:05<00:06, 845.47samples/s]
# Processing samples:  49%|████▉     | 4928/10000 [00:06<00:05, 846.05samples/s]
# Processing samples:  51%|█████     | 5056/10000 [00:06<00:05, 845.89samples/s]
# Processing samples:  52%|█████▏    | 5184/10000 [00:06<00:05, 845.73samples/s]
# Processing samples:  53%|█████▎    | 5312/10000 [00:06<00:05, 846.15samples/s]
# Processing samples:  54%|█████▍    | 5440/10000 [00:06<00:05, 847.95samples/s]
# Processing samples:  56%|█████▌    | 5568/10000 [00:06<00:05, 848.67samples/s]
# Processing samples:  57%|█████▋    | 5696/10000 [00:06<00:05, 848.00samples/s]
# Processing samples:  58%|█████▊    | 5824/10000 [00:07<00:04, 847.26samples/s]
# Processing samples:  60%|█████▉    | 5952/10000 [00:07<00:04, 847.76samples/s]
# Processing samples:  61%|██████    | 6080/10000 [00:07<00:04, 848.09samples/s]
# Processing samples:  62%|██████▏   | 6208/10000 [00:07<00:04, 847.62samples/s]
# Processing samples:  63%|██████▎   | 6336/10000 [00:07<00:04, 847.42samples/s]
# Processing samples:  65%|██████▍   | 6464/10000 [00:07<00:04, 847.40samples/s]
# Processing samples:  66%|██████▌   | 6592/10000 [00:07<00:04, 846.55samples/s]
# Processing samples:  67%|██████▋   | 6720/10000 [00:08<00:03, 846.94samples/s]
# Processing samples:  68%|██████▊   | 6848/10000 [00:08<00:03, 846.29samples/s]
# Processing samples:  70%|██████▉   | 6976/10000 [00:08<00:03, 844.94samples/s]
# Processing samples:  71%|███████   | 7104/10000 [00:08<00:03, 846.26samples/s]
# Processing samples:  72%|███████▏  | 7232/10000 [00:08<00:03, 844.37samples/s]
# Processing samples:  74%|███████▎  | 7360/10000 [00:08<00:03, 847.04samples/s]
# Processing samples:  75%|███████▍  | 7488/10000 [00:09<00:02, 847.07samples/s]
# Processing samples:  76%|███████▌  | 7616/10000 [00:09<00:02, 845.56samples/s]
# Processing samples:  77%|███████▋  | 7744/10000 [00:09<00:02, 844.76samples/s]
# Processing samples:  79%|███████▊  | 7872/10000 [00:09<00:02, 845.14samples/s]
# Processing samples:  80%|████████  | 8000/10000 [00:09<00:02, 845.16samples/s]
# Processing samples:  81%|████████▏ | 8128/10000 [00:09<00:02, 845.65samples/s]
# Processing samples:  83%|████████▎ | 8256/10000 [00:09<00:02, 845.73samples/s]
# Processing samples:  84%|████████▍ | 8384/10000 [00:10<00:01, 844.67samples/s]
# Processing samples:  85%|████████▌ | 8512/10000 [00:10<00:01, 845.02samples/s]
# Processing samples:  86%|████████▋ | 8640/10000 [00:10<00:01, 847.48samples/s]
# Processing samples:  88%|████████▊ | 8768/10000 [00:10<00:01, 849.61samples/s]
# Processing samples:  89%|████████▉ | 8896/10000 [00:10<00:01, 850.34samples/s]
# Processing samples:  90%|█████████ | 9024/10000 [00:10<00:01, 848.92samples/s]
# Processing samples:  92%|█████████▏| 9152/10000 [00:11<00:00, 848.26samples/s]
# Processing samples:  93%|█████████▎| 9280/10000 [00:11<00:00, 849.08samples/s]
# Processing samples:  94%|█████████▍| 9408/10000 [00:11<00:00, 848.39samples/s]
# Processing samples:  95%|█████████▌| 9536/10000 [00:11<00:00, 848.95samples/s]
# Processing samples:  97%|█████████▋| 9664/10000 [00:11<00:00, 849.65samples/s]
# Processing samples:  98%|█████████▊| 9792/10000 [00:11<00:00, 850.86samples/s]
# Processing samples:  99%|█████████▉| 9920/10000 [00:11<00:00, 849.92samples/s]
#                                                                               Processing samples
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Inception Score: 2.238329180538416 ± 0.045458657157484095
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 282.31202071211476
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:11,  8.64subsets/s]
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:11,  8.59subsets/s]
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:11,  8.22subsets/s]
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:11,  8.30subsets/s]
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:11,  8.05subsets/s]
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:11,  8.04subsets/s]
# Kernel Inception Distance:   7%|▋         | 7/100 [00:00<00:11,  7.99subsets/s]
# Kernel Inception Distance:   8%|▊         | 8/100 [00:00<00:11,  8.03subsets/s]
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:11,  8.17subsets/s]
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:10,  8.29subsets/s]
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:10,  8.35subsets/s]
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:10,  8.41subsets/s]
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:01<00:10,  8.20subsets/s]
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:01<00:10,  8.37subsets/s]
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:01<00:10,  8.36subsets/s]
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:01<00:09,  8.42subsets/s]
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:09,  8.42subsets/s]
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:09,  8.45subsets/s]
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:09,  8.41subsets/s]
# Kernel Inception Distance:  20%|██        | 20/100 [00:02<00:09,  8.35subsets/s]
# Kernel Inception Distance:  21%|██        | 21/100 [00:02<00:09,  8.36subsets/s]
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:02<00:09,  8.19subsets/s]
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:02<00:09,  8.27subsets/s]
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:02<00:09,  8.28subsets/s]
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:03<00:09,  8.30subsets/s]
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:08,  8.37subsets/s]
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:03<00:08,  8.42subsets/s]
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:03<00:08,  8.39subsets/s]
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:03<00:08,  8.39subsets/s]
# Kernel Inception Distance:  30%|███       | 30/100 [00:03<00:08,  8.38subsets/s]
# Kernel Inception Distance:  31%|███       | 31/100 [00:03<00:08,  8.44subsets/s]
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:03<00:08,  8.43subsets/s]
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:03<00:07,  8.51subsets/s]
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:04<00:07,  8.40subsets/s]
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:04<00:07,  8.45subsets/s]
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:04<00:07,  8.46subsets/s]
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:04<00:07,  8.57subsets/s]
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:04<00:07,  8.54subsets/s]
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:04<00:07,  8.51subsets/s]
# Kernel Inception Distance:  40%|████      | 40/100 [00:04<00:06,  8.62subsets/s]
# Kernel Inception Distance:  41%|████      | 41/100 [00:04<00:06,  8.44subsets/s]
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:05<00:06,  8.51subsets/s]
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:05<00:06,  8.54subsets/s]
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:05<00:06,  8.60subsets/s]
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:05<00:06,  8.69subsets/s]
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:05<00:06,  8.62subsets/s]
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:05<00:06,  8.63subsets/s]
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:05<00:06,  8.17subsets/s]
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:05<00:06,  8.11subsets/s]
# Kernel Inception Distance:  50%|█████     | 50/100 [00:05<00:06,  8.14subsets/s]
# Kernel Inception Distance:  51%|█████     | 51/100 [00:06<00:05,  8.28subsets/s]
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:06<00:05,  8.32subsets/s]
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:06<00:05,  8.33subsets/s]
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:06<00:05,  8.45subsets/s]
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:06<00:05,  8.56subsets/s]
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:06<00:05,  8.46subsets/s]
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:06<00:05,  8.50subsets/s]
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:06<00:04,  8.50subsets/s]
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:07<00:04,  8.54subsets/s]
# Kernel Inception Distance:  60%|██████    | 60/100 [00:07<00:04,  8.61subsets/s]
# Kernel Inception Distance:  61%|██████    | 61/100 [00:07<00:04,  8.67subsets/s]
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:07<00:04,  8.47subsets/s]
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:07<00:04,  8.50subsets/s]
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:07<00:04,  8.57subsets/s]
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:07<00:04,  8.43subsets/s]
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:07<00:04,  8.44subsets/s]
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:07<00:03,  8.45subsets/s]
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:08<00:03,  8.50subsets/s]
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:08<00:03,  8.57subsets/s]
# Kernel Inception Distance:  70%|███████   | 70/100 [00:08<00:03,  8.55subsets/s]
# Kernel Inception Distance:  71%|███████   | 71/100 [00:08<00:03,  8.58subsets/s]
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:08<00:03,  8.57subsets/s]
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:08<00:03,  8.53subsets/s]
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:08<00:03,  8.36subsets/s]
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:08<00:02,  8.50subsets/s]
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:09<00:02,  8.43subsets/s]
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:09<00:02,  8.60subsets/s]
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:09<00:02,  8.70subsets/s]
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:09<00:02,  8.67subsets/s]
# Kernel Inception Distance:  80%|████████  | 80/100 [00:09<00:02,  8.71subsets/s]
# Kernel Inception Distance:  81%|████████  | 81/100 [00:09<00:02,  8.69subsets/s]
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:09<00:02,  8.62subsets/s]
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:09<00:01,  8.50subsets/s]
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:09<00:01,  8.60subsets/s]
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:10<00:01,  8.69subsets/s]
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:10<00:01,  8.64subsets/s]
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:10<00:01,  8.76subsets/s]
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:10<00:01,  8.70subsets/s]
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:10<00:01,  8.62subsets/s]
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:10<00:01,  8.56subsets/s]
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:10<00:01,  8.49subsets/s]
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:10<00:00,  8.31subsets/s]
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:11<00:00,  8.29subsets/s]
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:11<00:00,  8.42subsets/s]
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:11<00:00,  8.49subsets/s]
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:11<00:00,  8.43subsets/s]
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:11<00:00,  8.44subsets/s]
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:11<00:00,  8.44subsets/s]
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:11<00:00,  8.38subsets/s]
# Kernel Inception Distance: 100%|██████████| 100/100 [00:11<00:00,  8.22subsets/s]
#                                                                                  Kernel Inception Distance: 0.26720941749999993 ± 0.0027288254944075846
# Global seed set to 42
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/optimization/closure.py:36: LightningDeprecationWarning: One of the returned values {'progress_bar', 'log'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   f"One of the returned values {set(extra.keys())} has a `grad_fn`. We will detach it automatically"
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Validating: 0it [00:00, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Extracting features from input1
#
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
#
# Processing samples:   1%|▏         | 128/10000 [00:00<00:13, 730.66samples/s]
#
# Processing samples:   3%|▎         | 256/10000 [00:00<00:13, 730.86samples/s]
#
# Processing samples:   4%|▍         | 384/10000 [00:00<00:13, 729.21samples/s]
#
# Processing samples:   5%|▌         | 512/10000 [00:00<00:13, 729.35samples/s]
#
# Processing samples:   6%|▋         | 640/10000 [00:00<00:12, 729.17samples/s]
#
# Processing samples:   8%|▊         | 768/10000 [00:01<00:12, 729.59samples/s]
#
# Processing samples:   9%|▉         | 896/10000 [00:01<00:12, 729.47samples/s]
#
# Processing samples:  10%|█         | 1024/10000 [00:01<00:12, 729.28samples/s]
#
# Processing samples:  12%|█▏        | 1152/10000 [00:01<00:12, 729.32samples/s]
#
# Processing samples:  13%|█▎        | 1280/10000 [00:01<00:11, 729.43samples/s]
#
# Processing samples:  14%|█▍        | 1408/10000 [00:01<00:11, 729.69samples/s]
#
# Processing samples:  15%|█▌        | 1536/10000 [00:02<00:11, 729.22samples/s]
#
# Processing samples:  17%|█▋        | 1664/10000 [00:02<00:11, 728.76samples/s]
#
# Processing samples:  18%|█▊        | 1792/10000 [00:02<00:11, 729.57samples/s]
#
# Processing samples:  19%|█▉        | 1920/10000 [00:02<00:11, 730.03samples/s]
#
# Processing samples:  20%|██        | 2048/10000 [00:02<00:10, 727.94samples/s]
#
# Processing samples:  22%|██▏       | 2176/10000 [00:02<00:10, 726.19samples/s]
#
# Processing samples:  23%|██▎       | 2304/10000 [00:03<00:10, 726.19samples/s]
#
# Processing samples:  24%|██▍       | 2432/10000 [00:03<00:10, 725.42samples/s]
#
# Processing samples:  26%|██▌       | 2560/10000 [00:03<00:10, 724.05samples/s]
#
# Processing samples:  27%|██▋       | 2688/10000 [00:03<00:10, 725.03samples/s]
#
# Processing samples:  28%|██▊       | 2816/10000 [00:03<00:09, 725.60samples/s]
#
# Processing samples:  29%|██▉       | 2944/10000 [00:04<00:09, 726.65samples/s]
#
# Processing samples:  31%|███       | 3072/10000 [00:04<00:09, 725.71samples/s]
#
# Processing samples:  32%|███▏      | 3200/10000 [00:04<00:09, 726.04samples/s]
#
# Processing samples:  33%|███▎      | 3328/10000 [00:04<00:09, 726.25samples/s]
#
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:09, 726.65samples/s]
#
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:08, 726.76samples/s]
#
# Processing samples:  37%|███▋      | 3712/10000 [00:05<00:08, 724.39samples/s]
#
# Processing samples:  38%|███▊      | 3840/10000 [00:05<00:08, 723.75samples/s]
#
# Processing samples:  40%|███▉      | 3968/10000 [00:05<00:08, 723.54samples/s]
#
# Processing samples:  41%|████      | 4096/10000 [00:05<00:08, 725.21samples/s]
#
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:07, 726.41samples/s]
#
# Processing samples:  44%|████▎     | 4352/10000 [00:05<00:07, 727.37samples/s]
#
# Processing samples:  45%|████▍     | 4480/10000 [00:06<00:07, 727.46samples/s]
#
# Processing samples:  46%|████▌     | 4608/10000 [00:06<00:07, 727.89samples/s]
#
# Processing samples:  47%|████▋     | 4736/10000 [00:06<00:07, 728.63samples/s]
#
# Processing samples:  49%|████▊     | 4864/10000 [00:06<00:07, 728.29samples/s]
#
# Processing samples:  50%|████▉     | 4992/10000 [00:06<00:06, 727.19samples/s]
#
# Processing samples:  51%|█████     | 5120/10000 [00:07<00:06, 726.94samples/s]
#
# Processing samples:  52%|█████▏    | 5248/10000 [00:07<00:06, 727.89samples/s]
#
# Processing samples:  54%|█████▍    | 5376/10000 [00:07<00:06, 728.49samples/s]
#
# Processing samples:  55%|█████▌    | 5504/10000 [00:07<00:06, 728.13samples/s]
#
# Processing samples:  56%|█████▋    | 5632/10000 [00:07<00:05, 728.37samples/s]
#
# Processing samples:  58%|█████▊    | 5760/10000 [00:07<00:05, 729.05samples/s]
#
# Processing samples:  59%|█████▉    | 5888/10000 [00:08<00:05, 728.48samples/s]
#
# Processing samples:  60%|██████    | 6016/10000 [00:08<00:05, 728.13samples/s]
#
# Processing samples:  61%|██████▏   | 6144/10000 [00:08<00:05, 724.41samples/s]
#
# Processing samples:  63%|██████▎   | 6272/10000 [00:08<00:05, 726.26samples/s]
#
# Processing samples:  64%|██████▍   | 6400/10000 [00:08<00:04, 725.00samples/s]
#
# Processing samples:  65%|██████▌   | 6528/10000 [00:08<00:04, 724.75samples/s]
#
# Processing samples:  67%|██████▋   | 6656/10000 [00:09<00:04, 724.22samples/s]
#
# Processing samples:  68%|██████▊   | 6784/10000 [00:09<00:04, 725.45samples/s]
#
# Processing samples:  69%|██████▉   | 6912/10000 [00:09<00:04, 725.05samples/s]
#
# Processing samples:  70%|███████   | 7040/10000 [00:09<00:04, 724.03samples/s]
#
# Processing samples:  72%|███████▏  | 7168/10000 [00:09<00:03, 725.64samples/s]
#
# Processing samples:  73%|███████▎  | 7296/10000 [00:10<00:03, 725.34samples/s]
#
# Processing samples:  74%|███████▍  | 7424/10000 [00:10<00:03, 725.99samples/s]
#
# Processing samples:  76%|███████▌  | 7552/10000 [00:10<00:03, 726.40samples/s]
#
# Processing samples:  77%|███████▋  | 7680/10000 [00:10<00:03, 726.59samples/s]
#
# Processing samples:  78%|███████▊  | 7808/10000 [00:10<00:03, 725.95samples/s]
#
# Processing samples:  79%|███████▉  | 7936/10000 [00:10<00:02, 727.04samples/s]
#
# Processing samples:  81%|████████  | 8064/10000 [00:11<00:02, 727.66samples/s]
#
# Processing samples:  82%|████████▏ | 8192/10000 [00:11<00:02, 728.99samples/s]
#
# Processing samples:  83%|████████▎ | 8320/10000 [00:11<00:02, 729.14samples/s]
#
# Processing samples:  84%|████████▍ | 8448/10000 [00:11<00:02, 730.07samples/s]
#
# Processing samples:  86%|████████▌ | 8576/10000 [00:11<00:01, 729.84samples/s]
#
# Processing samples:  87%|████████▋ | 8704/10000 [00:11<00:01, 730.22samples/s]
#
# Processing samples:  88%|████████▊ | 8832/10000 [00:12<00:01, 729.54samples/s]
#
# Processing samples:  90%|████████▉ | 8960/10000 [00:12<00:01, 729.92samples/s]
#
# Processing samples:  91%|█████████ | 9088/10000 [00:12<00:01, 730.15samples/s]
#
# Processing samples:  92%|█████████▏| 9216/10000 [00:12<00:01, 731.25samples/s]
#
# Processing samples:  93%|█████████▎| 9344/10000 [00:12<00:00, 731.25samples/s]
#
# Processing samples:  95%|█████████▍| 9472/10000 [00:13<00:00, 730.58samples/s]
#
# Processing samples:  96%|█████████▌| 9600/10000 [00:13<00:00, 731.74samples/s]
#
# Processing samples:  97%|█████████▋| 9728/10000 [00:13<00:00, 730.67samples/s]
#
# Processing samples:  99%|█████████▊| 9856/10000 [00:13<00:00, 728.48samples/s]
#
# Processing samples: 100%|█████████▉| 9984/10000 [00:13<00:00, 729.20samples/s]
#
#                                                                               Processing samples
# Extracting features from input2
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Inception Score: 2.3743424328785445 ± 0.029794394771509868
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 223.45202674933728
#
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
#
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:11,  8.41subsets/s]
#
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:12,  8.12subsets/s]
#
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:12,  8.00subsets/s]
#
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:12,  7.90subsets/s]
#
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:12,  7.66subsets/s]
#
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:12,  7.68subsets/s]
#
# Kernel Inception Distance:   7%|▋         | 7/100 [00:00<00:12,  7.61subsets/s]
#
# Kernel Inception Distance:   8%|▊         | 8/100 [00:01<00:11,  7.76subsets/s]
#
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:11,  7.92subsets/s]
#
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:11,  8.07subsets/s]
#
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:10,  8.19subsets/s]
#
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:10,  8.29subsets/s]
#
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:01<00:10,  8.38subsets/s]
#
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:01<00:10,  8.26subsets/s]
#
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:01<00:10,  8.23subsets/s]
#
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:01<00:10,  8.26subsets/s]
#
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:09,  8.35subsets/s]
#
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:09,  8.25subsets/s]
#
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:09,  8.37subsets/s]
#
# Kernel Inception Distance:  20%|██        | 20/100 [00:02<00:09,  8.44subsets/s]
#
# Kernel Inception Distance:  21%|██        | 21/100 [00:02<00:09,  8.50subsets/s]
#
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:02<00:09,  8.47subsets/s]
#
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:02<00:09,  8.34subsets/s]
#
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:02<00:09,  8.26subsets/s]
#
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:03<00:09,  8.20subsets/s]
#
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:09,  8.18subsets/s]
#
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:03<00:09,  8.09subsets/s]
#
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:03<00:08,  8.16subsets/s]
#
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:03<00:08,  8.19subsets/s]
#
# Kernel Inception Distance:  30%|███       | 30/100 [00:03<00:08,  8.22subsets/s]
#
# Kernel Inception Distance:  31%|███       | 31/100 [00:03<00:08,  7.92subsets/s]
#
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:03<00:08,  7.88subsets/s]
#
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:04<00:08,  7.90subsets/s]
#
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:04<00:08,  7.84subsets/s]
#
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:04<00:08,  7.85subsets/s]
#
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:04<00:08,  7.82subsets/s]
#
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:04<00:08,  7.84subsets/s]
#
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:04<00:07,  7.91subsets/s]
#
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:04<00:08,  7.61subsets/s]
#
# Kernel Inception Distance:  40%|████      | 40/100 [00:04<00:07,  7.65subsets/s]
#
# Kernel Inception Distance:  41%|████      | 41/100 [00:05<00:07,  7.72subsets/s]
#
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:05<00:07,  7.75subsets/s]
#
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:05<00:07,  7.74subsets/s]
#
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:05<00:07,  7.83subsets/s]
#
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:05<00:06,  7.92subsets/s]
#
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:05<00:06,  7.83subsets/s]
#
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:05<00:06,  7.70subsets/s]
#
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:06<00:06,  7.73subsets/s]
#
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:06<00:06,  7.80subsets/s]
#
# Kernel Inception Distance:  50%|█████     | 50/100 [00:06<00:06,  7.80subsets/s]
#
# Kernel Inception Distance:  51%|█████     | 51/100 [00:06<00:06,  7.88subsets/s]
#
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:06<00:06,  7.94subsets/s]
#
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:06<00:05,  8.01subsets/s]
#
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:06<00:05,  7.99subsets/s]
#
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:06<00:05,  7.83subsets/s]
#
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:07<00:05,  7.87subsets/s]
#
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:07<00:05,  8.02subsets/s]
#
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:07<00:05,  8.10subsets/s]
#
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:07<00:04,  8.26subsets/s]
#
# Kernel Inception Distance:  60%|██████    | 60/100 [00:07<00:04,  8.24subsets/s]
#
# Kernel Inception Distance:  61%|██████    | 61/100 [00:07<00:04,  8.26subsets/s]
#
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:07<00:04,  8.36subsets/s]
#
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:07<00:04,  8.36subsets/s]
#
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:07<00:04,  8.22subsets/s]
#
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:08<00:04,  8.20subsets/s]
#
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:08<00:04,  8.35subsets/s]
#
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:08<00:03,  8.33subsets/s]
#
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:08<00:03,  8.36subsets/s]
#
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:08<00:03,  8.21subsets/s]
#
# Kernel Inception Distance:  70%|███████   | 70/100 [00:08<00:03,  8.30subsets/s]
#
# Kernel Inception Distance:  71%|███████   | 71/100 [00:08<00:03,  8.22subsets/s]
#
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:08<00:03,  7.97subsets/s]
#
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:09<00:03,  8.06subsets/s]
#
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:09<00:03,  8.09subsets/s]
#
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:09<00:03,  8.09subsets/s]
#
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:09<00:02,  8.20subsets/s]
#
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:09<00:02,  8.19subsets/s]
#
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:09<00:02,  8.25subsets/s]
#
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:09<00:02,  8.24subsets/s]
#
# Kernel Inception Distance:  80%|████████  | 80/100 [00:09<00:02,  8.26subsets/s]
#
# Kernel Inception Distance:  81%|████████  | 81/100 [00:10<00:02,  8.27subsets/s]
#
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:10<00:02,  8.28subsets/s]
#
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:10<00:02,  8.21subsets/s]
#
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:10<00:01,  8.24subsets/s]
#
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:10<00:01,  8.16subsets/s]
#
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:10<00:01,  8.22subsets/s]
#
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:10<00:01,  8.06subsets/s]
#
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:10<00:01,  8.10subsets/s]
#
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:11<00:01,  8.07subsets/s]
#
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:11<00:01,  8.15subsets/s]
#
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:11<00:01,  8.09subsets/s]
#
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:11<00:01,  7.90subsets/s]
#
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:11<00:00,  7.97subsets/s]
#
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:11<00:00,  7.99subsets/s]
#
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:11<00:00,  8.02subsets/s]
#
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:11<00:00,  8.06subsets/s]
#
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:12<00:00,  7.97subsets/s]
#
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:12<00:00,  8.11subsets/s]
#
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:12<00:00,  8.15subsets/s]
#
# Kernel Inception Distance: 100%|██████████| 100/100 [00:12<00:00,  8.15subsets/s]
#
#                                                                                  Kernel Inception Distance: 0.2168568273648648 ± 0.0026040157610994724
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Validating: 0it [00:00, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Extracting features from input1
#
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
#
# Processing samples:   1%|▏         | 128/10000 [00:00<00:13, 739.03samples/s]
#
# Processing samples:   3%|▎         | 256/10000 [00:00<00:13, 736.11samples/s]
#
# Processing samples:   4%|▍         | 384/10000 [00:00<00:13, 734.66samples/s]
#
# Processing samples:   5%|▌         | 512/10000 [00:00<00:12, 733.89samples/s]
#
# Processing samples:   6%|▋         | 640/10000 [00:00<00:12, 732.97samples/s]
#
# Processing samples:   8%|▊         | 768/10000 [00:01<00:12, 734.17samples/s]
#
# Processing samples:   9%|▉         | 896/10000 [00:01<00:12, 734.19samples/s]
#
# Processing samples:  10%|█         | 1024/10000 [00:01<00:12, 733.94samples/s]
#
# Processing samples:  12%|█▏        | 1152/10000 [00:01<00:12, 733.68samples/s]
#
# Processing samples:  13%|█▎        | 1280/10000 [00:01<00:11, 733.58samples/s]
#
# Processing samples:  14%|█▍        | 1408/10000 [00:01<00:11, 732.06samples/s]
#
# Processing samples:  15%|█▌        | 1536/10000 [00:02<00:11, 731.55samples/s]
#
# Processing samples:  17%|█▋        | 1664/10000 [00:02<00:11, 728.65samples/s]
#
# Processing samples:  18%|█▊        | 1792/10000 [00:02<00:11, 729.17samples/s]
#
# Processing samples:  19%|█▉        | 1920/10000 [00:02<00:11, 728.81samples/s]
#
# Processing samples:  20%|██        | 2048/10000 [00:02<00:10, 728.70samples/s]
#
# Processing samples:  22%|██▏       | 2176/10000 [00:02<00:10, 727.23samples/s]
#
# Processing samples:  23%|██▎       | 2304/10000 [00:03<00:10, 728.85samples/s]
#
# Processing samples:  24%|██▍       | 2432/10000 [00:03<00:10, 729.87samples/s]
#
# Processing samples:  26%|██▌       | 2560/10000 [00:03<00:10, 730.72samples/s]
#
# Processing samples:  27%|██▋       | 2688/10000 [00:03<00:10, 730.51samples/s]
#
# Processing samples:  28%|██▊       | 2816/10000 [00:03<00:09, 730.68samples/s]
#
# Processing samples:  29%|██▉       | 2944/10000 [00:04<00:09, 731.55samples/s]
#
# Processing samples:  31%|███       | 3072/10000 [00:04<00:09, 731.24samples/s]
#
# Processing samples:  32%|███▏      | 3200/10000 [00:04<00:09, 730.49samples/s]
#
# Processing samples:  33%|███▎      | 3328/10000 [00:04<00:09, 729.57samples/s]
#
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:08, 730.27samples/s]
#
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:08, 731.89samples/s]
#
# Processing samples:  37%|███▋      | 3712/10000 [00:05<00:08, 731.95samples/s]
#
# Processing samples:  38%|███▊      | 3840/10000 [00:05<00:08, 733.13samples/s]
#
# Processing samples:  40%|███▉      | 3968/10000 [00:05<00:08, 732.56samples/s]
#
# Processing samples:  41%|████      | 4096/10000 [00:05<00:08, 732.85samples/s]
#
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:07, 732.31samples/s]
#
# Processing samples:  44%|████▎     | 4352/10000 [00:05<00:07, 732.55samples/s]
#
# Processing samples:  45%|████▍     | 4480/10000 [00:06<00:07, 732.98samples/s]
#
# Processing samples:  46%|████▌     | 4608/10000 [00:06<00:07, 733.70samples/s]
#
# Processing samples:  47%|████▋     | 4736/10000 [00:06<00:07, 733.37samples/s]
#
# Processing samples:  49%|████▊     | 4864/10000 [00:06<00:07, 733.32samples/s]
#
# Processing samples:  50%|████▉     | 4992/10000 [00:06<00:06, 733.03samples/s]
#
# Processing samples:  51%|█████     | 5120/10000 [00:06<00:06, 733.87samples/s]
#
# Processing samples:  52%|█████▏    | 5248/10000 [00:07<00:06, 734.64samples/s]
#
# Processing samples:  54%|█████▍    | 5376/10000 [00:07<00:06, 732.77samples/s]
#
# Processing samples:  55%|█████▌    | 5504/10000 [00:07<00:06, 731.28samples/s]
#
# Processing samples:  56%|█████▋    | 5632/10000 [00:07<00:05, 731.43samples/s]
#
# Processing samples:  58%|█████▊    | 5760/10000 [00:07<00:05, 731.41samples/s]
#
# Processing samples:  59%|█████▉    | 5888/10000 [00:08<00:05, 731.15samples/s]
#
# Processing samples:  60%|██████    | 6016/10000 [00:08<00:05, 730.73samples/s]
#
# Processing samples:  61%|██████▏   | 6144/10000 [00:08<00:05, 732.38samples/s]
#
# Processing samples:  63%|██████▎   | 6272/10000 [00:08<00:05, 732.43samples/s]
#
# Processing samples:  64%|██████▍   | 6400/10000 [00:08<00:04, 732.43samples/s]
#
# Processing samples:  65%|██████▌   | 6528/10000 [00:08<00:04, 733.18samples/s]
#
# Processing samples:  67%|██████▋   | 6656/10000 [00:09<00:04, 731.87samples/s]
#
# ...
#
# Processing samples:   6%|▋         | 640/10000 [00:00<00:12, 720.72samples/s]
#
# Processing samples:   8%|▊         | 768/10000 [00:01<00:12, 722.83samples/s]
#
# Processing samples:   9%|▉         | 896/10000 [00:01<00:12, 724.48samples/s]
#
# Processing samples:  10%|█         | 1024/10000 [00:01<00:12, 724.67samples/s]
#
# Processing samples:  12%|█▏        | 1152/10000 [00:01<00:12, 725.79samples/s]
#
# Processing samples:  13%|█▎        | 1280/10000 [00:01<00:11, 726.81samples/s]
#
# Processing samples:  14%|█▍        | 1408/10000 [00:01<00:11, 725.52samples/s]
#
# Processing samples:  15%|█▌        | 1536/10000 [00:02<00:11, 727.21samples/s]
#
# Processing samples:  17%|█▋        | 1664/10000 [00:02<00:11, 727.31samples/s]
#
# Processing samples:  18%|█▊        | 1792/10000 [00:02<00:11, 727.37samples/s]
#
# Processing samples:  19%|█▉        | 1920/10000 [00:02<00:11, 726.04samples/s]
#
# Processing samples:  20%|██        | 2048/10000 [00:02<00:10, 729.08samples/s]
#
# Processing samples:  22%|██▏       | 2176/10000 [00:03<00:10, 726.89samples/s]
#
# Processing samples:  23%|██▎       | 2304/10000 [00:03<00:10, 728.30samples/s]
#
# Processing samples:  24%|██▍       | 2432/10000 [00:03<00:10, 729.18samples/s]
#
# Processing samples:  26%|██▌       | 2560/10000 [00:03<00:10, 730.61samples/s]
#
# Processing samples:  27%|██▋       | 2688/10000 [00:03<00:10, 729.75samples/s]
#
# Processing samples:  28%|██▊       | 2816/10000 [00:03<00:09, 731.86samples/s]
#
# Processing samples:  29%|██▉       | 2944/10000 [00:04<00:09, 731.92samples/s]
#
# Processing samples:  31%|███       | 3072/10000 [00:04<00:09, 732.88samples/s]
#
# Processing samples:  32%|███▏      | 3200/10000 [00:04<00:09, 732.42samples/s]
#
# Processing samples:  33%|███▎      | 3328/10000 [00:04<00:09, 732.55samples/s]
#
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:08, 731.96samples/s]
#
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:08, 732.00samples/s]
#
# Processing samples:  37%|███▋      | 3712/10000 [00:05<00:08, 731.33samples/s]
#
# Processing samples:  38%|███▊      | 3840/10000 [00:05<00:08, 732.13samples/s]
#
# Processing samples:  40%|███▉      | 3968/10000 [00:05<00:08, 731.25samples/s]
#
# Processing samples:  41%|████      | 4096/10000 [00:05<00:08, 731.55samples/s]
#
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:07, 731.14samples/s]
#
# Processing samples:  44%|████▎     | 4352/10000 [00:05<00:07, 729.85samples/s]
#
# Processing samples:  45%|████▍     | 4480/10000 [00:06<00:07, 730.90samples/s]
#
# Processing samples:  46%|████▌     | 4608/10000 [00:06<00:07, 731.75samples/s]
#
# Processing samples:  47%|████▋     | 4736/10000 [00:06<00:07, 732.02samples/s]
#
# Processing samples:  49%|████▊     | 4864/10000 [00:06<00:07, 731.96samples/s]
#
# Processing samples:  50%|████▉     | 4992/10000 [00:06<00:06, 732.92samples/s]
#
# Processing samples:  51%|█████     | 5120/10000 [00:07<00:06, 732.29samples/s]
#
# Processing samples:  52%|█████▏    | 5248/10000 [00:07<00:06, 731.73samples/s]
#
# Processing samples:  54%|█████▍    | 5376/10000 [00:07<00:06, 732.69samples/s]
#
# Processing samples:  55%|█████▌    | 5504/10000 [00:07<00:06, 732.18samples/s]
#
# Processing samples:  56%|█████▋    | 5632/10000 [00:07<00:05, 730.06samples/s]
#
# Processing samples:  58%|█████▊    | 5760/10000 [00:07<00:05, 728.87samples/s]
#
# Processing samples:  59%|█████▉    | 5888/10000 [00:08<00:05, 727.22samples/s]
#
# Processing samples:  60%|██████    | 6016/10000 [00:08<00:05, 727.22samples/s]
#
# Processing samples:  61%|██████▏   | 6144/10000 [00:08<00:05, 727.97samples/s]
#
# Processing samples:  63%|██████▎   | 6272/10000 [00:08<00:05, 727.75samples/s]
#
# Processing samples:  64%|██████▍   | 6400/10000 [00:08<00:04, 729.09samples/s]
#
# Processing samples:  65%|██████▌   | 6528/10000 [00:08<00:04, 730.24samples/s]
#
# Processing samples:  67%|██████▋   | 6656/10000 [00:09<00:04, 730.02samples/s]
#
# Processing samples:  68%|██████▊   | 6784/10000 [00:09<00:04, 729.66samples/s]
#
# Processing samples:  69%|██████▉   | 6912/10000 [00:09<00:04, 729.16samples/s]
#
# Processing samples:  70%|███████   | 7040/10000 [00:09<00:04, 728.23samples/s]
#
# Processing samples:  72%|███████▏  | 7168/10000 [00:09<00:03, 728.29samples/s]
#
# Processing samples:  73%|███████▎  | 7296/10000 [00:10<00:03, 727.75samples/s]
#
# Processing samples:  74%|███████▍  | 7424/10000 [00:10<00:03, 727.80samples/s]
#
# Processing samples:  76%|███████▌  | 7552/10000 [00:10<00:03, 728.36samples/s]
#
# Processing samples:  77%|███████▋  | 7680/10000 [00:10<00:03, 728.24samples/s]
#
# Processing samples:  78%|███████▊  | 7808/10000 [00:10<00:03, 728.84samples/s]
#
# Processing samples:  79%|███████▉  | 7936/10000 [00:10<00:02, 729.32samples/s]
#
# Processing samples:  81%|████████  | 8064/10000 [00:11<00:02, 728.38samples/s]
#
# Processing samples:  82%|████████▏ | 8192/10000 [00:11<00:02, 729.10samples/s]
#
# Processing samples:  83%|████████▎ | 8320/10000 [00:11<00:02, 729.75samples/s]
#
# Processing samples:  84%|████████▍ | 8448/10000 [00:11<00:02, 729.90samples/s]
#
# Processing samples:  86%|████████▌ | 8576/10000 [00:11<00:01, 730.15samples/s]
#
# Processing samples:  87%|████████▋ | 8704/10000 [00:11<00:01, 730.45samples/s]
#
# Processing samples:  88%|████████▊ | 8832/10000 [00:12<00:01, 730.67samples/s]
#
# Processing samples:  90%|████████▉ | 8960/10000 [00:12<00:01, 731.44samples/s]
#
# Processing samples:  91%|█████████ | 9088/10000 [00:12<00:01, 732.46samples/s]
#
# Processing samples:  92%|█████████▏| 9216/10000 [00:12<00:01, 731.45samples/s]
#
# Processing samples:  93%|█████████▎| 9344/10000 [00:12<00:00, 730.90samples/s]
#
# Processing samples:  95%|█████████▍| 9472/10000 [00:12<00:00, 730.62samples/s]
#
# Processing samples:  96%|█████████▌| 9600/10000 [00:13<00:00, 730.41samples/s]
#
# Processing samples:  97%|█████████▋| 9728/10000 [00:13<00:00, 730.44samples/s]
#
# Processing samples:  99%|█████████▊| 9856/10000 [00:13<00:00, 731.09samples/s]
#
# Processing samples: 100%|█████████▉| 9984/10000 [00:13<00:00, 730.96samples/s]
#
#                                                                               Processing samples
# Extracting features from input2
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Inception Score: 7.988368874260608 ± 0.1337317405191027
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 19.98818389564576
#
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
#
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:16,  5.86subsets/s]
#
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:14,  6.60subsets/s]
#
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:15,  6.28subsets/s]
#
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:15,  6.26subsets/s]
#
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:13,  6.80subsets/s]
#
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:13,  7.14subsets/s]
#
# Kernel Inception Distance:   7%|▋         | 7/100 [00:01<00:13,  7.15subsets/s]
#
# Kernel Inception Distance:   8%|▊         | 8/100 [00:01<00:13,  6.94subsets/s]
#
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:13,  6.73subsets/s]
#
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:12,  7.26subsets/s]
#
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:12,  7.00subsets/s]
#
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:12,  7.29subsets/s]
#
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:01<00:12,  7.13subsets/s]
#
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:02<00:12,  6.71subsets/s]
#
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:02<00:13,  6.41subsets/s]
#
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:02<00:13,  6.23subsets/s]
#
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:12,  6.48subsets/s]
#
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:12,  6.57subsets/s]
#
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:12,  6.52subsets/s]
#
# Kernel Inception Distance:  20%|██        | 20/100 [00:02<00:12,  6.66subsets/s]
#
# Kernel Inception Distance:  21%|██        | 21/100 [00:03<00:12,  6.36subsets/s]
#
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:03<00:11,  6.61subsets/s]
#
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:03<00:11,  6.63subsets/s]
#
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:03<00:11,  6.39subsets/s]
#
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:03<00:11,  6.41subsets/s]
#
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:11,  6.39subsets/s]
#
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:04<00:11,  6.30subsets/s]
#
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:04<00:11,  6.43subsets/s]
#
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:04<00:11,  6.35subsets/s]
#
# Kernel Inception Distance:  30%|███       | 30/100 [00:04<00:11,  6.19subsets/s]
#
# Kernel Inception Distance:  31%|███       | 31/100 [00:04<00:10,  6.40subsets/s]
#
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:04<00:10,  6.61subsets/s]
#
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:05<00:10,  6.36subsets/s]
#
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:05<00:10,  6.40subsets/s]
#
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:05<00:09,  6.84subsets/s]
#
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:05<00:09,  6.43subsets/s]
#
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:05<00:09,  6.33subsets/s]
#
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:05<00:10,  6.15subsets/s]
#
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:05<00:09,  6.35subsets/s]
#
# Kernel Inception Distance:  40%|████      | 40/100 [00:06<00:09,  6.63subsets/s]
#
# Kernel Inception Distance:  41%|████      | 41/100 [00:06<00:08,  6.62subsets/s]
#
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:06<00:08,  6.71subsets/s]
#
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:06<00:08,  6.62subsets/s]
#
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:06<00:08,  6.89subsets/s]
#
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:06<00:07,  7.21subsets/s]
#
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:06<00:07,  7.34subsets/s]
#
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:07<00:07,  7.49subsets/s]
#
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:07<00:07,  6.80subsets/s]
#
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:07<00:07,  6.85subsets/s]
#
# Kernel Inception Distance:  50%|█████     | 50/100 [00:07<00:07,  6.47subsets/s]
#
# Kernel Inception Distance:  51%|█████     | 51/100 [00:07<00:07,  6.58subsets/s]
#
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:07<00:07,  6.38subsets/s]
#
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:08<00:07,  6.63subsets/s]
#
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:08<00:06,  6.67subsets/s]
#
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:08<00:06,  6.95subsets/s]
#
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:08<00:06,  7.17subsets/s]
#
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:08<00:05,  7.23subsets/s]
#
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:08<00:06,  6.86subsets/s]
#
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:08<00:06,  6.65subsets/s]
#
# Kernel Inception Distance:  60%|██████    | 60/100 [00:09<00:06,  6.31subsets/s]
#
# Kernel Inception Distance:  61%|██████    | 61/100 [00:09<00:06,  6.36subsets/s]
#
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:09<00:05,  6.70subsets/s]
#
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:09<00:05,  6.43subsets/s]
#
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:09<00:05,  6.72subsets/s]
#
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:09<00:05,  6.43subsets/s]
#
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:09<00:05,  6.33subsets/s]
#
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:10<00:05,  6.15subsets/s]
#
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:10<00:04,  6.60subsets/s]
#
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:10<00:04,  6.43subsets/s]
#
# Kernel Inception Distance:  70%|███████   | 70/100 [00:10<00:04,  6.49subsets/s]
#
# Kernel Inception Distance:  71%|███████   | 71/100 [00:10<00:04,  6.33subsets/s]
#
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:10<00:04,  6.60subsets/s]
#
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:11<00:04,  6.58subsets/s]
#
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:11<00:04,  6.44subsets/s]
#
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:11<00:03,  6.64subsets/s]
#
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:11<00:03,  6.80subsets/s]
#
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:11<00:03,  6.98subsets/s]
#
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:11<00:03,  6.73subsets/s]
#
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:11<00:03,  6.96subsets/s]
#
# Kernel Inception Distance:  80%|████████  | 80/100 [00:12<00:02,  6.98subsets/s]
#
# Kernel Inception Distance:  81%|████████  | 81/100 [00:12<00:02,  7.18subsets/s]
#
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:12<00:02,  6.79subsets/s]
#
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:12<00:02,  6.80subsets/s]
#
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:12<00:02,  6.48subsets/s]
#
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:12<00:02,  6.59subsets/s]
#
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:12<00:02,  6.25subsets/s]
#
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:13<00:02,  6.26subsets/s]
#
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:13<00:01,  6.31subsets/s]
#
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:13<00:01,  6.37subsets/s]
#
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:13<00:01,  6.30subsets/s]
#
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:13<00:01,  6.23subsets/s]
#
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:13<00:01,  5.78subsets/s]
#
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:14<00:01,  6.04subsets/s]
#
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:14<00:00,  6.24subsets/s]
#
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:14<00:00,  6.11subsets/s]
#
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:14<00:00,  5.92subsets/s]
#
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:14<00:00,  6.21subsets/s]
#
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:14<00:00,  6.44subsets/s]
#
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:15<00:00,  6.66subsets/s]
#
# Kernel Inception Distance: 100%|██████████| 100/100 [00:15<00:00,  7.04subsets/s]
#
#                                                                                  Kernel Inception Distance: 0.011442661874374371 ± 0.0011695643370948766
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:688: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 280... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 5525.04MB of 5525.04MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, ma…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>FID</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>IS</td><td>▁▂▄▄▅▆▆▆▇▇▆▇▇▇▇▇▇▇█▇████▇▇█▇▇███████████</td></tr><tr><td>KID</td><td>█▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_discriminator_loss</td><td>▁▆▇▇▆▆▇▇▇▇▇▇▇▇▇▇▇███▇███████████████████</td></tr><tr><td>train_gen_loss</td><td>█▁▃▁▃▃▃▁▄▃▃▃▃▃▃▃▃▃▃▃▄▂▃▃▃▂▃▂▂▂▂▃▂▂▂▂▂▃▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>FID</td><td>19.98818</td></tr><tr><td>IS</td><td>7.98837</td></tr><tr><td>KID</td><td>0.01144</td></tr><tr><td>epoch</td><td>351</td></tr><tr><td>train_discriminator_loss</td><td>1.89019</td></tr><tr><td>train_gen_loss</td><td>0.13036</td></tr><tr><td>trainer/global_step</td><td>68991</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 423 media file(s), 70 artifact file(s) and 1 other file(s)
# <br/>Synced <strong style="color:#cdcd00">vibrant-brook-92</strong>: <a href="https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/19kepjip" target="_blank">https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/19kepjip</a><br/>
# Find logs at: <code>./wandb/run-20220206_150542-19kepjip/logs</code><br/>
