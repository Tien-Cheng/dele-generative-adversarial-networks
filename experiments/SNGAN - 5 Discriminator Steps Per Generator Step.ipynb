# %% [markdown]
# # Background
#
# ## Problem Statement
#
# My objective for this project is to attempt to create a GAN model that is able to generate realistic images based on information that is provided to it.
#
# Such a task generally falls under two categories:
#
# 1. Conditional Image Generation: Given a class (e.g. a car), generate an image of that class
# 2. Controllable Image Generation: Given some description of features of the image (e.g. The car should be red in color), generate an image with those features
#
# In this project, I hope to tackle the first category (Conditional Image Generation), with the view of eventually tackling the second category if time and resources permit.
#
# So, what would I consider to be a success? Well, I would preferably hope to be able to reliably generate images conditionally that look real enough, based on
#
# - Eye Power 🕵️
# - Metrics like FID (described later in the report)
#
# By real enough, I mean that I hope to get results that are close enough to some of the top GAN models out there, with minimal artifacts.

# %% [markdown]
# # Google Colab Setup
#
# Due to the heavy computational requirements for training a GAN, Google Colab is used as a compute platform. The dataset and utilty functions have been stored on a GitHub repository, and so we need to clone the Git repo. In addition, some additional libraries have to be installed.

# %%
! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp: # Repository Deploy Key
    fp.write("""
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
""")
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:Tien-Cheng/dele-generative-adversarial-networks.git
# %cd /content/dele-generative-adversarial-networks
# Out:
# # github.com:22 SSH-2.0-babeld-00610741
# Cloning into 'dele-generative-adversarial-networks'...
# Warning: Permanently added the RSA host key for IP address '140.82.113.4' to the list of known hosts.
# remote: Enumerating objects: 555, done.
# remote: Counting objects: 100% (555/555), done.
# remote: Compressing objects: 100% (374/374), done.
# remote: Total 555 (delta 345), reused 369 (delta 169), pack-reused 0
# Receiving objects: 100% (555/555), 696.36 KiB | 3.08 MiB/s, done.
# Resolving deltas: 100% (345/345), done.
# /content/dele-generative-adversarial-networks

# %%
# %%capture
# %pip install -U torch-fidelity wandb torch-summary pytorch-lightning

# %% [markdown]
# # Setup

# %% [markdown]
# ### Imports

# %%
import gc
from collections import OrderedDict
from typing import *

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch_fidelity
from pytorch_lightning import LightningModule, Trainer, seed_everything
from pytorch_lightning.callbacks import ModelCheckpoint, ModelSummary
from pytorch_lightning.loggers import WandbLogger
from torch import nn
from torch.nn import functional as F
from torch.nn.utils import spectral_norm
from torch.optim import Adam
from torch.optim.lr_scheduler import *

from torchvision import transforms as T

import wandb
from data.dataset import CIFAR10DataModule
from utils.DiffAugment_pytorch import (
    DiffAugment,
)  # Make use of the official implementation of DiffAugment

from utils.layers import (
    NormalizeInverse,
    ResidualBlockDiscriminator,
    ResidualBlockDiscriminatorHead,
    ResidualBlockGenerator,
)
from utils.loss import R1, HingeGANLossGenerator, HingeGANLossDiscriminator
from utils.visualize import visualize

# %% [markdown]
# ### Basic Hyperparameters
#
# The most important hyperparameter for the data loader is the batch size, which defines how many real images (and thus how many generated fake images) will be fed into the discriminator during training of either the generator or discriminator.
#
# It was found in Brock, Donahue, and Simonyan, “Large Scale GAN Training for High Fidelity Natural Image Synthesis.” that larger batch sizes could improve the overall quality of the GAN output, but would lead to more unstable training.
#
# > We begin by increasing the batch size for the baseline model, and immediately find tremendous benefits in doing so. Rows 1-4 of Table 1 show that simply increasing the batch size by a factor of 8 improves the state-of-the-art IS by 46%. We conjecture that this is a result of each batch covering more modes, providing better gradients for both networks. One notable side effect of this scaling is that our models reach better final performance in fewer iterations, but become unstable and undergo complete training collapse.
#
# As a result of their findings, I will try and use as large a batch size as possible, within the limitations of the GPU memory. To increase my batch size further, I can make use of gradient accumulation, which is helpfully implemented in PyTorch Lightning's Trainers, to accumulate the gradients from backprogagation over multiple batches, resulting in an increased effective batch size

# %%
# @title Basic Hyperparameters { run: "auto" }
DATA_DIR = "./data"  # @param {type:"string"}
BATCH_SIZE = 256  # @param {type:"integer"}
NUM_WORKERS = 8  # @param {type:"integer"}

# %% [markdown]
# # Data
#
# ## CIFAR-10
#
# CIFAR-10 is a labelled subset of the 80 million tiny images dataset. It consists of 60000 32x32 color images in 10 classes.
#
# - They are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
#
# There are 6000 images per class. CIFAR-10 splits data into 50000 training images, and 10000 test images. It is a common benchmark dataset, used to evaluate computer vision models. It is also commonly used as a benchmark for GAN training, as GAN training typically takes a long time, and so a smaller dataset like CIFAR with a lower resolution is easier to train, allowing GAN models to be more easily evaluated.

# %% [markdown]
# ## Data Ingestion and Preprocessing
#
# To make the set up of the dataset easier and consistent for multiple experiments, a PyTorch Lightning (PL) Data Module is defined as follows. A `LightningDataModule` is a custom class in PL, which defines a structure for defining a dataset, such that it can be easily loaded by a PL Trainer.
#
# ### Preprocessing
#
# A common preprocessing step when training a GAN is to normalize the dataset images such that they are within the range of -1 to 1. By performing feature scaling, I help the model to converge faster by gradient descent.
#
# ### Augmentation
#
# Data augmentation is common applied in deep learning as a technique for preventing overfitting of a model by randomly applying transformations to images to generate variations of it. In this case, we want to reduce overfitting in the discriminator, as an overfitting discriminator, as found in Karras et al., “Training Generative Adversarial Networks with Limited Data.” can lead to reduce quality of the generated images.
#
# > The distributions overlap initially but keep drifting apart as the discriminator becomes more and more confident, and the point where FID starts to deteriorate is consistent with the loss of sufficient overlap between distributions. This is a strong indication of overfitting, evidenced further by the drop in accuracy measured for a separate validation set. - Section 2, Overfitting in GANs
#
# When performing data augmentation in GAN training, there are some things to take note of:
#
# - Some augmentations are "leaky", meaning that the generator may learn to generate augmented images as it is unable to separate the augmentation from the data distribution.
#
# As a result, I will initially not apply any data augmentation, but will investigate safe data augmentation techniques to apply later on.

# %%
preprocessing = [T.ToTensor(), T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]

# %%
dm = CIFAR10DataModule(
    data_dir=DATA_DIR,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    transforms=preprocessing,
)

# %% [markdown]
# # Building an SNGAN with Projection Discriminator

# %% [markdown]
# ## Generator

# %%
class ResNetGenerator(nn.Module):
    def __init__(
        self,
        latent_dim: int = 128,
        num_filters: int = 256,
        num_classes: int = 10,
        activation: callable = F.relu,
        use_spectral_norm: bool = True,
    ):
        super().__init__()
        self.latent_dim = latent_dim
        self.num_filters = num_filters
        self.num_classes = num_classes
        self.use_spectral_norm = use_spectral_norm
        self.latent = nn.Linear(latent_dim, num_filters * 4 * 4)
        self.blocks = nn.ModuleList(
            [
                ResidualBlockGenerator(
                    in_ch=num_filters,
                    out_ch=num_filters,
                    activation=activation,
                    upsample=True,
                    num_classes=num_classes,
                    use_spectral_norm=use_spectral_norm,
                )
                for _ in range(3)  # Input: 4x4 | -> 8x8 -> 16x16 -> 32x32
            ]
        )
        self.output = [
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Conv2d(num_filters, 3, kernel_size=3, padding=1, stride=1),
            nn.Tanh(),
        ]
        if use_spectral_norm:
            self.output[2] = spectral_norm(self.output[2])

        self.output = nn.Sequential(*self.output)

    def forward(self, x, y):
        h = self.latent(x)
        h = h.view(h.shape[0], self.num_filters, 4, 4)
        for block in self.blocks:
            h = block(h, y)
        output = self.output(h)
        if not self.training:
            output = 255 * (output.clamp(-1, 1) * 0.5 + 0.5)
            output = output.to(torch.uint8)
        return output

# %% [markdown]
# ## Discriminator

# %%
class ResNetDiscriminator(nn.Module):
    def __init__(
        self,
        num_filters: int = 128,
        num_classes: int = 10,
        activation: callable = F.relu,
    ):
        """Implementation inspired by Projection Discriminator: https://github.com/pfnet-research/sngan_projection/blob/master/dis_models/snresnet_32.py

        :param num_filters: [description], defaults to 128
        :type num_filters: int, optional
        :param num_classes: [description], defaults to 10
        :type num_classes: int, optional
        :param activation: [description], defaults to F.relu
        :type activation: callable, optional
        """
        super().__init__()
        self.num_filters = num_filters
        self.num_classes = num_classes
        self.activation = activation
        self.blocks = nn.Sequential(
            ResidualBlockDiscriminatorHead(3, num_filters, activation=activation),
            ResidualBlockDiscriminator(
                num_filters, num_filters, activation=activation, downsample=True
            ),
            ResidualBlockDiscriminator(
                num_filters, num_filters, activation=activation, downsample=False
            ),
            ResidualBlockDiscriminator(
                num_filters, num_filters, activation=activation, downsample=False
            ),
        )
        self.classifier = spectral_norm(nn.Linear(num_filters, 1, bias=False))
        self.embed = spectral_norm(nn.Embedding(num_classes, num_filters))

    def forward(self, x, y):
        h = self.blocks(x)
        h = self.activation(h)
        h = h.mean([2, 3])  # Global Avg Pooling
        out = self.classifier(h)
        out = out + torch.sum(self.embed(y) * h, axis=1, keepdims=True)
        return out

# %% [markdown]
# ## Conditional DCGAN

# %%
class SNGAN(LightningModule):
    def __init__(
        self,
        latent_dim: int = 128,
        num_classes: int = 10,
        g_lr: float = 0.0002,
        d_lr: float = 0.0002,
        adam_betas: Tuple[float, float] = (0.0, 0.999),
        d_steps: int = 1,
        r1_gamma: Optional[float] = 0.2,
        w_init_policy: str = "ortho",
        **kwargs,
    ):
        super().__init__()

        self.latent_dim = latent_dim
        self.num_classes = num_classes
        self.g_lr = g_lr
        self.d_lr = d_lr
        self.betas = adam_betas
        self.d_steps = d_steps  # Number of Discriminator steps per Generator Step
        self.r1_gamma = r1_gamma
        self.w_init_policy = w_init_policy
        self.save_hyperparameters()

        self.G = ResNetGenerator(
            latent_dim=latent_dim,
            num_classes=num_classes,
        )

        self.D = ResNetDiscriminator(num_classes=num_classes)

        if w_init_policy == "normal":
            init_func = self._normal_weights_init
        elif w_init_policy == "ortho":
            init_func = self._ortho_weights_init
        else:
            raise ValueError("Unknown Weight Init Policy")
        self.G.apply(init_func)
        self.D.apply(init_func)

        self.generator_loss = HingeGANLossGenerator()
        self.discriminator_loss = HingeGANLossDiscriminator()
        self.regularization_loss = R1(r1_gamma)

        self.viz_z = torch.randn(64, self.latent_dim)
        self.viz_labels = torch.LongTensor(torch.randint(0, self.num_classes, (64,)))

        self.unnormalize = NormalizeInverse((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

    @staticmethod
    def _normal_weights_init(m):
        if (
            isinstance(m, nn.Linear)
            or isinstance(m, nn.Conv2d)
            or isinstance(m, nn.Embedding)
        ):
            torch.nn.init.normal_(m.weight, 0.0, 0.02)
        elif isinstance(m, nn.BatchNorm2d):
            torch.nn.init.normal_(m.weight, 1.0, 0.02)
            torch.nn.init.zeros_(m.bias)

    @staticmethod
    def _ortho_weights_init(m):
        if (
            isinstance(m, nn.Linear)
            or isinstance(m, nn.Conv2d)
            or isinstance(m, nn.Embedding)
        ):
            torch.nn.init.orthogonal_(m.weight)

    def forward(self, z, labels):
        return self.G(z, labels)

    # Alternating schedule for optimizer steps (i.e.: GANs)
    def optimizer_step(
        self,
        epoch,
        batch_idx,
        optimizer,
        optimizer_idx,
        optimizer_closure,
        on_tpu,
        using_native_amp,
        using_lbfgs,
    ):
        # update discriminator opt every step
        if optimizer_idx == 1:
            optimizer.step(closure=optimizer_closure)

        # update generator opt every 4 steps
        if optimizer_idx == 0:
            if (batch_idx + 1) % self.d_steps == 0:
                optimizer.step(closure=optimizer_closure)
            else:
                # call the closure by itself to run `training_step` + `backward` without an optimizer step
                optimizer_closure()

    def training_step(self, batch, batch_idx, optimizer_idx):
        imgs, labels = batch  # Get real images and corresponding labels

        # Generate Noise Vector z
        z = torch.randn(imgs.shape[0], self.latent_dim)
        z = z.type_as(imgs)  # Ensure z runs on the same device as the images
        self.fake_labels = torch.LongTensor(
            torch.randint(0, self.num_classes, (imgs.shape[0],))
        ).to(self.device)
        # Train Generator
        if optimizer_idx == 0:
            # Generate Images
            self.fakes = self.forward(z, self.fake_labels)

            # Classify Generated Images with Discriminator
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))

            # We want to penalize the Generator if the Discriminator predicts it as fake
            # Hence, set the target as a 1's vector
            g_loss = self.generator_loss(fake_preds)

            self.log(
                "train_gen_loss",
                g_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )  # Log Generator Loss
            tqdm_dict = {
                "g_loss": g_loss,
            }
            output = OrderedDict(
                {"loss": g_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

        # Train Discriminator
        if optimizer_idx == 1:
            # Train on Real Data
            imgs.requires_grad = True
            real_preds = torch.squeeze(self.D(imgs, labels))
            # Train on Generated Images
            self.fakes = self.forward(z, self.fake_labels)
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))
            d_loss = self.discriminator_loss(real_preds, fake_preds)
            if self.r1_gamma is not None:
                d_loss = d_loss + self.regularization_loss(real_preds, imgs)
            self.log(
                "train_discriminator_loss",
                d_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )
            tqdm_dict = {
                "d_loss": d_loss,
            }
            output = OrderedDict(
                {"loss": d_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

    def training_epoch_end(self, outputs):
        # Log Sampled Images
        sample_imgs = self.unnormalize(self.fakes[:64].detach()).cpu()
        sample_labels = self.fake_labels[:64].detach().cpu()
        num_rows = int(np.floor(np.sqrt(len(sample_imgs))))
        fig = visualize(sample_imgs, sample_labels, grid_shape=(num_rows, num_rows))
        self.logger.log_image(key="generated_images", images=[fig])
        plt.close(fig)
        del sample_imgs
        del sample_labels
        del fig
        gc.collect()

    def validation_step(self, batch, batch_idx):
        pass

    def validation_epoch_end(self, outputs):
        sample_imgs = (
            self.forward(self.viz_z.to(self.device), self.viz_labels.to(self.device))
            .cpu()
            .detach()
        )
        fig = visualize(sample_imgs, self.viz_labels.cpu().detach(), grid_shape=(8, 8))
        metrics = torch_fidelity.calculate_metrics(
            input1=torch_fidelity.GenerativeModelModuleWrapper(
                self.G, self.latent_dim, "normal", self.num_classes
            ),
            input1_model_num_samples=10000,
            input2="cifar10-val",
            isc=True,
            fid=True,
            kid=True,
        )
        self.logger.log_image(key="Validation Images", images=[fig])
        plt.close(fig)
        del sample_imgs
        del fig
        gc.collect()
        self.log("FID", metrics["frechet_inception_distance"], prog_bar=True)
        self.log("IS", metrics["inception_score_mean"], prog_bar=True)
        self.log("KID", metrics["kernel_inception_distance_mean"], prog_bar=True)

    def configure_optimizers(self):
        """Define the optimizers and schedulers for PyTorch Lightning

        :return: A tuple of two lists - a list of optimizers and a list of learning rate schedulers
        :rtype: Tuple[List, List]
        """
        opt_G = Adam(
            self.G.parameters(), lr=self.g_lr, betas=self.betas
        )  # optimizer_idx = 0
        opt_D = Adam(
            self.D.parameters(), lr=self.d_lr, betas=self.betas
        )  # optimizer_idx = 1
        return [opt_G, opt_D], []

# %% [markdown]
# ## Trainer

# %%
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
seed_everything(42)
wandb_logger = WandbLogger(
    project="DELE_CA2_GAN",
    log_model="all",
    tags=[
        "R1 Regularization",
        "SNGAN",
        "Hinge Loss",
        "Spectral Normalization",
        "cBN",
    ],
)
model = SNGAN(g_lr=0.0002, d_lr=0.0002, r1_gamma=0.2, d_steps=5)
trainer = Trainer(
    check_val_every_n_epoch=5,
    logger=wandb_logger,
    max_epochs=1000,
    callbacks=[
        ModelSummary(3),
    ],
    gpus=1,
)
# Out:
# Global seed set to 42
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
trainer.fit(model, dm)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: Currently logged in as: tiencheng (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/3ejpzf2k" target="_blank">fancy-flower-96</a></strong> to <a href="https://wandb.ai/tiencheng/DELE_CA2_GAN" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#    | Name                | Type                           | Params
# ------------------------------------------------------------------------
# 0  | G                   | ResNetGenerator                | 5.5 M
# 1  | G.latent            | Linear                         | 528 K
# 2  | G.blocks            | ModuleList                     | 4.9 M
# 3  | G.blocks.0          | ResidualBlockGenerator         | 1.6 M
# 4  | G.blocks.1          | ResidualBlockGenerator         | 1.6 M
# 5  | G.blocks.2          | ResidualBlockGenerator         | 1.6 M
# 6  | G.output            | Sequential                     | 7.4 K
# 7  | G.output.0          | BatchNorm2d                    | 512
# 8  | G.output.1          | ReLU                           | 0
# 9  | G.output.2          | Conv2d                         | 6.9 K
# 10 | G.output.3          | Tanh                           | 0
# 11 | D                   | ResNetDiscriminator            | 1.1 M
# 12 | D.blocks            | Sequential                     | 1.1 M
# 13 | D.blocks.0          | ResidualBlockDiscriminatorHead | 151 K
# 14 | D.blocks.1          | ResidualBlockDiscriminator     | 311 K
# 15 | D.blocks.2          | ResidualBlockDiscriminator     | 311 K
# 16 | D.blocks.3          | ResidualBlockDiscriminator     | 311 K
# 17 | D.classifier        | Linear                         | 128
# 18 | D.embed             | Embedding                      | 1.3 K
# 19 | generator_loss      | HingeGANLossGenerator          | 0
# 20 | discriminator_loss  | HingeGANLossDiscriminator      | 0
# 21 | regularization_loss | R1                             | 0
# 22 | unnormalize         | NormalizeInverse               | 0
# ------------------------------------------------------------------------
# 6.5 M     Trainable params
# 0         Non-trainable params
# 6.5 M     Total params
# 26.178    Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
#   0%|          | 0.00/91.2M [00:00<?, ?B/s]
# Extracting features from input1
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
# Processing samples:   1%|          | 64/10000 [00:00<00:26, 372.16samples/s]
# Processing samples:   1%|▏         | 128/10000 [00:00<00:25, 381.91samples/s]
# Processing samples:   2%|▏         | 192/10000 [00:00<00:25, 384.20samples/s]
# Processing samples:   3%|▎         | 256/10000 [00:00<00:25, 385.83samples/s]
# Processing samples:   3%|▎         | 320/10000 [00:00<00:24, 387.20samples/s]
# Processing samples:   4%|▍         | 384/10000 [00:00<00:24, 388.07samples/s]
# Processing samples:   4%|▍         | 448/10000 [00:01<00:24, 388.10samples/s]
# Processing samples:   5%|▌         | 512/10000 [00:01<00:24, 388.52samples/s]
# Processing samples:   6%|▌         | 576/10000 [00:01<00:24, 388.73samples/s]
# Processing samples:   6%|▋         | 640/10000 [00:01<00:24, 388.89samples/s]
# Processing samples:   7%|▋         | 704/10000 [00:01<00:23, 389.42samples/s]
# Processing samples:   8%|▊         | 768/10000 [00:01<00:23, 388.90samples/s]
# Processing samples:   8%|▊         | 832/10000 [00:02<00:23, 389.47samples/s]
# Processing samples:   9%|▉         | 896/10000 [00:02<00:23, 389.17samples/s]
# Processing samples:  10%|▉         | 960/10000 [00:02<00:23, 388.18samples/s]
# Processing samples:  10%|█         | 1024/10000 [00:02<00:23, 388.25samples/s]
# Processing samples:  11%|█         | 1088/10000 [00:02<00:22, 387.84samples/s]
# Processing samples:  12%|█▏        | 1152/10000 [00:02<00:22, 388.14samples/s]
# Processing samples:  12%|█▏        | 1216/10000 [00:03<00:22, 387.93samples/s]
# Processing samples:  13%|█▎        | 1280/10000 [00:03<00:22, 387.94samples/s]
# Processing samples:  13%|█▎        | 1344/10000 [00:03<00:22, 388.41samples/s]
# Processing samples:  14%|█▍        | 1408/10000 [00:03<00:22, 388.18samples/s]
# Processing samples:  15%|█▍        | 1472/10000 [00:03<00:21, 388.13samples/s]
# Processing samples:  15%|█▌        | 1536/10000 [00:03<00:21, 388.28samples/s]
# Processing samples:  16%|█▌        | 1600/10000 [00:04<00:21, 388.57samples/s]
# Processing samples:  17%|█▋        | 1664/10000 [00:04<00:21, 388.99samples/s]
# Processing samples:  17%|█▋        | 1728/10000 [00:04<00:21, 389.37samples/s]
# Processing samples:  88%|████████▊ | 8832/10000 [00:22<00:03, 387.69samples/s]
# Processing samples:  89%|████████▉ | 8896/10000 [00:22<00:02, 388.26samples/s]
# Processing samples:  90%|████████▉ | 8960/10000 [00:23<00:02, 389.16samples/s]
# Processing samples:  90%|█████████ | 9024/10000 [00:23<00:02, 389.00samples/s]
# Processing samples:  91%|█████████ | 9088/10000 [00:23<00:02, 388.95samples/s]
# Processing samples:  92%|█████████▏| 9152/10000 [00:23<00:02, 388.61samples/s]
# Processing samples:  92%|█████████▏| 9216/10000 [00:23<00:02, 388.45samples/s]
# Processing samples:  93%|█████████▎| 9280/10000 [00:23<00:01, 388.54samples/s]
# Processing samples:  93%|█████████▎| 9344/10000 [00:24<00:01, 388.94samples/s]
# Processing samples:  94%|█████████▍| 9408/10000 [00:24<00:01, 389.01samples/s]
# Processing samples:  95%|█████████▍| 9472/10000 [00:24<00:01, 389.02samples/s]
# Processing samples:  95%|█████████▌| 9536/10000 [00:24<00:01, 387.54samples/s]
# Processing samples:  96%|█████████▌| 9600/10000 [00:24<00:01, 387.39samples/s]
# Processing samples:  97%|█████████▋| 9664/10000 [00:24<00:00, 386.96samples/s]
# Processing samples:  97%|█████████▋| 9728/10000 [00:25<00:00, 385.99samples/s]
# Processing samples:  98%|█████████▊| 9792/10000 [00:25<00:00, 387.32samples/s]
# Processing samples:  99%|█████████▊| 9856/10000 [00:25<00:00, 387.56samples/s]
# Processing samples:  99%|█████████▉| 9920/10000 [00:25<00:00, 388.03samples/s]
# Processing samples: 100%|█████████▉| 9984/10000 [00:25<00:00, 389.39samples/s]
#                                                                               Processing samples
# Extracting features from input2
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.cache/torch/fidelity_datasets/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /root/.cache/torch/fidelity_datasets/cifar-10-python.tar.gz to /root/.cache/torch/fidelity_datasets
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
# Processing samples:   1%|          | 64/10000 [00:00<00:48, 205.24samples/s]
# Processing samples:   1%|▏         | 128/10000 [00:00<00:32, 308.13samples/s]
# Processing samples:   2%|▏         | 192/10000 [00:00<00:26, 367.88samples/s]
# Processing samples:   3%|▎         | 256/10000 [00:00<00:24, 405.08samples/s]
# Processing samples:   3%|▎         | 320/10000 [00:00<00:22, 429.79samples/s]
# Processing samples:   4%|▍         | 384/10000 [00:00<00:21, 445.49samples/s]
# Processing samples:   4%|▍         | 448/10000 [00:01<00:20, 456.12samples/s]
# Processing samples:   5%|▌         | 512/10000 [00:01<00:20, 464.13samples/s]
# Processing samples:   6%|▌         | 576/10000 [00:01<00:20, 469.13samples/s]
# Processing samples:   6%|▋         | 640/10000 [00:01<00:19, 472.09samples/s]
# Processing samples:   7%|▋         | 704/10000 [00:01<00:19, 475.20samples/s]
# Processing samples:   8%|▊         | 768/10000 [00:01<00:19, 477.85samples/s]
# Processing samples:   8%|▊         | 832/10000 [00:01<00:19, 479.08samples/s]
# Processing samples:   9%|▉         | 896/10000 [00:02<00:18, 479.81samples/s]
# Processing samples:  10%|▉         | 960/10000 [00:02<00:18, 480.59samples/s]
# Processing samples:  10%|█         | 1024/10000 [00:02<00:18, 480.65samples/s]
# Processing samples:  81%|████████▏ | 8128/10000 [00:17<00:03, 478.75samples/s]
# Processing samples:  82%|████████▏ | 8192/10000 [00:17<00:03, 478.93samples/s]
# Processing samples:  83%|████████▎ | 8256/10000 [00:17<00:03, 479.65samples/s]
# Processing samples:  83%|████████▎ | 8320/10000 [00:17<00:03, 480.36samples/s]
# Processing samples:  84%|████████▍ | 8384/10000 [00:17<00:03, 480.32samples/s]
# Processing samples:  84%|████████▍ | 8448/10000 [00:17<00:03, 481.29samples/s]
# Processing samples:  85%|████████▌ | 8512/10000 [00:17<00:03, 481.34samples/s]
# Processing samples:  86%|████████▌ | 8576/10000 [00:18<00:02, 480.64samples/s]
# Processing samples:  86%|████████▋ | 8640/10000 [00:18<00:02, 481.16samples/s]
# Processing samples:  87%|████████▋ | 8704/10000 [00:18<00:02, 480.56samples/s]
# Processing samples:  88%|████████▊ | 8768/10000 [00:18<00:02, 481.19samples/s]
# Processing samples:  88%|████████▊ | 8832/10000 [00:18<00:02, 481.82samples/s]
# Processing samples:  89%|████████▉ | 8896/10000 [00:18<00:02, 481.33samples/s]
# Processing samples:  90%|████████▉ | 8960/10000 [00:18<00:02, 477.09samples/s]
# Processing samples:  90%|█████████ | 9024/10000 [00:18<00:02, 476.93samples/s]
# Processing samples:  91%|█████████ | 9088/10000 [00:19<00:01, 478.46samples/s]
# Processing samples:  92%|█████████▏| 9152/10000 [00:19<00:01, 479.24samples/s]
# Processing samples:  92%|█████████▏| 9216/10000 [00:19<00:01, 478.74samples/s]
# Processing samples:  93%|█████████▎| 9280/10000 [00:19<00:01, 480.18samples/s]
# Processing samples:  93%|█████████▎| 9344/10000 [00:19<00:01, 480.80samples/s]
# Processing samples:  94%|█████████▍| 9408/10000 [00:19<00:01, 481.31samples/s]
# Processing samples:  95%|█████████▍| 9472/10000 [00:19<00:01, 480.89samples/s]
# Processing samples:  95%|█████████▌| 9536/10000 [00:20<00:00, 480.71samples/s]
# Processing samples:  96%|█████████▌| 9600/10000 [00:20<00:00, 480.84samples/s]
# Processing samples:  97%|█████████▋| 9664/10000 [00:20<00:00, 481.29samples/s]
# Processing samples:  97%|█████████▋| 9728/10000 [00:20<00:00, 481.16samples/s]
# Processing samples:  98%|█████████▊| 9792/10000 [00:20<00:00, 480.79samples/s]
# Processing samples:  99%|█████████▊| 9856/10000 [00:20<00:00, 481.35samples/s]
# Processing samples:  99%|█████████▉| 9920/10000 [00:20<00:00, 481.22samples/s]
# Processing samples: 100%|█████████▉| 9984/10000 [00:20<00:00, 479.20samples/s]
#                                                                               Processing samples
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Inception Score: 2.2382918652933035 ± 0.04541541928562418
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 282.3098824235799
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:12,  8.24subsets/s]
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:12,  7.80subsets/s]
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:12,  7.86subsets/s]
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:12,  7.74subsets/s]
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:12,  7.77subsets/s]
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:12,  7.47subsets/s]
# Kernel Inception Distance:   7%|▋         | 7/100 [00:00<00:12,  7.65subsets/s]
# Kernel Inception Distance:   8%|▊         | 8/100 [00:01<00:11,  7.83subsets/s]
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:11,  7.92subsets/s]
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:11,  7.99subsets/s]
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:10,  8.11subsets/s]
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:10,  8.22subsets/s]
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:01<00:10,  8.31subsets/s]
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:01<00:10,  8.23subsets/s]
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:01<00:10,  8.06subsets/s]
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:02<00:10,  8.14subsets/s]
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:10,  8.07subsets/s]
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:10,  8.12subsets/s]
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:09,  8.15subsets/s]
# Kernel Inception Distance:  20%|██        | 20/100 [00:02<00:09,  8.14subsets/s]
# Kernel Inception Distance:  21%|██        | 21/100 [00:02<00:09,  8.09subsets/s]
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:02<00:09,  7.83subsets/s]
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:02<00:10,  7.38subsets/s]
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:03<00:09,  7.60subsets/s]
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:03<00:09,  7.76subsets/s]
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:09,  7.85subsets/s]
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:03<00:09,  7.94subsets/s]
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:03<00:08,  8.10subsets/s]
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:03<00:08,  8.22subsets/s]
# Kernel Inception Distance:  30%|███       | 30/100 [00:03<00:08,  8.18subsets/s]
# Kernel Inception Distance:  31%|███       | 31/100 [00:03<00:08,  7.85subsets/s]
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:04<00:08,  7.82subsets/s]
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:04<00:08,  7.82subsets/s]
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:04<00:08,  7.90subsets/s]
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:04<00:08,  7.97subsets/s]
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:04<00:07,  8.09subsets/s]
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:04<00:07,  8.12subsets/s]
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:04<00:07,  8.10subsets/s]
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:04<00:07,  7.98subsets/s]
# Kernel Inception Distance:  40%|████      | 40/100 [00:05<00:07,  8.05subsets/s]
# Kernel Inception Distance:  41%|████      | 41/100 [00:05<00:07,  8.00subsets/s]
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:05<00:07,  7.84subsets/s]
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:05<00:07,  7.91subsets/s]
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:05<00:06,  8.01subsets/s]
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:05<00:06,  8.06subsets/s]
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:05<00:06,  8.12subsets/s]
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:05<00:06,  7.87subsets/s]
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:06<00:06,  7.83subsets/s]
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:06<00:06,  7.89subsets/s]
# Kernel Inception Distance:  50%|█████     | 50/100 [00:06<00:06,  7.99subsets/s]
# Kernel Inception Distance:  51%|█████     | 51/100 [00:06<00:06,  8.13subsets/s]
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:06<00:05,  8.22subsets/s]
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:06<00:05,  8.25subsets/s]
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:06<00:05,  8.21subsets/s]
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:06<00:05,  8.08subsets/s]
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:07<00:05,  8.18subsets/s]
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:07<00:05,  7.96subsets/s]
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:07<00:05,  7.76subsets/s]
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:07<00:05,  7.91subsets/s]
# Kernel Inception Distance:  60%|██████    | 60/100 [00:07<00:05,  8.00subsets/s]
# Kernel Inception Distance:  61%|██████    | 61/100 [00:07<00:04,  8.12subsets/s]
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:07<00:04,  8.10subsets/s]
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:07<00:04,  8.18subsets/s]
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:08<00:04,  7.96subsets/s]
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:08<00:04,  7.90subsets/s]
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:08<00:04,  7.91subsets/s]
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:08<00:04,  8.04subsets/s]
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:08<00:03,  8.16subsets/s]
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:08<00:03,  8.17subsets/s]
# Kernel Inception Distance:  70%|███████   | 70/100 [00:08<00:03,  8.15subsets/s]
# Kernel Inception Distance:  71%|███████   | 71/100 [00:08<00:03,  8.20subsets/s]
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:09<00:03,  8.07subsets/s]
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:09<00:03,  8.00subsets/s]
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:09<00:03,  7.98subsets/s]
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:09<00:03,  8.04subsets/s]
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:09<00:02,  8.09subsets/s]
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:09<00:02,  8.15subsets/s]
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:09<00:02,  8.11subsets/s]
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:09<00:02,  8.10subsets/s]
# Kernel Inception Distance:  80%|████████  | 80/100 [00:10<00:02,  7.90subsets/s]
# Kernel Inception Distance:  81%|████████  | 81/100 [00:10<00:02,  7.78subsets/s]
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:10<00:02,  7.68subsets/s]
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:10<00:02,  7.67subsets/s]
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:10<00:02,  7.83subsets/s]
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:10<00:01,  8.01subsets/s]
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:10<00:01,  7.88subsets/s]
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:10<00:01,  7.97subsets/s]
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:11<00:01,  7.79subsets/s]
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:11<00:01,  7.86subsets/s]
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:11<00:01,  8.00subsets/s]
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:11<00:01,  8.10subsets/s]
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:11<00:00,  8.14subsets/s]
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:11<00:00,  8.14subsets/s]
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:11<00:00,  8.06subsets/s]
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:11<00:00,  8.15subsets/s]
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:12<00:00,  8.14subsets/s]
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:12<00:00,  6.24subsets/s]
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:12<00:00,  6.61subsets/s]
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:12<00:00,  6.91subsets/s]
# Kernel Inception Distance: 100%|██████████| 100/100 [00:12<00:00,  7.04subsets/s]
#                                                                                  Kernel Inception Distance: 0.2672023307532532 ± 0.002729099357375687
# Global seed set to 42
# Training: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/optimization/closure.py:36: LightningDeprecationWarning: One of the returned values {'log', 'progress_bar'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   f"One of the returned values {set(extra.keys())} has a `grad_fn`. We will detach it automatically"
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Validating: 0it [00:00, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Extracting features from input1
#
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
#
# Processing samples:   1%|          | 64/10000 [00:00<00:25, 396.27samples/s]
#
# Processing samples:   1%|▏         | 128/10000 [00:00<00:25, 392.82samples/s]
#
# Processing samples:   2%|▏         | 192/10000 [00:00<00:25, 390.81samples/s]
#
# Processing samples:   3%|▎         | 256/10000 [00:00<00:24, 389.96samples/s]
#
# Processing samples:   3%|▎         | 320/10000 [00:00<00:24, 390.11samples/s]
#
# Processing samples:   4%|▍         | 384/10000 [00:00<00:24, 389.97samples/s]
#
# Processing samples:   4%|▍         | 448/10000 [00:01<00:24, 390.26samples/s]
#
# Processing samples:   5%|▌         | 512/10000 [00:01<00:24, 389.87samples/s]
#
# Processing samples:   6%|▌         | 576/10000 [00:01<00:24, 389.77samples/s]
#
# Processing samples:   6%|▋         | 640/10000 [00:01<00:24, 389.68samples/s]
#
# Processing samples:   7%|▋         | 704/10000 [00:01<00:23, 389.50samples/s]
#
# Processing samples:   8%|▊         | 768/10000 [00:01<00:23, 389.30samples/s]
#
# Processing samples:   8%|▊         | 832/10000 [00:02<00:23, 389.07samples/s]
#
# Processing samples:   9%|▉         | 896/10000 [00:02<00:23, 389.26samples/s]
#
# Processing samples:  10%|▉         | 960/10000 [00:02<00:23, 389.36samples/s]
#
# Processing samples:  10%|█         | 1024/10000 [00:02<00:23, 388.75samples/s]
#
# Processing samples:  11%|█         | 1088/10000 [00:02<00:22, 388.94samples/s]
#
# Processing samples:  12%|█▏        | 1152/10000 [00:02<00:22, 389.17samples/s]
#
# Processing samples:  12%|█▏        | 1216/10000 [00:03<00:22, 389.32samples/s]
#
# Processing samples:  13%|█▎        | 1280/10000 [00:03<00:22, 389.47samples/s]
#
# Processing samples:  13%|█▎        | 1344/10000 [00:03<00:22, 388.82samples/s]
#
# Processing samples:  14%|█▍        | 1408/10000 [00:03<00:22, 388.82samples/s]
#
# Processing samples:  15%|█▍        | 1472/10000 [00:03<00:21, 388.73samples/s]
#
# Processing samples:  15%|█▌        | 1536/10000 [00:03<00:21, 389.07samples/s]
#
# Processing samples:  16%|█▌        | 1600/10000 [00:04<00:21, 388.73samples/s]
#
# Processing samples:  17%|█▋        | 1664/10000 [00:04<00:21, 388.65samples/s]
#
# Processing samples:  17%|█▋        | 1728/10000 [00:04<00:21, 388.48samples/s]
#
# Processing samples:  18%|█▊        | 1792/10000 [00:04<00:21, 388.85samples/s]
#
# Processing samples:  19%|█▊        | 1856/10000 [00:04<00:20, 388.60samples/s]
#
# Processing samples:  19%|█▉        | 1920/10000 [00:04<00:20, 387.85samples/s]
#
# Processing samples:  20%|█▉        | 1984/10000 [00:05<00:20, 388.09samples/s]
#
# Processing samples:  20%|██        | 2048/10000 [00:05<00:20, 388.45samples/s]
#
# Processing samples:  21%|██        | 2112/10000 [00:05<00:20, 388.94samples/s]
#
# Processing samples:  22%|██▏       | 2176/10000 [00:05<00:20, 388.29samples/s]
#
# Processing samples:  22%|██▏       | 2240/10000 [00:05<00:19, 388.71samples/s]
#
# Processing samples:  23%|██▎       | 2304/10000 [00:05<00:19, 389.21samples/s]
#
# Processing samples:  24%|██▎       | 2368/10000 [00:06<00:19, 389.07samples/s]
#
#
# Processing samples:  67%|██████▋   | 6720/10000 [00:17<00:08, 390.37samples/s]
#
# Processing samples:  68%|██████▊   | 6784/10000 [00:17<00:08, 389.96samples/s]
#
# Processing samples:  68%|██████▊   | 6848/10000 [00:17<00:08, 390.04samples/s]
#
# Processing samples:  69%|██████▉   | 6912/10000 [00:17<00:07, 390.26samples/s]
#
# Processing samples:  70%|██████▉   | 6976/10000 [00:17<00:07, 390.31samples/s]
#
# Processing samples:  70%|███████   | 7040/10000 [00:18<00:07, 390.01samples/s]
#
# Processing samples:  71%|███████   | 7104/10000 [00:18<00:07, 388.93samples/s]
#
# Processing samples:  72%|███████▏  | 7168/10000 [00:18<00:07, 389.13samples/s]
#
# Processing samples:  72%|███████▏  | 7232/10000 [00:18<00:07, 389.18samples/s]
#
# Processing samples:  73%|███████▎  | 7296/10000 [00:18<00:06, 389.24samples/s]
#
# Processing samples:  74%|███████▎  | 7360/10000 [00:18<00:06, 389.17samples/s]
#
# Processing samples:  74%|███████▍  | 7424/10000 [00:19<00:06, 389.83samples/s]
#
# Processing samples:  75%|███████▍  | 7488/10000 [00:19<00:06, 390.02samples/s]
#
# Processing samples:  76%|███████▌  | 7552/10000 [00:19<00:06, 389.82samples/s]
#
# Processing samples:  76%|███████▌  | 7616/10000 [00:19<00:06, 390.08samples/s]
#
# Processing samples:  77%|███████▋  | 7680/10000 [00:19<00:05, 388.79samples/s]
#
# Processing samples:  77%|███████▋  | 7744/10000 [00:19<00:05, 389.45samples/s]
#
# Processing samples:  78%|███████▊  | 7808/10000 [00:20<00:05, 389.51samples/s]
#
# Processing samples:  79%|███████▊  | 7872/10000 [00:20<00:05, 389.34samples/s]
#
# Processing samples:  79%|███████▉  | 7936/10000 [00:20<00:05, 389.20samples/s]
#
# Processing samples:  80%|████████  | 8000/10000 [00:20<00:05, 389.21samples/s]
#
# Processing samples:  81%|████████  | 8064/10000 [00:20<00:04, 388.99samples/s]
#
# Processing samples:  81%|████████▏ | 8128/10000 [00:20<00:04, 388.84samples/s]
#
# Processing samples:  82%|████████▏ | 8192/10000 [00:21<00:04, 389.22samples/s]
#
# Processing samples:  83%|████████▎ | 8256/10000 [00:21<00:04, 389.58samples/s]
#
# Processing samples:  83%|████████▎ | 8320/10000 [00:21<00:04, 390.19samples/s]
#
# Processing samples:  84%|████████▍ | 8384/10000 [00:21<00:04, 390.06samples/s]
#
# Processing samples:  84%|████████▍ | 8448/10000 [00:21<00:03, 389.30samples/s]
#
# Processing samples:  85%|████████▌ | 8512/10000 [00:21<00:03, 388.61samples/s]
#
# Processing samples:  86%|████████▌ | 8576/10000 [00:22<00:03, 387.12samples/s]
#
# Processing samples:  86%|████████▋ | 8640/10000 [00:22<00:03, 386.77samples/s]
#
# Processing samples:  87%|████████▋ | 8704/10000 [00:22<00:03, 386.64samples/s]
#
# Processing samples:  88%|████████▊ | 8768/10000 [00:22<00:03, 387.37samples/s]
#
# Processing samples:  88%|████████▊ | 8832/10000 [00:22<00:03, 388.57samples/s]
#
# Processing samples:  89%|████████▉ | 8896/10000 [00:22<00:02, 389.24samples/s]
#
# Processing samples:  90%|████████▉ | 8960/10000 [00:23<00:02, 389.46samples/s]
#
# Processing samples:  90%|█████████ | 9024/10000 [00:23<00:02, 388.77samples/s]
#
# Processing samples:  91%|█████████ | 9088/10000 [00:23<00:02, 388.98samples/s]
#
# Processing samples:  92%|█████████▏| 9152/10000 [00:23<00:02, 389.53samples/s]
#
# Processing samples:  92%|█████████▏| 9216/10000 [00:23<00:02, 389.28samples/s]
#
# Processing samples:  93%|█████████▎| 9280/10000 [00:23<00:01, 389.15samples/s]
#
# Processing samples:  93%|█████████▎| 9344/10000 [00:23<00:01, 389.09samples/s]
#
# Processing samples:  94%|█████████▍| 9408/10000 [00:24<00:01, 389.83samples/s]
#
# Processing samples:  95%|█████████▍| 9472/10000 [00:24<00:01, 389.20samples/s]
#
# Processing samples:  95%|█████████▌| 9536/10000 [00:24<00:01, 389.68samples/s]
#
# Processing samples:  96%|█████████▌| 9600/10000 [00:24<00:01, 388.96samples/s]
#
# Processing samples:  97%|█████████▋| 9664/10000 [00:24<00:00, 388.38samples/s]
#
# Processing samples:  97%|█████████▋| 9728/10000 [00:24<00:00, 387.98samples/s]
#
# Processing samples:  98%|█████████▊| 9792/10000 [00:25<00:00, 388.16samples/s]
#
# Processing samples:  99%|█████████▊| 9856/10000 [00:25<00:00, 388.55samples/s]
#
# Processing samples:  99%|█████████▉| 9920/10000 [00:25<00:00, 387.96samples/s]
#
# Processing samples: 100%|█████████▉| 9984/10000 [00:25<00:00, 388.63samples/s]
#
#                                                                               Processing samples
# Extracting features from input2
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Inception Score: 7.331718700078278 ± 0.15436871434420826
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 25.4419984541355
#
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
#
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:15,  6.46subsets/s]
#
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:14,  6.54subsets/s]
#
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:14,  6.68subsets/s]
#
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:14,  6.75subsets/s]
#
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:14,  6.39subsets/s]
#
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:14,  6.27subsets/s]
#
# Kernel Inception Distance:   7%|▋         | 7/100 [00:01<00:13,  6.65subsets/s]
#
# Kernel Inception Distance:   8%|▊         | 8/100 [00:01<00:14,  6.55subsets/s]
#
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:13,  6.53subsets/s]
#
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:13,  6.74subsets/s]
#
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:13,  6.42subsets/s]
#
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:13,  6.36subsets/s]
#
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:02<00:13,  6.32subsets/s]
#
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:02<00:12,  6.68subsets/s]
#
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:02<00:12,  6.70subsets/s]
#
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:02<00:12,  6.80subsets/s]
#
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:12,  6.61subsets/s]
#
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:12,  6.57subsets/s]
#
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:12,  6.27subsets/s]
#
# Kernel Inception Distance:  20%|██        | 20/100 [00:03<00:12,  6.36subsets/s]
#
# Kernel Inception Distance:  21%|██        | 21/100 [00:03<00:12,  6.55subsets/s]
#
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:03<00:11,  6.76subsets/s]
#
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:03<00:11,  6.63subsets/s]
#
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:03<00:11,  6.70subsets/s]
#
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:03<00:11,  6.58subsets/s]
#
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:10,  6.92subsets/s]
#
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:04<00:10,  7.10subsets/s]
#
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:04<00:10,  7.03subsets/s]
#
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:04<00:10,  7.06subsets/s]
#
# Kernel Inception Distance:  30%|███       | 30/100 [00:04<00:10,  6.96subsets/s]
#
# Kernel Inception Distance:  31%|███       | 31/100 [00:04<00:09,  6.93subsets/s]
#
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:04<00:09,  6.86subsets/s]
#
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:04<00:09,  6.75subsets/s]
#
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:05<00:09,  7.02subsets/s]
#
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:05<00:09,  7.13subsets/s]
#
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:05<00:09,  6.77subsets/s]
#
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:05<00:09,  6.58subsets/s]
#
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:05<00:09,  6.55subsets/s]
#
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:05<00:09,  6.60subsets/s]
#
# Kernel Inception Distance:  40%|████      | 40/100 [00:05<00:08,  6.80subsets/s]
#
# Kernel Inception Distance:  41%|████      | 41/100 [00:06<00:08,  6.75subsets/s]
#
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:06<00:08,  7.07subsets/s]
#
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:06<00:08,  6.94subsets/s]
#
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:06<00:07,  7.00subsets/s]
#
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:06<00:07,  6.89subsets/s]
#
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:06<00:07,  6.76subsets/s]
#
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:06<00:07,  6.96subsets/s]
#
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:07<00:07,  6.85subsets/s]
#
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:07<00:07,  6.97subsets/s]
#
# Kernel Inception Distance:  50%|█████     | 50/100 [00:07<00:07,  6.78subsets/s]
#
# Kernel Inception Distance:  51%|█████     | 51/100 [00:07<00:06,  7.06subsets/s]
#
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:07<00:06,  6.90subsets/s]
#
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:07<00:06,  6.87subsets/s]
#
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:08<00:06,  6.73subsets/s]
#
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:08<00:06,  6.69subsets/s]
#
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:08<00:06,  6.54subsets/s]
#
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:08<00:06,  6.76subsets/s]
#
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:08<00:06,  6.60subsets/s]
#
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:08<00:06,  6.71subsets/s]
#
# Kernel Inception Distance:  60%|██████    | 60/100 [00:08<00:05,  7.05subsets/s]
#
# Kernel Inception Distance:  61%|██████    | 61/100 [00:09<00:05,  6.89subsets/s]
#
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:09<00:05,  6.88subsets/s]
#
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:09<00:05,  6.59subsets/s]
#
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:09<00:05,  6.38subsets/s]
#
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:09<00:05,  6.26subsets/s]
#
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:09<00:05,  6.26subsets/s]
#
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:10<00:05,  6.49subsets/s]
#
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:10<00:04,  6.86subsets/s]
#
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:10<00:04,  6.65subsets/s]
#
# Kernel Inception Distance:  70%|███████   | 70/100 [00:10<00:04,  6.78subsets/s]
#
# Kernel Inception Distance:  71%|███████   | 71/100 [00:10<00:04,  6.65subsets/s]
#
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:10<00:04,  6.79subsets/s]
#
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:10<00:03,  7.10subsets/s]
#
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:11<00:03,  6.57subsets/s]
#
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:11<00:03,  6.80subsets/s]
#
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:11<00:03,  6.78subsets/s]
#
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:11<00:03,  6.90subsets/s]
#
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:11<00:03,  6.74subsets/s]
#
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:11<00:03,  6.82subsets/s]
#
# Kernel Inception Distance:  80%|████████  | 80/100 [00:11<00:02,  6.77subsets/s]
#
# Kernel Inception Distance:  81%|████████  | 81/100 [00:12<00:02,  6.46subsets/s]
#
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:12<00:02,  6.72subsets/s]
#
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:12<00:02,  6.72subsets/s]
#
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:12<00:02,  6.59subsets/s]
#
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:12<00:02,  6.77subsets/s]
#
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:12<00:02,  6.88subsets/s]
#
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:12<00:01,  6.68subsets/s]
#
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:13<00:01,  6.32subsets/s]
#
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:13<00:01,  6.36subsets/s]
#
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:13<00:01,  6.51subsets/s]
#
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:13<00:01,  6.90subsets/s]
#
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:13<00:01,  6.79subsets/s]
#
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:13<00:01,  6.53subsets/s]
#
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:14<00:00,  6.59subsets/s]
#
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:14<00:00,  6.51subsets/s]
#
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:14<00:00,  6.73subsets/s]
#
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:14<00:00,  6.75subsets/s]
#
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:14<00:00,  7.09subsets/s]
#
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:14<00:00,  6.96subsets/s]
#
# Kernel Inception Distance: 100%|██████████| 100/100 [00:14<00:00,  6.80subsets/s]
#
#                                                                                  Kernel Inception Distance: 0.01402596969219223 ± 0.0011062311090385395
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:688: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 284... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 2303.44MB of 2303.44MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, ma…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>FID</td><td>█▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>IS</td><td>▁▃▄▅▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>KID</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_discriminator_loss</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>train_gen_loss</td><td>█▄▃▃▂▂▁▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>FID</td><td>25.442</td></tr><tr><td>IS</td><td>7.33172</td></tr><tr><td>KID</td><td>0.01403</td></tr><tr><td>epoch</td><td>147</td></tr><tr><td>train_discriminator_loss</td><td>1.8541</td></tr><tr><td>train_gen_loss</td><td>0.1496</td></tr><tr><td>trainer/global_step</td><td>29007</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 178 media file(s), 29 artifact file(s) and 1 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fancy-flower-96</strong>: <a href="https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/3ejpzf2k" target="_blank">https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/3ejpzf2k</a><br/>
# Find logs at: <code>./wandb/run-20220208_024237-3ejpzf2k/logs</code><br/>
