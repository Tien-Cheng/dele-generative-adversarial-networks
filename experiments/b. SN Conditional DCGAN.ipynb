# %% [markdown]
# <a href="https://colab.research.google.com/github/Tien-Cheng/dele-generative-adversarial-networks/blob/main/SN%20Conditional%20DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Background
#
# ## Problem Statement
#
# My objective for this project is to attempt to create a GAN model that is able to generate realistic images based on information that is provided to it.
#
# Such a task generally falls under two categories:
#
# 1. Conditional Image Generation: Given a class (e.g. a car), generate an image of that class
# 2. Controllable Image Generation: Given some description of features of the image (e.g. The car should be red in color), generate an image with those features
#
# In this project, I hope to tackle the first category (Conditional Image Generation), with the view of eventually tackling the second category if time and resources permit.
#
# So, what would I consider to be a success? Well, I would preferably hope to be able to reliably generate images conditionally that look real enough, based on
#
# - Eye Power 🕵️
# - Metrics like FID (described later in the report)
#
# By real enough, I mean that I hope to get results that are close enough to some of the top GAN models out there, with minimal artifacts.

# %% [markdown]
# # Google Colab Setup
#
# Due to the heavy computational requirements for training a GAN, Google Colab is used as a compute platform. The dataset and utilty functions have been stored on a GitHub repository, and so we need to clone the Git repo. In addition, some additional libraries have to be installed.

# %%
! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp: # Repository Deploy Key
    fp.write("""
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
""")
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:Tien-Cheng/dele-generative-adversarial-networks.git
# %cd /content/dele-generative-adversarial-networks
# Out:
# # github.com:22 SSH-2.0-babeld-00610741
# Cloning into 'dele-generative-adversarial-networks'...
# Warning: Permanently added the RSA host key for IP address '140.82.121.3' to the list of known hosts.
# remote: Enumerating objects: 489, done.
# remote: Counting objects: 100% (489/489), done.
# remote: Compressing objects: 100% (324/324), done.
# remote: Total 489 (delta 301), reused 335 (delta 153), pack-reused 0
# Receiving objects: 100% (489/489), 246.00 KiB | 1015.00 KiB/s, done.
# Resolving deltas: 100% (301/301), done.
# /content/dele-generative-adversarial-networks

# %%
# %%capture
# %pip install -U torch-fidelity wandb torch-summary pytorch-lightning

# %% [markdown]
# # Setup

# %% [markdown]
# ### Imports

# %%
import gc
from collections import OrderedDict
from typing import *

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch_fidelity
from pytorch_lightning import LightningModule, Trainer, seed_everything
from pytorch_lightning.callbacks import ModelCheckpoint, ModelSummary
from pytorch_lightning.loggers import WandbLogger
from torch import nn
from torch.nn import functional as F
from torch.nn.utils import spectral_norm
from torch.optim import Adam
from torch.optim.lr_scheduler import *

from torchvision import transforms as T

import wandb
from data.dataset import CIFAR10DataModule
from utils.DiffAugment_pytorch import (
    DiffAugment,
)  # Make use of the official implementation of DiffAugment
from utils.ema import EMA
from utils.layers import (
    ConditionalBatchNorm2d,
    NormalizeInverse,
    ResidualBlockDiscriminator,
    ResidualBlockDiscriminatorHead,
    ResidualBlockGenerator,
)
from utils.loss import R1
from utils.visualize import visualize

# %% [markdown]
# ### Basic Hyperparameters
#
# The most important hyperparameter for the data loader is the batch size, which defines how many real images (and thus how many generated fake images) will be fed into the discriminator during training of either the generator or discriminator.
#
# It was found in Brock, Donahue, and Simonyan, “Large Scale GAN Training for High Fidelity Natural Image Synthesis.” that larger batch sizes could improve the overall quality of the GAN output, but would lead to more unstable training.
#
# > We begin by increasing the batch size for the baseline model, and immediately find tremendous benefits in doing so. Rows 1-4 of Table 1 show that simply increasing the batch size by a factor of 8 improves the state-of-the-art IS by 46%. We conjecture that this is a result of each batch covering more modes, providing better gradients for both networks. One notable side effect of this scaling is that our models reach better final performance in fewer iterations, but become unstable and undergo complete training collapse.
#
# As a result of their findings, I will try and use as large a batch size as possible, within the limitations of the GPU memory. To increase my batch size further, I can make use of gradient accumulation, which is helpfully implemented in PyTorch Lightning's Trainers, to accumulate the gradients from backprogagation over multiple batches, resulting in an increased effective batch size

# %%
# @title Basic Hyperparameters { run: "auto" }
DATA_DIR = "./data"  # @param {type:"string"}
BATCH_SIZE = 256  # @param {type:"integer"}
NUM_WORKERS = 2  # @param {type:"integer"}

# %% [markdown]
# # Data
#
# ## CIFAR-10
#
# CIFAR-10 is a labelled subset of the 80 million tiny images dataset. It consists of 60000 32x32 color images in 10 classes.
#
# - They are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
#
# There are 6000 images per class. CIFAR-10 splits data into 50000 training images, and 10000 test images. It is a common benchmark dataset, used to evaluate computer vision models. It is also commonly used as a benchmark for GAN training, as GAN training typically takes a long time, and so a smaller dataset like CIFAR with a lower resolution is easier to train, allowing GAN models to be more easily evaluated.

# %% [markdown]
# ## Data Ingestion and Preprocessing
#
# To make the set up of the dataset easier and consistent for multiple experiments, a PyTorch Lightning (PL) Data Module is defined as follows. A `LightningDataModule` is a custom class in PL, which defines a structure for defining a dataset, such that it can be easily loaded by a PL Trainer.
#
# ### Preprocessing
#
# A common preprocessing step when training a GAN is to normalize the dataset images such that they are within the range of -1 to 1. By performing feature scaling, I help the model to converge faster by gradient descent.
#
# ### Augmentation
#
# Data augmentation is common applied in deep learning as a technique for preventing overfitting of a model by randomly applying transformations to images to generate variations of it. In this case, we want to reduce overfitting in the discriminator, as an overfitting discriminator, as found in Karras et al., “Training Generative Adversarial Networks with Limited Data.” can lead to reduce quality of the generated images.
#
# > The distributions overlap initially but keep drifting apart as the discriminator becomes more and more confident, and the point where FID starts to deteriorate is consistent with the loss of sufficient overlap between distributions. This is a strong indication of overfitting, evidenced further by the drop in accuracy measured for a separate validation set. - Section 2, Overfitting in GANs
#
# When performing data augmentation in GAN training, there are some things to take note of:
#
# - Some augmentations are "leaky", meaning that the generator may learn to generate augmented images as it is unable to separate the augmentation from the data distribution.
#
# As a result, I will initially not apply any data augmentation, but will investigate safe data augmentation techniques to apply later on.

# %%
preprocessing = [T.ToTensor(), T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]

# %%
dm = CIFAR10DataModule(
    data_dir=DATA_DIR,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    transforms=preprocessing,
)

# %% [markdown]
# # Building a Conditional DCGAN

# %% [markdown]
# ## Generator

# %%
class Generator(nn.Module):
    def __init__(
        self,
        latent_dim: int = 128,
        embed_dim: int = 256,
        num_filters: int = 64,
        num_classes: int = 10,
    ):
        super().__init__()
        self.latent_dim = latent_dim
        self.num_filters = num_filters  # Base Number of Filters in Generator Blocks
        self.num_classes = num_classes
        self.embed_dim = embed_dim
        self.label_embedding = nn.Embedding(num_classes, embed_dim)
        self.latent = nn.Linear(latent_dim + embed_dim, latent_dim)
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, num_filters * 4, 4, 1, 0, bias=False),
            nn.BatchNorm2d(num_filters * 4),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(num_filters * 4, num_filters * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(num_filters * 2),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d(num_filters * 2, num_filters, 4, 2, 1, bias=False),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d(num_filters, 3, 4, 2, 1, bias=False),
            nn.Tanh(),
        )

    def forward(self, x: torch.Tensor, y: list = None):
        y_embed = self.label_embedding(y)
        y_embed = y_embed / torch.norm(y_embed, p=2, dim=1, keepdim=True)
        conditional_inputs = torch.cat([x, y_embed], dim=1)
        conditional_inputs = self.latent(conditional_inputs)
        conditional_inputs = conditional_inputs.view(
            conditional_inputs.shape[0], self.latent_dim, 1, 1
        )
        fake = self.main(conditional_inputs)
        if not self.training:
            fake = 255 * (fake.clamp(-1, 1) * 0.5 + 0.5)
            fake = fake.to(torch.uint8)
        return fake

# %% [markdown]
# ## Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, num_filters: int = 64, num_classes: int = 10):
        super().__init__()
        self.num_filters = num_filters
        self.num_classes = num_classes
        self.label_embedding = nn.Embedding(num_classes, 32 * 32)
        self.main = nn.Sequential(
            spectral_norm(nn.Conv2d(4, num_filters, 4, 2, 1, bias=False)),
            nn.LeakyReLU(0.2, inplace=True),
            spectral_norm(nn.Conv2d(num_filters, num_filters * 2, 4, 2, 1, bias=False)),
            nn.BatchNorm2d(num_filters * 2),
            nn.LeakyReLU(0.2, inplace=True),
            spectral_norm(
                nn.Conv2d(num_filters * 2, num_filters * 4, 4, 2, 1, bias=False)
            ),
            nn.BatchNorm2d(num_filters * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            spectral_norm(
                nn.Conv2d(num_filters * 4, 1, 4, 1, 0, bias=False)
            ),  # Apply a 4x4 Convolution to a 4x4 input, resulting in a 1x1 output
            nn.Sigmoid(),
        )

    def forward(self, x: torch.Tensor, y: list = None):
        labels = self.label_embedding(y)
        labels = labels / torch.norm(labels, p=2, dim=1, keepdim=True)
        labels = labels.view(labels.shape[0], 1, 32, 32)
        conditional_inputs = torch.cat([x, labels], dim=1)  # Concat as Extra Channel
        return self.main(conditional_inputs)

# %% [markdown]
# ## Conditional DCGAN
# To improve my conditional DCGAN, I introduce some improvements
# ### Label Smoothing
# One of the ways to improve the training of the GAN, as recommended by Goodfellow, “NIPS 2016 Tutorial.” ﻿ is to replace the positive classification target of the discriminator when working with real images (a value of 1, corresponding to a real image), with a smoothed value like 0.9. This prevents the discriminator from being too confident in it's predictions, reducing vulnerability to adversarial examples created by the generator.
# In this case, I set the label smoothing hyperparameter as 0.1.
#
# ### R1 Regularization
# One of the ways to regularize the discriminator is to perform R1 regularization. R1 regularization tries to enforce the Nash Equilibrium (the optimal solution when training a GAN when both the generator and discriminator are no longer able to improve), by penalizing the gradient on real data alone. If the generator performs well (discovering the actual data distribution), we want to ensure that the discriminator does not create a gradient that will cause the generator to create something outside that distribution.
#
# ### Spectral Normalization
# To further stabilize the training of the discriminator network, I attempt to introduce spectral normalization. Spectral normalization is a weight normalization method that attempts to enforce Lipschitz continuity in the network. Lipschitz continuity means that for a given function, the magnitude of its gradient should be at most K for every point.
#
# The actual result of the network having Lipschitz continuity is that it constrains the gradients in the network (by enforcing an upper bound to the gradients). As a result spectral normalization reduces the risk of exploding gradients during training. In addition, spectral normalization controls the variance of the weights in the network, helping to prevent the vanishing gradient problem. (Lin, Sekar, and Fanti, “Why Spectral Normalization Stabilizes GANs.”)

# %%
class ConditionalDCGAN(LightningModule):
    def __init__(
        self,
        latent_dim: int = 128,
        embed_dim: int = 128,
        num_classes: int = 10,
        g_lr: float = 0.0002,
        d_lr: float = 0.0002,
        adam_betas: Tuple[float, float] = (0.0, 0.999),
        d_steps: int = 1,
        **kwargs,
    ):
        super().__init__()

        self.latent_dim = latent_dim
        self.embed_dim = embed_dim
        self.num_classes = num_classes
        self.g_lr = g_lr
        self.d_lr = d_lr
        self.betas = adam_betas
        self.d_steps = d_steps  # Number of Discriminator steps per Generator Step
        self.save_hyperparameters()

        self.G = Generator(
            latent_dim=self.latent_dim,
            embed_dim=self.embed_dim,
            num_classes=num_classes,
        )

        self.D = Discriminator(num_classes=num_classes)

        self.G.apply(self._weights_init)
        self.D.apply(self._weights_init)

        self.adversarial_loss = nn.BCELoss()  # BCE Loss

        self.viz_z = torch.randn(64, self.latent_dim)
        self.viz_labels = torch.LongTensor(torch.randint(0, self.num_classes, (64,)))

        self.unnormalize = NormalizeInverse((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

    @staticmethod
    def _weights_init(m):
        classname = m.__class__.__name__
        if classname.find("Conv") != -1:
            torch.nn.init.normal_(m.weight, 0.0, 0.02)
        elif classname.find("BatchNorm") != -1:
            torch.nn.init.normal_(m.weight, 1.0, 0.02)
            torch.nn.init.zeros_(m.bias)

    def forward(self, z, labels):
        return self.G(z, labels)

    # Alternating schedule for optimizer steps (i.e.: GANs)
    def optimizer_step(
        self,
        epoch,
        batch_idx,
        optimizer,
        optimizer_idx,
        optimizer_closure,
        on_tpu,
        using_native_amp,
        using_lbfgs,
    ):
        # update discriminator opt every step
        if optimizer_idx == 1:
            optimizer.step(closure=optimizer_closure)

        # update generator opt every 4 steps
        if optimizer_idx == 0:
            if (batch_idx + 1) % self.d_steps == 0:
                optimizer.step(closure=optimizer_closure)
            else:
                # call the closure by itself to run `training_step` + `backward` without an optimizer step
                optimizer_closure()

    def training_step(self, batch, batch_idx, optimizer_idx):
        imgs, labels = batch  # Get real images and corresponding labels

        # Generate Noise Vector z
        z = torch.randn(imgs.shape[0], self.latent_dim)
        z = z.type_as(imgs)  # Ensure z runs on the same device as the images
        self.fake_labels = torch.LongTensor(
            torch.randint(0, self.num_classes, (imgs.shape[0],))
        ).to(self.device)
        # Train Generator
        if optimizer_idx == 0:
            # Generate Images
            self.fakes = self.forward(z, self.fake_labels)

            # Classify Generated Images with Discriminator
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))

            # We want to penalize the Generator if the Discriminator predicts it as fake
            # Hence, set the target as a 1's vector
            target = torch.ones(imgs.shape[0]).type_as(imgs)

            g_loss = self.adversarial_loss(fake_preds, target)

            self.log(
                "train_gen_loss",
                g_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )  # Log Generator Loss
            tqdm_dict = {
                "g_loss": g_loss,
            }
            output = OrderedDict(
                {"loss": g_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

        # Train Discriminator
        if optimizer_idx == 1:
            # Train on Real Data
            real_preds = torch.squeeze(self.D(imgs, labels))
            target = torch.ones(imgs.shape[0]).type_as(imgs)
            d_real_loss = self.adversarial_loss(real_preds, target)

            # Train on Generated Images
            self.fakes = self.forward(z, self.fake_labels)
            target = torch.zeros(imgs.shape[0]).type_as(imgs)
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))
            d_fake_loss = self.adversarial_loss(fake_preds, target)
            d_loss = (d_real_loss + d_fake_loss) / 2

            self.log(
                "train_discriminator_loss",
                d_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )
            tqdm_dict = {
                "d_loss": d_loss,
            }
            output = OrderedDict(
                {"loss": d_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

    def training_epoch_end(self, outputs):
        # Log Sampled Images
        sample_imgs = self.unnormalize(self.fakes[:64].detach()).cpu()
        sample_labels = self.fake_labels[:64].detach().cpu()
        num_rows = int(np.floor(np.sqrt(len(sample_imgs))))
        fig = visualize(sample_imgs, sample_labels, grid_shape=(num_rows, num_rows))
        self.logger.log_image(key="generated_images", images=[fig])
        plt.close(fig)
        del sample_imgs
        del sample_labels
        del fig
        gc.collect()

    def validation_step(self, batch, batch_idx):
        pass

    def validation_epoch_end(self, outputs):
        sample_imgs = (
            self.forward(self.viz_z.to(self.device), self.viz_labels.to(self.device))
            .cpu()
            .detach()
        )
        fig = visualize(sample_imgs, self.viz_labels.cpu().detach(), grid_shape=(8, 8))
        metrics = torch_fidelity.calculate_metrics(
            input1=torch_fidelity.GenerativeModelModuleWrapper(
                self.G, self.latent_dim, "normal", self.num_classes
            ),
            input1_model_num_samples=10000,
            input2="cifar10-val",
            isc=True,
            fid=True,
            kid=True,
        )
        self.logger.log_image(key="Validation Images", images=[fig])
        plt.close(fig)
        del sample_imgs
        del fig
        gc.collect()
        self.log("FID", metrics["frechet_inception_distance"], prog_bar=True)
        self.log("IS", metrics["inception_score_mean"], prog_bar=True)
        self.log("KID", metrics["kernel_inception_distance_mean"], prog_bar=True)

    def configure_optimizers(self):
        """Define the optimizers and schedulers for PyTorch Lightning

        :return: A tuple of two lists - a list of optimizers and a list of learning rate schedulers
        :rtype: Tuple[List, List]
        """
        opt_G = Adam(
            self.G.parameters(), lr=self.g_lr, betas=self.betas
        )  # optimizer_idx = 0
        opt_D = Adam(
            self.D.parameters(), lr=self.d_lr, betas=self.betas
        )  # optimizer_idx = 1
        return [opt_G, opt_D], []

# %%
class ConditionalDCGANV2(ConditionalDCGAN):
    def __init__(
        self,
        latent_dim: int = 128,
        embed_dim: int = 128,
        num_classes: int = 10,
        g_lr: float = 0.0002,
        d_lr: float = 0.0002,
        adam_betas: Tuple[float, float] = (0.0, 0.999),
        d_steps: int = 1,
        label_smoothing: float = 0.1,
        r1_gamma: Optional[float] = 0.2,
        **kwargs,
    ):
        super().__init__(
            latent_dim,
            embed_dim,
            num_classes,
            g_lr,
            d_lr,
            adam_betas,
            d_steps,
            **kwargs,
        )
        self.label_smoothing = label_smoothing
        self.r1_gamma = r1_gamma
        self.save_hyperparameters()

        self.regularization_loss = R1(r1_gamma)

    def training_step(self, batch, batch_idx, optimizer_idx):
        imgs, labels = batch  # Get real images and corresponding labels

        # Generate Noise Vector z
        z = torch.randn(imgs.shape[0], self.latent_dim)
        z = z.type_as(imgs)  # Ensure z runs on the same device as the images
        self.fake_labels = torch.LongTensor(
            torch.randint(0, self.num_classes, (imgs.shape[0],))
        ).to(self.device)
        # Train Generator
        if optimizer_idx == 0:
            # Generate Images
            self.fakes = self.forward(z, self.fake_labels)

            # Classify Generated Images with Discriminator
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))

            # We want to penalize the Generator if the Discriminator predicts it as fake
            # Hence, set the target as a 1's vector
            target = torch.ones(imgs.shape[0]).type_as(imgs)

            g_loss = self.adversarial_loss(fake_preds, target)

            self.log(
                "train_gen_loss",
                g_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )  # Log Generator Loss
            tqdm_dict = {
                "g_loss": g_loss,
            }
            output = OrderedDict(
                {"loss": g_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

        # Train Discriminator
        if optimizer_idx == 1:
            # Train on Real Data
            imgs.requires_grad = True
            real_preds = torch.squeeze(self.D(imgs, labels))
            target = torch.ones(imgs.shape[0]).type_as(imgs) - self.label_smoothing
            d_real_loss = self.adversarial_loss(real_preds, target)
            if self.r1_gamma is not None:
                d_real_loss = d_real_loss + self.regularization_loss(real_preds, imgs)
            # Train on Generated Images
            self.fakes = self.forward(z, self.fake_labels)
            target = torch.zeros(imgs.shape[0]).type_as(imgs)
            fake_preds = torch.squeeze(self.D(self.fakes, self.fake_labels))
            d_fake_loss = self.adversarial_loss(fake_preds, target)
            d_loss = (d_real_loss + d_fake_loss) / 2

            self.log(
                "train_discriminator_loss",
                d_loss,
                on_epoch=True,
                on_step=False,
                prog_bar=True,
            )
            tqdm_dict = {
                "d_loss": d_loss,
            }
            output = OrderedDict(
                {"loss": d_loss, "progress_bar": tqdm_dict, "log": tqdm_dict}
            )
            return output

# %% [markdown]
# ## Trainer

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
seed_everything(42)
wandb_logger = WandbLogger(
    project="DELE_CA2_GAN",
    log_model="all",
    tags=[
        "R1 Regularization",
        "Label Smoothing",
        "DCGAN",
        "BCE Loss",
        "Spectral Normalization",
    ],
)
model = ConditionalDCGANV2(
    g_lr=0.0002, d_lr=0.0002, label_smoothing=0.1, r1_gamma=0.2
)
trainer = Trainer(
    check_val_every_n_epoch=5,
    logger=wandb_logger,
    max_epochs=1000,
    callbacks=[
        ModelSummary(3),
    ],
    gpus=1,
)
# Out:
# Global seed set to 42
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
trainer.fit(model, dm)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: Currently logged in as: tiencheng (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/8w856w0y" target="_blank">mild-paper-88</a></strong> to <a href="https://wandb.ai/tiencheng/DELE_CA2_GAN" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#    | Name                | Type             | Params
# ----------------------------------------------------------
# 0  | G                   | Generator        | 1.2 M
# 1  | G.label_embedding   | Embedding        | 1.3 K
# 2  | G.latent            | Linear           | 32.9 K
# 3  | G.main              | Sequential       | 1.2 M
# 4  | G.main.0            | ConvTranspose2d  | 524 K
# 5  | G.main.1            | BatchNorm2d      | 512
# 6  | G.main.2            | ReLU             | 0
# 7  | G.main.3            | ConvTranspose2d  | 524 K
# 8  | G.main.4            | BatchNorm2d      | 256
# 9  | G.main.5            | ReLU             | 0
# 10 | G.main.6            | ConvTranspose2d  | 131 K
# 11 | G.main.7            | BatchNorm2d      | 128
# 12 | G.main.8            | ReLU             | 0
# 13 | G.main.9            | ConvTranspose2d  | 3.1 K
# 14 | G.main.10           | Tanh             | 0
# 15 | D                   | Discriminator    | 674 K
# 16 | D.label_embedding   | Embedding        | 10.2 K
# 17 | D.main              | Sequential       | 664 K
# 18 | D.main.0            | Conv2d           | 4.1 K
# 19 | D.main.1            | LeakyReLU        | 0
# 20 | D.main.2            | Conv2d           | 131 K
# 21 | D.main.3            | BatchNorm2d      | 256
# 22 | D.main.4            | LeakyReLU        | 0
# 23 | D.main.5            | Conv2d           | 524 K
# 24 | D.main.6            | BatchNorm2d      | 512
# 25 | D.main.7            | LeakyReLU        | 0
# 26 | D.main.8            | Dropout2d        | 0
# 27 | D.main.9            | Conv2d           | 4.1 K
# 28 | D.main.10           | Sigmoid          | 0
# 29 | adversarial_loss    | BCELoss          | 0
# 30 | unnormalize         | NormalizeInverse | 0
# 31 | regularization_loss | R1               | 0
# ----------------------------------------------------------
# 1.9 M     Trainable params
# 0         Non-trainable params
# 1.9 M     Total params
# 7.569     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Creating feature extractor "inception-v3-compat" with features ['2048', 'logits_unbiased']
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
#   0%|          | 0.00/91.2M [00:00<?, ?B/s]
# Extracting features from input1
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
# Processing samples:   1%|          | 64/10000 [00:00<00:18, 535.55samples/s]
# Processing samples:   2%|▏         | 192/10000 [00:00<00:13, 706.59samples/s]
# Processing samples:   3%|▎         | 320/10000 [00:00<00:12, 763.23samples/s]
# Processing samples:   4%|▍         | 448/10000 [00:00<00:12, 791.83samples/s]
# Processing samples:   6%|▌         | 576/10000 [00:00<00:11, 808.32samples/s]
# Processing samples:   7%|▋         | 704/10000 [00:00<00:11, 817.17samples/s]
# Processing samples:   8%|▊         | 832/10000 [00:01<00:11, 824.22samples/s]
# Processing samples:  10%|▉         | 960/10000 [00:01<00:10, 826.80samples/s]
# Processing samples:  11%|█         | 1088/10000 [00:01<00:10, 828.63samples/s]
# Processing samples:  12%|█▏        | 1216/10000 [00:01<00:10, 832.38samples/s]
# Processing samples:  13%|█▎        | 1344/10000 [00:01<00:10, 832.83samples/s]
# Processing samples:  15%|█▍        | 1472/10000 [00:01<00:10, 833.17samples/s]
# Processing samples:  16%|█▌        | 1600/10000 [00:01<00:10, 834.77samples/s]
# Processing samples:  17%|█▋        | 1728/10000 [00:02<00:09, 835.77samples/s]
# Processing samples:  19%|█▊        | 1856/10000 [00:02<00:09, 834.85samples/s]
# Processing samples:  20%|█▉        | 1984/10000 [00:02<00:09, 836.27samples/s]
# Processing samples:  21%|██        | 2112/10000 [00:02<00:09, 837.49samples/s]
# Processing samples:  22%|██▏       | 2240/10000 [00:02<00:09, 836.35samples/s]
# Processing samples:  24%|██▎       | 2368/10000 [00:02<00:09, 835.64samples/s]
# Processing samples:  25%|██▍       | 2496/10000 [00:03<00:08, 836.36samples/s]
# Processing samples:  26%|██▌       | 2624/10000 [00:03<00:08, 837.29samples/s]
# Processing samples:  28%|██▊       | 2752/10000 [00:03<00:08, 833.47samples/s]
# Processing samples:  29%|██▉       | 2880/10000 [00:03<00:08, 831.34samples/s]
# Processing samples:  30%|███       | 3008/10000 [00:03<00:08, 831.78samples/s]
# Processing samples:  31%|███▏      | 3136/10000 [00:03<00:08, 831.55samples/s]
# Processing samples:  33%|███▎      | 3264/10000 [00:03<00:08, 831.09samples/s]
# Processing samples:  34%|███▍      | 3392/10000 [00:04<00:07, 832.15samples/s]
# Processing samples:  35%|███▌      | 3520/10000 [00:04<00:07, 833.01samples/s]
# Processing samples:  36%|███▋      | 3648/10000 [00:04<00:07, 830.87samples/s]
# Processing samples:  38%|███▊      | 3776/10000 [00:04<00:07, 831.98samples/s]
# Processing samples:  39%|███▉      | 3904/10000 [00:04<00:07, 833.81samples/s]
# Processing samples:  40%|████      | 4032/10000 [00:04<00:07, 834.20samples/s]
# Processing samples:  42%|████▏     | 4160/10000 [00:05<00:07, 834.17samples/s]
# Processing samples:  43%|████▎     | 4288/10000 [00:05<00:06, 833.96samples/s]
# Processing samples:  44%|████▍     | 4416/10000 [00:05<00:06, 832.27samples/s]
# Processing samples:  45%|████▌     | 4544/10000 [00:05<00:06, 830.76samples/s]
# Processing samples:  47%|████▋     | 4672/10000 [00:05<00:06, 830.70samples/s]
# Processing samples:  48%|████▊     | 4800/10000 [00:05<00:06, 829.69samples/s]
# Processing samples:  49%|████▉     | 4928/10000 [00:05<00:06, 829.07samples/s]
# Processing samples:  51%|█████     | 5056/10000 [00:06<00:05, 827.70samples/s]
# Processing samples:  52%|█████▏    | 5184/10000 [00:06<00:05, 828.98samples/s]
# Processing samples:  53%|█████▎    | 5312/10000 [00:06<00:05, 827.75samples/s]
# Processing samples:  54%|█████▍    | 5440/10000 [00:06<00:05, 827.92samples/s]
# Processing samples:  56%|█████▌    | 5568/10000 [00:06<00:05, 829.18samples/s]
# Processing samples:  57%|█████▋    | 5696/10000 [00:06<00:05, 831.12samples/s]
# Processing samples:  58%|█████▊    | 5824/10000 [00:07<00:05, 832.22samples/s]
# Processing samples:  60%|█████▉    | 5952/10000 [00:07<00:04, 831.59samples/s]
# Processing samples:  61%|██████    | 6080/10000 [00:07<00:04, 833.39samples/s]
# Processing samples:  62%|██████▏   | 6208/10000 [00:07<00:04, 833.86samples/s]
# Processing samples:  63%|██████▎   | 6336/10000 [00:07<00:04, 833.28samples/s]
# Processing samples:  65%|██████▍   | 6464/10000 [00:07<00:04, 833.93samples/s]
# Processing samples:  66%|██████▌   | 6592/10000 [00:07<00:04, 832.69samples/s]
# Processing samples:  67%|██████▋   | 6720/10000 [00:08<00:03, 832.33samples/s]
# Processing samples:  68%|██████▊   | 6848/10000 [00:08<00:03, 831.89samples/s]
# Processing samples:  70%|██████▉   | 6976/10000 [00:08<00:03, 832.24samples/s]
# Processing samples:  71%|███████   | 7104/10000 [00:08<00:03, 832.91samples/s]
# Processing samples:  72%|███████▏  | 7232/10000 [00:08<00:03, 831.92samples/s]
# Processing samples:  74%|███████▎  | 7360/10000 [00:08<00:03, 832.43samples/s]
# Processing samples:  75%|███████▍  | 7488/10000 [00:09<00:03, 831.74samples/s]
# Processing samples:  76%|███████▌  | 7616/10000 [00:09<00:02, 831.06samples/s]
# Processing samples:  77%|███████▋  | 7744/10000 [00:09<00:02, 831.71samples/s]
# Processing samples:  79%|███████▊  | 7872/10000 [00:09<00:02, 832.62samples/s]
# Processing samples:  80%|████████  | 8000/10000 [00:09<00:02, 832.84samples/s]
# Processing samples:  81%|████████▏ | 8128/10000 [00:09<00:02, 833.25samples/s]
# Processing samples:  83%|████████▎ | 8256/10000 [00:09<00:02, 833.03samples/s]
# Processing samples:  84%|████████▍ | 8384/10000 [00:10<00:01, 832.99samples/s]
# Processing samples:  85%|████████▌ | 8512/10000 [00:10<00:01, 833.15samples/s]
# Processing samples:  86%|████████▋ | 8640/10000 [00:10<00:01, 832.63samples/s]
# Processing samples:  88%|████████▊ | 8768/10000 [00:10<00:01, 833.38samples/s]
# Processing samples:  89%|████████▉ | 8896/10000 [00:10<00:01, 834.11samples/s]
# Processing samples:  90%|█████████ | 9024/10000 [00:10<00:01, 831.39samples/s]
# Processing samples:  92%|█████████▏| 9152/10000 [00:11<00:01, 829.94samples/s]
# Processing samples:  93%|█████████▎| 9280/10000 [00:11<00:00, 831.84samples/s]
# Processing samples:  94%|█████████▍| 9408/10000 [00:11<00:00, 832.70samples/s]
# Processing samples:  95%|█████████▌| 9536/10000 [00:11<00:00, 833.40samples/s]
# Processing samples:  97%|█████████▋| 9664/10000 [00:11<00:00, 833.85samples/s]
# Processing samples:  98%|█████████▊| 9792/10000 [00:11<00:00, 833.84samples/s]
# Processing samples:  99%|█████████▉| 9920/10000 [00:11<00:00, 833.70samples/s]
#                                                                               Processing samples
# Extracting features from input2
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.cache/torch/fidelity_datasets/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /root/.cache/torch/fidelity_datasets/cifar-10-python.tar.gz to /root/.cache/torch/fidelity_datasets
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
# Processing samples:   1%|          | 64/10000 [00:00<00:39, 250.70samples/s]
# Processing samples:   2%|▏         | 192/10000 [00:00<00:19, 508.04samples/s]
# Processing samples:   3%|▎         | 320/10000 [00:00<00:15, 636.36samples/s]
# Processing samples:   4%|▍         | 448/10000 [00:00<00:13, 710.19samples/s]
# Processing samples:   6%|▌         | 576/10000 [00:00<00:12, 755.63samples/s]
# Processing samples:   7%|▋         | 704/10000 [00:01<00:11, 785.31samples/s]
# Processing samples:   8%|▊         | 832/10000 [00:01<00:11, 801.58samples/s]
# Processing samples:  10%|▉         | 960/10000 [00:01<00:11, 814.55samples/s]
# Processing samples:  11%|█         | 1088/10000 [00:01<00:10, 824.13samples/s]
# Processing samples:  12%|█▏        | 1216/10000 [00:01<00:10, 831.30samples/s]
# Processing samples:  13%|█▎        | 1344/10000 [00:01<00:10, 834.00samples/s]
# Processing samples:  15%|█▍        | 1472/10000 [00:01<00:10, 836.85samples/s]
# Processing samples:  16%|█▌        | 1600/10000 [00:02<00:10, 839.44samples/s]
# Processing samples:  17%|█▋        | 1728/10000 [00:02<00:09, 841.28samples/s]
# Processing samples:  19%|█▊        | 1856/10000 [00:02<00:09, 842.50samples/s]
# Processing samples:  20%|█▉        | 1984/10000 [00:02<00:09, 842.78samples/s]
# Processing samples:  21%|██        | 2112/10000 [00:02<00:09, 842.79samples/s]
# Processing samples:  22%|██▏       | 2240/10000 [00:02<00:09, 838.41samples/s]
# Processing samples:  24%|██▎       | 2368/10000 [00:03<00:09, 840.32samples/s]
# Processing samples:  25%|██▍       | 2496/10000 [00:03<00:08, 840.88samples/s]
# Processing samples:  26%|██▌       | 2624/10000 [00:03<00:08, 842.13samples/s]
# Processing samples:  28%|██▊       | 2752/10000 [00:03<00:08, 844.40samples/s]
# Processing samples:  29%|██▉       | 2880/10000 [00:03<00:08, 843.98samples/s]
# Processing samples:  30%|███       | 3008/10000 [00:03<00:08, 842.64samples/s]
# Processing samples:  31%|███▏      | 3136/10000 [00:03<00:08, 842.32samples/s]
# Processing samples:  33%|███▎      | 3264/10000 [00:04<00:07, 843.61samples/s]
# Processing samples:  34%|███▍      | 3392/10000 [00:04<00:07, 842.94samples/s]
# Processing samples:  35%|███▌      | 3520/10000 [00:04<00:07, 842.10samples/s]
# Processing samples:  36%|███▋      | 3648/10000 [00:04<00:07, 842.60samples/s]
# Processing samples:  38%|███▊      | 3776/10000 [00:04<00:07, 841.51samples/s]
# Processing samples:  39%|███▉      | 3904/10000 [00:04<00:07, 841.75samples/s]
# Processing samples:  40%|████      | 4032/10000 [00:04<00:07, 843.28samples/s]
# Processing samples:  42%|████▏     | 4160/10000 [00:05<00:06, 843.72samples/s]
# Processing samples:  43%|████▎     | 4288/10000 [00:05<00:06, 843.86samples/s]
# Processing samples:  44%|████▍     | 4416/10000 [00:05<00:06, 845.08samples/s]
# Processing samples:  45%|████▌     | 4544/10000 [00:05<00:06, 845.18samples/s]
# Processing samples:  47%|████▋     | 4672/10000 [00:05<00:06, 845.60samples/s]
# Processing samples:  48%|████▊     | 4800/10000 [00:05<00:06, 844.79samples/s]
# Processing samples:  49%|████▉     | 4928/10000 [00:06<00:05, 845.88samples/s]
# Processing samples:  51%|█████     | 5056/10000 [00:06<00:05, 844.87samples/s]
# Processing samples:  52%|█████▏    | 5184/10000 [00:06<00:05, 844.11samples/s]
# Processing samples:  53%|█████▎    | 5312/10000 [00:06<00:05, 844.31samples/s]
# Processing samples:  54%|█████▍    | 5440/10000 [00:06<00:05, 844.90samples/s]
# Processing samples:  56%|█████▌    | 5568/10000 [00:06<00:05, 843.80samples/s]
# Processing samples:  57%|█████▋    | 5696/10000 [00:06<00:05, 842.13samples/s]
# Processing samples:  58%|█████▊    | 5824/10000 [00:07<00:04, 842.15samples/s]
# Processing samples:  60%|█████▉    | 5952/10000 [00:07<00:04, 843.71samples/s]
# Processing samples:  61%|██████    | 6080/10000 [00:07<00:04, 844.31samples/s]
# Processing samples:  62%|██████▏   | 6208/10000 [00:07<00:04, 844.45samples/s]
# Processing samples:  63%|██████▎   | 6336/10000 [00:07<00:04, 846.27samples/s]
# Processing samples:  65%|██████▍   | 6464/10000 [00:07<00:04, 845.29samples/s]
# Processing samples:  66%|██████▌   | 6592/10000 [00:08<00:04, 845.21samples/s]
# Processing samples:  67%|██████▋   | 6720/10000 [00:08<00:03, 844.69samples/s]
# Processing samples:  68%|██████▊   | 6848/10000 [00:08<00:03, 844.78samples/s]
# Processing samples:  70%|██████▉   | 6976/10000 [00:08<00:03, 844.89samples/s]
# Processing samples:  71%|███████   | 7104/10000 [00:08<00:03, 843.79samples/s]
# Processing samples:  72%|███████▏  | 7232/10000 [00:08<00:03, 845.73samples/s]
# Processing samples:  74%|███████▎  | 7360/10000 [00:08<00:03, 845.02samples/s]
# Processing samples:  75%|███████▍  | 7488/10000 [00:09<00:02, 844.83samples/s]
# Processing samples:  76%|███████▌  | 7616/10000 [00:09<00:02, 844.13samples/s]
# Processing samples:  77%|███████▋  | 7744/10000 [00:09<00:02, 839.60samples/s]
# Processing samples:  79%|███████▊  | 7872/10000 [00:09<00:02, 839.88samples/s]
# Processing samples:  80%|████████  | 8000/10000 [00:09<00:02, 840.83samples/s]
# Processing samples:  81%|████████▏ | 8128/10000 [00:09<00:02, 842.00samples/s]
# Processing samples:  83%|████████▎ | 8256/10000 [00:09<00:02, 840.02samples/s]
# Processing samples:  84%|████████▍ | 8384/10000 [00:10<00:01, 840.36samples/s]
# Processing samples:  85%|████████▌ | 8512/10000 [00:10<00:01, 840.64samples/s]
# Processing samples:  86%|████████▋ | 8640/10000 [00:10<00:01, 842.76samples/s]
# Processing samples:  88%|████████▊ | 8768/10000 [00:10<00:01, 843.85samples/s]
# Processing samples:  89%|████████▉ | 8896/10000 [00:10<00:01, 842.90samples/s]
# Processing samples:  90%|█████████ | 9024/10000 [00:10<00:01, 842.70samples/s]
# Processing samples:  92%|█████████▏| 9152/10000 [00:11<00:01, 842.40samples/s]
# Processing samples:  93%|█████████▎| 9280/10000 [00:11<00:00, 843.88samples/s]
# Processing samples:  94%|█████████▍| 9408/10000 [00:11<00:00, 842.24samples/s]
# Processing samples:  95%|█████████▌| 9536/10000 [00:11<00:00, 844.09samples/s]
# Processing samples:  97%|█████████▋| 9664/10000 [00:11<00:00, 844.38samples/s]
# Processing samples:  98%|█████████▊| 9792/10000 [00:11<00:00, 842.58samples/s]
# Processing samples:  99%|█████████▉| 9920/10000 [00:11<00:00, 841.01samples/s]
#                                                                               Processing samples
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Inception Score: 1.0032755733352885 ± 7.375985028233389e-05
# Caching /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 510.87180809004394
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:11,  8.27subsets/s]
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:11,  8.40subsets/s]
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:11,  8.34subsets/s]
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:11,  8.42subsets/s]
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:11,  8.39subsets/s]
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:11,  8.53subsets/s]
# Kernel Inception Distance:   7%|▋         | 7/100 [00:00<00:11,  8.28subsets/s]
# Kernel Inception Distance:   8%|▊         | 8/100 [00:00<00:10,  8.40subsets/s]
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:10,  8.54subsets/s]
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:10,  8.48subsets/s]
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:10,  8.44subsets/s]
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:10,  8.40subsets/s]
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:01<00:10,  8.45subsets/s]
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:01<00:09,  8.60subsets/s]
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:01<00:10,  8.32subsets/s]
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:01<00:10,  8.00subsets/s]
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:10,  8.24subsets/s]
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:09,  8.34subsets/s]
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:09,  8.41subsets/s]
# Kernel Inception Distance:  20%|██        | 20/100 [00:02<00:09,  8.41subsets/s]
# Kernel Inception Distance:  21%|██        | 21/100 [00:02<00:09,  8.53subsets/s]
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:02<00:09,  8.65subsets/s]
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:02<00:08,  8.69subsets/s]
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:02<00:08,  8.59subsets/s]
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:02<00:08,  8.67subsets/s]
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:08,  8.66subsets/s]
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:03<00:08,  8.70subsets/s]
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:03<00:08,  8.65subsets/s]
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:03<00:08,  8.50subsets/s]
# Kernel Inception Distance:  30%|███       | 30/100 [00:03<00:08,  8.60subsets/s]
# Kernel Inception Distance:  31%|███       | 31/100 [00:03<00:07,  8.67subsets/s]
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:03<00:07,  8.71subsets/s]
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:03<00:07,  8.40subsets/s]
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:04<00:07,  8.45subsets/s]
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:04<00:07,  8.51subsets/s]
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:04<00:07,  8.56subsets/s]
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:04<00:07,  8.55subsets/s]
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:04<00:07,  8.57subsets/s]
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:04<00:07,  8.50subsets/s]
# Kernel Inception Distance:  40%|████      | 40/100 [00:04<00:07,  8.56subsets/s]
# Kernel Inception Distance:  41%|████      | 41/100 [00:04<00:06,  8.58subsets/s]
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:04<00:06,  8.36subsets/s]
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:05<00:06,  8.47subsets/s]
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:05<00:06,  8.53subsets/s]
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:05<00:06,  8.53subsets/s]
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:05<00:06,  8.41subsets/s]
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:05<00:06,  8.48subsets/s]
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:05<00:06,  8.49subsets/s]
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:05<00:06,  8.41subsets/s]
# Kernel Inception Distance:  50%|█████     | 50/100 [00:05<00:05,  8.42subsets/s]
# Kernel Inception Distance:  51%|█████     | 51/100 [00:06<00:05,  8.33subsets/s]
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:06<00:05,  8.34subsets/s]
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:06<00:05,  8.43subsets/s]
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:06<00:05,  8.41subsets/s]
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:06<00:05,  8.36subsets/s]
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:06<00:05,  8.42subsets/s]
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:06<00:05,  8.49subsets/s]
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:06<00:04,  8.45subsets/s]
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:06<00:05,  8.11subsets/s]
# Kernel Inception Distance:  60%|██████    | 60/100 [00:07<00:04,  8.25subsets/s]
# Kernel Inception Distance:  61%|██████    | 61/100 [00:07<00:04,  8.36subsets/s]
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:07<00:04,  8.41subsets/s]
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:07<00:04,  8.31subsets/s]
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:07<00:04,  8.42subsets/s]
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:07<00:04,  8.47subsets/s]
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:07<00:03,  8.51subsets/s]
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:07<00:03,  8.44subsets/s]
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:08<00:03,  8.37subsets/s]
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:08<00:03,  8.34subsets/s]
# Kernel Inception Distance:  70%|███████   | 70/100 [00:08<00:03,  8.23subsets/s]
# Kernel Inception Distance:  71%|███████   | 71/100 [00:08<00:03,  8.23subsets/s]
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:08<00:03,  8.32subsets/s]
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:08<00:03,  8.44subsets/s]
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:08<00:03,  8.45subsets/s]
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:08<00:02,  8.36subsets/s]
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:09<00:02,  8.40subsets/s]
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:09<00:02,  8.37subsets/s]
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:09<00:02,  8.43subsets/s]
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:09<00:02,  8.51subsets/s]
# Kernel Inception Distance:  80%|████████  | 80/100 [00:09<00:02,  8.24subsets/s]
# Kernel Inception Distance:  81%|████████  | 81/100 [00:09<00:02,  8.40subsets/s]
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:09<00:02,  8.45subsets/s]
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:09<00:02,  8.47subsets/s]
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:09<00:01,  8.37subsets/s]
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:10<00:01,  8.18subsets/s]
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:10<00:01,  8.31subsets/s]
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:10<00:01,  8.39subsets/s]
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:10<00:01,  8.30subsets/s]
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:10<00:01,  8.36subsets/s]
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:10<00:01,  8.45subsets/s]
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:10<00:01,  8.54subsets/s]
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:10<00:00,  8.45subsets/s]
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:11<00:00,  8.49subsets/s]
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:11<00:00,  8.29subsets/s]
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:11<00:00,  8.38subsets/s]
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:11<00:00,  8.40subsets/s]
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:11<00:00,  8.32subsets/s]
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:11<00:00,  8.39subsets/s]
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:11<00:00,  8.48subsets/s]
# Kernel Inception Distance: 100%|██████████| 100/100 [00:11<00:00,  8.53subsets/s]
#                                                                                  Kernel Inception Distance: 0.5641415243368368 ± 0.004133821179584754
# Global seed set to 42
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/optimization/closure.py:36: LightningDeprecationWarning: One of the returned values {'log', 'progress_bar'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   f"One of the returned values {set(extra.keys())} has a `grad_fn`. We will detach it automatically"
# Validating: 0it [00:00, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['2048', 'logits_unbiased']
# Extracting features from input1
#
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
#
# Processing samples:   1%|▏         | 128/10000 [00:00<00:11, 843.36samples/s]
#
# Processing samples:   3%|▎         | 256/10000 [00:00<00:11, 831.14samples/s]
#
# Processing samples:   4%|▍         | 384/10000 [00:00<00:11, 829.04samples/s]
#
# Processing samples:   5%|▌         | 512/10000 [00:00<00:11, 829.78samples/s]
#
# Processing samples:   6%|▋         | 640/10000 [00:00<00:11, 830.51samples/s]
#
# Processing samples:   8%|▊         | 768/10000 [00:00<00:11, 831.86samples/s]
#
# Processing samples:   9%|▉         | 896/10000 [00:01<00:10, 832.18samples/s]
#
# Processing samples:  10%|█         | 1024/10000 [00:01<00:10, 833.87samples/s]
#
# Processing samples:  12%|█▏        | 1152/10000 [00:01<00:10, 831.91samples/s]
#
# Processing samples:  13%|█▎        | 1280/10000 [00:01<00:10, 831.97samples/s]
#
# Processing samples:  14%|█▍        | 1408/10000 [00:01<00:10, 832.93samples/s]
#
# Processing samples:  15%|█▌        | 1536/10000 [00:01<00:10, 834.14samples/s]
#
# Processing samples:  17%|█▋        | 1664/10000 [00:01<00:09, 834.21samples/s]
#
# Processing samples:  18%|█▊        | 1792/10000 [00:02<00:09, 833.45samples/s]
#
# Processing samples:  19%|█▉        | 1920/10000 [00:02<00:09, 833.16samples/s]
#
# Processing samples:  20%|██        | 2048/10000 [00:02<00:09, 833.74samples/s]
#
# Processing samples:  22%|██▏       | 2176/10000 [00:02<00:09, 834.68samples/s]
#
# Processing samples:  23%|██▎       | 2304/10000 [00:02<00:09, 834.02samples/s]
#
# Processing samples:  24%|██▍       | 2432/10000 [00:02<00:09, 834.07samples/s]
#
# Processing samples:  26%|██▌       | 2560/10000 [00:03<00:08, 834.25samples/s]
#
# Processing samples:  27%|██▋       | 2688/10000 [00:03<00:08, 832.81samples/s]
#
# Processing samples:  28%|██▊       | 2816/10000 [00:03<00:08, 831.77samples/s]
#
# Processing samples:  29%|██▉       | 2944/10000 [00:03<00:08, 833.01samples/s]
#
# Processing samples:  31%|███       | 3072/10000 [00:03<00:08, 832.95samples/s]
#
# Processing samples:  32%|███▏      | 3200/10000 [00:03<00:08, 830.54samples/s]
#
# Processing samples:  33%|███▎      | 3328/10000 [00:03<00:08, 829.77samples/s]
#
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:07, 828.70samples/s]
#
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:07, 828.22samples/s]
#
# Processing samples:  37%|███▋      | 3712/10000 [00:04<00:07, 828.41samples/s]
#
# Processing samples:  38%|███▊      | 3840/10000 [00:04<00:07, 828.43samples/s]
#
# Processing samples:  40%|███▉      | 3968/10000 [00:04<00:07, 829.88samples/s]
#
# Processing samples:  41%|████      | 4096/10000 [00:04<00:07, 828.05samples/s]
#
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:06, 828.18samples/s]
#
# Processing samples:  44%|████▎     | 4352/10000 [00:05<00:06, 827.79samples/s]
#
# Processing samples:  45%|████▍     | 4480/10000 [00:05<00:06, 826.10samples/s]
#
# Processing samples:  46%|████▌     | 4608/10000 [00:05<00:06, 826.66samples/s]
#
# Processing samples:  47%|████▋     | 4736/10000 [00:05<00:06, 826.44samples/s]
#
# Processing samples:  49%|████▊     | 4864/10000 [00:05<00:06, 826.43samples/s]
#
# Processing samples:  50%|████▉     | 4992/10000 [00:06<00:06, 827.22samples/s]
#
# Processing samples:  51%|█████     | 5120/10000 [00:06<00:05, 829.34samples/s]
#
# Processing samples:  52%|█████▏    | 5248/10000 [00:06<00:05, 830.01samples/s]
#
# Processing samples:  54%|█████▍    | 5376/10000 [00:06<00:05, 830.29samples/s]
#
# Processing samples:  55%|█████▌    | 5504/10000 [00:06<00:05, 829.56samples/s]
#
# Processing samples:  56%|█████▋    | 5632/10000 [00:06<00:05, 831.04samples/s]
#
# Processing samples:  58%|█████▊    | 5760/10000 [00:06<00:05, 832.52samples/s]
#
# Processing samples:  59%|█████▉    | 5888/10000 [00:07<00:04, 831.96samples/s]
#
# Processing samples:  60%|██████    | 6016/10000 [00:07<00:04, 833.31samples/s]
#
# Processing samples:  61%|██████▏   | 6144/10000 [00:07<00:04, 830.99samples/s]
#
# Processing samples:  63%|██████▎   | 6272/10000 [00:07<00:04, 829.65samples/s]
#
# Processing samples:  64%|██████▍   | 6400/10000 [00:07<00:04, 828.31samples/s]
#
# Processing samples:  65%|██████▌   | 6528/10000 [00:07<00:04, 828.43samples/s]
#
# Processing samples:  67%|██████▋   | 6656/10000 [00:08<00:04, 828.99samples/s]
#
# Processing samples:  68%|██████▊   | 6784/10000 [00:08<00:03, 829.11samples/s]
#
# Processing samples:  69%|██████▉   | 6912/10000 [00:08<00:03, 829.77samples/s]
#
# Processing samples:  70%|███████   | 7040/10000 [00:08<00:03, 827.90samples/s]
#
# Processing samples:  72%|███████▏  | 7168/10000 [00:08<00:03, 829.89samples/s]
#
# Processing samples:  73%|███████▎  | 7296/10000 [00:08<00:03, 830.90samples/s]
#
# Processing samples:  74%|███████▍  | 7424/10000 [00:08<00:03, 832.11samples/s]
#
# Processing samples:  76%|███████▌  | 7552/10000 [00:09<00:02, 831.24samples/s]
#
# Processing samples:  77%|███████▋  | 7680/10000 [00:09<00:02, 830.71samples/s]
#
# Processing samples:  78%|███████▊  | 7808/10000 [00:09<00:02, 831.73samples/s]
#
# Processing samples:  79%|███████▉  | 7936/10000 [00:09<00:02, 831.58samples/s]
#
# Processing samples:  81%|████████  | 8064/10000 [00:09<00:02, 832.31samples/s]
#
# Processing samples:  82%|████████▏ | 8192/10000 [00:09<00:02, 831.54samples/s]
#
# Processing samples:  83%|████████▎ | 8320/10000 [00:10<00:02, 831.48samples/s]
#
# Processing samples:  84%|████████▍ | 8448/10000 [00:10<00:01, 832.33samples/s]
#
# Processing samples:  86%|████████▌ | 8576/10000 [00:10<00:01, 831.71samples/s]
#
# Processing samples:  87%|████████▋ | 8704/10000 [00:10<00:01, 831.97samples/s]
#
# Processing samples:  88%|████████▊ | 8832/10000 [00:10<00:01, 831.80samples/s]
#
# Processing samples:  90%|████████▉ | 8960/10000 [00:10<00:01, 831.93samples/s]
#
# Processing samples:  91%|█████████ | 9088/10000 [00:10<00:01, 831.01samples/s]
#
# Processing samples:  92%|█████████▏| 9216/10000 [00:11<00:00, 831.84samples/s]
#
# Processing samples:  93%|█████████▎| 9344/10000 [00:11<00:00, 832.47samples/s]
#
# Processing samples:  95%|█████████▍| 9472/10000 [00:11<00:00, 831.28samples/s]
#
# Processing samples:  96%|█████████▌| 9600/10000 [00:11<00:00, 830.90samples/s]
#
# Processing samples:  97%|█████████▋| 9728/10000 [00:11<00:00, 832.39samples/s]
#
# Processing samples:  99%|█████████▊| 9856/10000 [00:11<00:00, 832.45samples/s]
#
# Processing samples: 100%|█████████▉| 9984/10000 [00:12<00:00, 830.97samples/s]
#
#                                                                               Processing samples
# Extracting features from input2
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Inception Score: 3.23158475646366 ± 0.06263687258777616
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 134.25380423328033
#
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
#
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:13,  7.37subsets/s]
#
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:12,  7.93subsets/s]
#
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:12,  7.99subsets/s]
#
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:11,  8.21subsets/s]
#
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:11,  8.23subsets/s]
#
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:11,  8.21subsets/s]
#
# Kernel Inception Distance:   7%|▋         | 7/100 [00:00<00:11,  8.23subsets/s]
#
# Kernel Inception Distance:   8%|▊         | 8/100 [00:00<00:11,  8.30subsets/s]
#
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:11,  8.15subsets/s]
#
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:11,  7.98subsets/s]
#
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:11,  7.98subsets/s]
#
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:01<00:11,  7.85subsets/s]
#
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:01<00:11,  7.74subsets/s]
#
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:01<00:11,  7.73subsets/s]
#
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:01<00:11,  7.68subsets/s]
#
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:02<00:10,  7.77subsets/s]
#
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:10,  7.70subsets/s]
#
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:10,  7.81subsets/s]
#
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:02<00:10,  7.71subsets/s]
#
# Kernel Inception Distance:  20%|██        | 20/100 [00:02<00:10,  7.82subsets/s]
#
# Kernel Inception Distance:  21%|██        | 21/100 [00:02<00:10,  7.87subsets/s]
#
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:02<00:09,  7.90subsets/s]
#
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:02<00:09,  7.83subsets/s]
#
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:03<00:09,  7.87subsets/s]
#
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:03<00:09,  7.69subsets/s]
#
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:03<00:09,  7.75subsets/s]
#
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:03<00:09,  7.82subsets/s]
#
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:03<00:09,  7.87subsets/s]
#
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:03<00:08,  7.90subsets/s]
#
# Kernel Inception Distance:  30%|███       | 30/100 [00:03<00:08,  7.96subsets/s]
#
# Kernel Inception Distance:  31%|███       | 31/100 [00:03<00:08,  7.89subsets/s]
#
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:04<00:08,  7.93subsets/s]
#
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:04<00:08,  7.78subsets/s]
#
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:04<00:08,  7.75subsets/s]
#
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:04<00:08,  7.80subsets/s]
#
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:04<00:08,  7.84subsets/s]
#
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:04<00:07,  7.90subsets/s]
#
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:04<00:07,  7.94subsets/s]
#
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:04<00:07,  7.92subsets/s]
#
# Kernel Inception Distance:  40%|████      | 40/100 [00:05<00:07,  7.90subsets/s]
#
# Kernel Inception Distance:  41%|████      | 41/100 [00:05<00:07,  7.89subsets/s]
#
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:05<00:07,  8.01subsets/s]
#
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:05<00:07,  8.03subsets/s]
#
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:05<00:06,  8.09subsets/s]
#
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:05<00:06,  8.26subsets/s]
#
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:05<00:06,  8.25subsets/s]
#
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:05<00:06,  8.32subsets/s]
#
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:06<00:06,  8.43subsets/s]
#
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:06<00:06,  8.45subsets/s]
#
# Kernel Inception Distance:  50%|█████     | 50/100 [00:06<00:06,  8.28subsets/s]
#
# Kernel Inception Distance:  51%|█████     | 51/100 [00:06<00:05,  8.41subsets/s]
#
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:06<00:05,  8.50subsets/s]
#
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:06<00:05,  8.50subsets/s]
#
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:06<00:05,  8.37subsets/s]
#
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:06<00:05,  8.40subsets/s]
#
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:06<00:05,  8.49subsets/s]
#
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:07<00:05,  8.46subsets/s]
#
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:07<00:04,  8.53subsets/s]
#
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:07<00:04,  8.41subsets/s]
#
# Kernel Inception Distance:  60%|██████    | 60/100 [00:07<00:04,  8.32subsets/s]
#
# Kernel Inception Distance:  61%|██████    | 61/100 [00:07<00:04,  8.28subsets/s]
#
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:07<00:04,  7.97subsets/s]
#
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:07<00:04,  8.12subsets/s]
#
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:07<00:04,  8.17subsets/s]
#
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:08<00:04,  8.23subsets/s]
#
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:08<00:04,  8.29subsets/s]
#
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:08<00:04,  8.10subsets/s]
#
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:08<00:03,  8.19subsets/s]
#
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:08<00:03,  8.29subsets/s]
#
# Kernel Inception Distance:  70%|███████   | 70/100 [00:08<00:03,  8.32subsets/s]
#
# Kernel Inception Distance:  71%|███████   | 71/100 [00:08<00:03,  8.21subsets/s]
#
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:08<00:03,  8.21subsets/s]
#
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:09<00:03,  8.19subsets/s]
#
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:09<00:03,  8.31subsets/s]
#
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:09<00:03,  8.22subsets/s]
#
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:09<00:02,  8.24subsets/s]
#
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:09<00:02,  8.28subsets/s]
#
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:09<00:02,  8.26subsets/s]
#
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:09<00:02,  8.33subsets/s]
#
# Kernel Inception Distance:  80%|████████  | 80/100 [00:09<00:02,  8.39subsets/s]
#
# Kernel Inception Distance:  81%|████████  | 81/100 [00:10<00:02,  8.32subsets/s]
#
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:10<00:02,  8.38subsets/s]
#
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:10<00:02,  8.43subsets/s]
#
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:10<00:01,  8.47subsets/s]
#
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:10<00:01,  8.41subsets/s]
#
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:10<00:01,  8.15subsets/s]
#
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:10<00:01,  8.23subsets/s]
#
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:10<00:01,  8.32subsets/s]
#
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:10<00:01,  8.34subsets/s]
#
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:11<00:01,  8.32subsets/s]
#
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:11<00:01,  8.37subsets/s]
#
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:11<00:00,  8.19subsets/s]
#
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:11<00:00,  8.13subsets/s]
#
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:11<00:00,  8.23subsets/s]
#
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:11<00:00,  8.25subsets/s]
#
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:11<00:00,  8.26subsets/s]
#
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:11<00:00,  8.28subsets/s]
#
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:12<00:00,  8.30subsets/s]
#
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:12<00:00,  8.39subsets/s]
#
# Kernel Inception Distance: 100%|██████████| 100/100 [00:12<00:00,  8.19subsets/s]
#
#                                                                                  Kernel Inception Distance: 0.11309615514764765 ± 0.0023979293115761724
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Validating: 0it [00:00, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['2048', 'logits_unbiased']
# Extracting features from input1
#
#
# Processing samples:   0%|          | 0/10000 [00:00<?, ?samples/s]
#
# Processing samples:   1%|▏         | 128/10000 [00:00<00:11, 847.04samples/s]
#
# Processing samples:   3%|▎         | 256/10000 [00:00<00:11, 840.53samples/s]
#
# Processing samples:   4%|▍         | 384/10000 [00:00<00:11, 839.57samples/s]
#
# Processing samples:   5%|▌         | 512/10000 [00:00<00:11, 837.66samples/s]
#
# Processing samples:   6%|▋         | 640/10000 [00:00<00:11, 836.89samples/s]
#
# Processing samples:   8%|▊         | 768/10000 [00:00<00:11, 836.37samples/s]
#
# Processing samples:   9%|▉         | 896/10000 [00:01<00:10, 835.78samples/s]
#
# Processing samples:  10%|█         | 1024/10000 [00:01<00:10, 833.98samples/s]
#
# Processing samples:  12%|█▏        | 1152/10000 [00:01<00:10, 833.88samples/s]
#
# Processing samples:  13%|█▎        | 1280/10000 [00:01<00:10, 832.64samples/s]
#
# Processing samples:  14%|█▍        | 1408/10000 [00:01<00:10, 830.42samples/s]
#
# Processing samples:  15%|█▌        | 1536/10000 [00:01<00:10, 830.18samples/s]
#
# Processing samples:  17%|█▋        | 1664/10000 [00:01<00:10, 829.70samples/s]
#
# Processing samples:  18%|█▊        | 1792/10000 [00:02<00:09, 829.61samples/s]
#
# Processing samples:  19%|█▉        | 1920/10000 [00:02<00:09, 827.12samples/s]
#
# Processing samples:  20%|██        | 2048/10000 [00:02<00:09, 826.86samples/s]
#
# Processing samples:  22%|██▏       | 2176/10000 [00:02<00:09, 826.32samples/s]
#
# Processing samples:  23%|██▎       | 2304/10000 [00:02<00:09, 827.13samples/s]
#
# Processing samples:  24%|██▍       | 2432/10000 [00:02<00:09, 828.91samples/s]
#
# Processing samples:  26%|██▌       | 2560/10000 [00:03<00:08, 830.74samples/s]
#
# Processing samples:  27%|██▋       | 2688/10000 [00:03<00:08, 830.83samples/s]
#
# Processing samples:  28%|██▊       | 2816/10000 [00:03<00:08, 829.51samples/s]
#
# Processing samples:  29%|██▉       | 2944/10000 [00:03<00:08, 831.42samples/s]
#
# Processing samples:  31%|███       | 3072/10000 [00:03<00:08, 831.72samples/s]
#
# Processing samples:  32%|███▏      | 3200/10000 [00:03<00:08, 832.00samples/s]
#
# Processing samples:  33%|███▎      | 3328/10000 [00:04<00:08, 831.23samples/s]
#
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:07, 829.51samples/s]
#
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:07, 828.80samples/s]
#
# Processing samples:  37%|███▋      | 3712/10000 [00:04<00:07, 828.63samples/s]
#
# Processing samples:  38%|███▊      | 3840/10000 [00:04<00:07, 830.40samples/s]
#
# Processing samples:  40%|███▉      | 3968/10000 [00:04<00:07, 829.53samples/s]
#
# Processing samples:  41%|████      | 4096/10000 [00:04<00:07, 830.06samples/s]
#
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:06, 830.88samples/s]
#
# Processing samples:  44%|████▎     | 4352/10000 [00:05<00:06, 831.06samples/s]
#
# Processing samples:  45%|████▍     | 4480/10000 [00:05<00:06, 829.82samples/s]
#
# Processing samples:  46%|████▌     | 4608/10000 [00:05<00:06, 829.17samples/s]
#
# Processing samples:  47%|████▋     | 4736/10000 [00:05<00:06, 828.74samples/s]
#
# Processing samples:  49%|████▊     | 4864/10000 [00:05<00:06, 830.48samples/s]
#
# Processing samples:  50%|████▉     | 4992/10000 [00:06<00:06, 830.82samples/s]
#
# Processing samples:  51%|█████     | 5120/10000 [00:06<00:05, 830.22samples/s]
#
# Processing samples:  52%|█████▏    | 5248/10000 [00:06<00:05, 830.06samples/s]
#
# Processing samples:  54%|█████▍    | 5376/10000 [00:06<00:05, 830.71samples/s]
#
# Processing samples:  55%|█████▌    | 5504/10000 [00:06<00:05, 830.41samples/s]
#
# Processing samples:  56%|█████▋    | 5632/10000 [00:06<00:05, 831.35samples/s]
#
# Processing samples:  58%|█████▊    | 5760/10000 [00:06<00:05, 831.10samples/s]
#
# Processing samples:  59%|█████▉    | 5888/10000 [00:07<00:04, 832.04samples/s]
#
# Processing samples:  60%|██████    | 6016/10000 [00:07<00:04, 831.63samples/s]
#
# Processing samples:  61%|██████▏   | 6144/10000 [00:07<00:04, 830.48samples/s]
#
# Processing samples:  63%|██████▎   | 6272/10000 [00:07<00:04, 829.20samples/s]
#
# Processing samples:  64%|██████▍   | 6400/10000 [00:07<00:04, 827.51samples/s]
#
# Processing samples:  65%|██████▌   | 6528/10000 [00:07<00:04, 827.94samples/s]
#
# Processing samples:  67%|██████▋   | 6656/10000 [00:08<00:04, 827.68samples/s]
#
# Processing samples:  68%|██████▊   | 6784/10000 [00:08<00:03, 826.74samples/s]
#
# Processing samples:  69%|██████▉   | 6912/10000 [00:08<00:03, 825.91samples/s]
#
# Processing samples:  70%|███████   | 7040/10000 [00:08<00:03, 827.34samples/s]
#
# Processing samples:  72%|███████▏  | 7168/10000 [00:08<00:03, 827.64samples/s]
#
# Processing samples:  73%|███████▎  | 7296/10000 [00:08<00:03, 827.26samples/s]
#
# Processing samples:  74%|███████▍  | 7424/10000 [00:08<00:03, 827.58samples/s]
#
# Processing samples:  76%|███████▌  | 7552/10000 [00:09<00:02, 828.66samples/s]
#
# Processing samples:  77%|███████▋  | 7680/10000 [00:09<00:02, 828.68samples/s]
#
# Processing samples:  78%|███████▊  | 7808/10000 [00:09<00:02, 828.09samples/s]
#
# Processing samples:  79%|███████▉  | 7936/10000 [00:09<00:02, 829.12samples/s]
#
# Processing samples:  81%|████████  | 8064/10000 [00:09<00:02, 828.33samples/s]
#
# Processing samples:  82%|████████▏ | 8192/10000 [00:09<00:02, 828.00samples/s]
#
# Processing samples:  83%|████████▎ | 8320/10000 [00:10<00:02, 829.79samples/s]
#
# Processing samples:  84%|████████▍ | 8448/10000 [00:10<00:01, 831.25samples/s]
#
# Processing samples:  86%|████████▌ | 8576/10000 [00:10<00:01, 829.65samples/s]
#
# Processing samples:  87%|████████▋ | 8704/10000 [00:10<00:01, 828.98samples/s]
#
# Processing samples:  88%|████████▊ | 8832/10000 [00:10<00:01, 830.84samples/s]
#
# Processing samples:  90%|████████▉ | 8960/10000 [00:10<00:01, 829.56samples/s]
#
# Processing samples:  91%|█████████ | 9088/10000 [00:10<00:01, 828.82samples/s]
#
# Processing samples:  92%|█████████▏| 9216/10000 [00:11<00:00, 826.98samples/s]
#
# Processing samples:  93%|█████████▎| 9344/10000 [00:11<00:00, 827.00samples/s]
#
# ...
#
# Processing samples:  29%|██▉       | 2944/10000 [00:03<00:08, 832.16samples/s]
#
# Processing samples:  31%|███       | 3072/10000 [00:03<00:08, 831.40samples/s]
#
# Processing samples:  32%|███▏      | 3200/10000 [00:03<00:08, 833.04samples/s]
#
# Processing samples:  33%|███▎      | 3328/10000 [00:03<00:07, 834.13samples/s]
#
# Processing samples:  35%|███▍      | 3456/10000 [00:04<00:07, 834.10samples/s]
#
# Processing samples:  36%|███▌      | 3584/10000 [00:04<00:07, 833.97samples/s]
#
# Processing samples:  37%|███▋      | 3712/10000 [00:04<00:07, 834.31samples/s]
#
# Processing samples:  38%|███▊      | 3840/10000 [00:04<00:07, 834.68samples/s]
#
# Processing samples:  40%|███▉      | 3968/10000 [00:04<00:07, 834.21samples/s]
#
# Processing samples:  41%|████      | 4096/10000 [00:04<00:07, 833.22samples/s]
#
# Processing samples:  42%|████▏     | 4224/10000 [00:05<00:06, 832.62samples/s]
#
# Processing samples:  44%|████▎     | 4352/10000 [00:05<00:06, 833.66samples/s]
#
# Processing samples:  45%|████▍     | 4480/10000 [00:05<00:06, 834.13samples/s]
#
# Processing samples:  46%|████▌     | 4608/10000 [00:05<00:06, 834.84samples/s]
#
# Processing samples:  47%|████▋     | 4736/10000 [00:05<00:06, 835.47samples/s]
#
# Processing samples:  49%|████▊     | 4864/10000 [00:05<00:06, 835.77samples/s]
#
# Processing samples:  50%|████▉     | 4992/10000 [00:05<00:05, 836.50samples/s]
#
# Processing samples:  51%|█████     | 5120/10000 [00:06<00:05, 837.06samples/s]
#
# Processing samples:  52%|█████▏    | 5248/10000 [00:06<00:05, 837.47samples/s]
#
# Processing samples:  54%|█████▍    | 5376/10000 [00:06<00:05, 836.87samples/s]
#
# Processing samples:  55%|█████▌    | 5504/10000 [00:06<00:05, 833.37samples/s]
#
# Processing samples:  56%|█████▋    | 5632/10000 [00:06<00:05, 834.28samples/s]
#
# Processing samples:  58%|█████▊    | 5760/10000 [00:06<00:05, 835.44samples/s]
#
# Processing samples:  59%|█████▉    | 5888/10000 [00:07<00:04, 835.30samples/s]
#
# Processing samples:  60%|██████    | 6016/10000 [00:07<00:04, 834.40samples/s]
#
# Processing samples:  61%|██████▏   | 6144/10000 [00:07<00:04, 834.17samples/s]
#
# Processing samples:  63%|██████▎   | 6272/10000 [00:07<00:04, 832.26samples/s]
#
# Processing samples:  64%|██████▍   | 6400/10000 [00:07<00:04, 831.07samples/s]
#
# Processing samples:  65%|██████▌   | 6528/10000 [00:07<00:04, 830.00samples/s]
#
# Processing samples:  67%|██████▋   | 6656/10000 [00:07<00:04, 830.32samples/s]
#
# Processing samples:  68%|██████▊   | 6784/10000 [00:08<00:03, 831.34samples/s]
#
# Processing samples:  69%|██████▉   | 6912/10000 [00:08<00:03, 832.91samples/s]
#
# Processing samples:  70%|███████   | 7040/10000 [00:08<00:03, 834.70samples/s]
#
# Processing samples:  72%|███████▏  | 7168/10000 [00:08<00:03, 833.67samples/s]
#
# Processing samples:  73%|███████▎  | 7296/10000 [00:08<00:03, 830.28samples/s]
#
# Processing samples:  74%|███████▍  | 7424/10000 [00:08<00:03, 829.19samples/s]
#
# Processing samples:  76%|███████▌  | 7552/10000 [00:09<00:02, 829.27samples/s]
#
# Processing samples:  77%|███████▋  | 7680/10000 [00:09<00:02, 831.13samples/s]
#
# Processing samples:  78%|███████▊  | 7808/10000 [00:09<00:02, 831.13samples/s]
#
# Processing samples:  79%|███████▉  | 7936/10000 [00:09<00:02, 831.69samples/s]
#
# Processing samples:  81%|████████  | 8064/10000 [00:09<00:02, 831.79samples/s]
#
# Processing samples:  82%|████████▏ | 8192/10000 [00:09<00:02, 831.36samples/s]
#
# Processing samples:  83%|████████▎ | 8320/10000 [00:09<00:02, 832.26samples/s]
#
# Processing samples:  84%|████████▍ | 8448/10000 [00:10<00:01, 832.83samples/s]
#
# Processing samples:  86%|████████▌ | 8576/10000 [00:10<00:01, 832.28samples/s]
#
# Processing samples:  87%|████████▋ | 8704/10000 [00:10<00:01, 833.06samples/s]
#
# Processing samples:  88%|████████▊ | 8832/10000 [00:10<00:01, 831.90samples/s]
#
# Processing samples:  90%|████████▉ | 8960/10000 [00:10<00:01, 830.70samples/s]
#
# Processing samples:  91%|█████████ | 9088/10000 [00:10<00:01, 831.26samples/s]
#
# Processing samples:  92%|█████████▏| 9216/10000 [00:11<00:00, 832.48samples/s]
#
# Processing samples:  93%|█████████▎| 9344/10000 [00:11<00:00, 833.37samples/s]
#
# Processing samples:  95%|█████████▍| 9472/10000 [00:11<00:00, 834.25samples/s]
#
# Processing samples:  96%|█████████▌| 9600/10000 [00:11<00:00, 833.89samples/s]
#
# Processing samples:  97%|█████████▋| 9728/10000 [00:11<00:00, 833.00samples/s]
#
# Processing samples:  99%|█████████▊| 9856/10000 [00:11<00:00, 832.52samples/s]
#
# Processing samples: 100%|█████████▉| 9984/10000 [00:11<00:00, 832.84samples/s]
#
#                                                                               Processing samples
# Extracting features from input2
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-2048.pt
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-features-logits_unbiased.pt
# Inception Score: 7.148343383514306 ± 0.12603371110092285
# Loading cached /root/.cache/torch/fidelity_cache/cifar10-val-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 30.165034075388462
#
#
# Kernel Inception Distance:   0%|          | 0/100 [00:00<?, ?subsets/s]
#
# Kernel Inception Distance:   1%|          | 1/100 [00:00<00:19,  5.04subsets/s]
#
# Kernel Inception Distance:   2%|▏         | 2/100 [00:00<00:16,  5.97subsets/s]
#
# Kernel Inception Distance:   3%|▎         | 3/100 [00:00<00:16,  6.03subsets/s]
#
# Kernel Inception Distance:   4%|▍         | 4/100 [00:00<00:15,  6.08subsets/s]
#
# Kernel Inception Distance:   5%|▌         | 5/100 [00:00<00:14,  6.39subsets/s]
#
# Kernel Inception Distance:   6%|▌         | 6/100 [00:00<00:14,  6.32subsets/s]
#
# Kernel Inception Distance:   7%|▋         | 7/100 [00:01<00:15,  6.05subsets/s]
#
# Kernel Inception Distance:   8%|▊         | 8/100 [00:01<00:15,  5.96subsets/s]
#
# Kernel Inception Distance:   9%|▉         | 9/100 [00:01<00:15,  5.85subsets/s]
#
# Kernel Inception Distance:  10%|█         | 10/100 [00:01<00:15,  5.73subsets/s]
#
# Kernel Inception Distance:  11%|█         | 11/100 [00:01<00:15,  5.76subsets/s]
#
# Kernel Inception Distance:  12%|█▏        | 12/100 [00:02<00:14,  5.93subsets/s]
#
# Kernel Inception Distance:  13%|█▎        | 13/100 [00:02<00:14,  6.17subsets/s]
#
# Kernel Inception Distance:  14%|█▍        | 14/100 [00:02<00:14,  6.13subsets/s]
#
# Kernel Inception Distance:  15%|█▌        | 15/100 [00:02<00:13,  6.30subsets/s]
#
# Kernel Inception Distance:  16%|█▌        | 16/100 [00:02<00:13,  6.04subsets/s]
#
# Kernel Inception Distance:  17%|█▋        | 17/100 [00:02<00:13,  6.23subsets/s]
#
# Kernel Inception Distance:  18%|█▊        | 18/100 [00:02<00:13,  6.29subsets/s]
#
# Kernel Inception Distance:  19%|█▉        | 19/100 [00:03<00:12,  6.30subsets/s]
#
# Kernel Inception Distance:  20%|██        | 20/100 [00:03<00:12,  6.53subsets/s]
#
# Kernel Inception Distance:  21%|██        | 21/100 [00:03<00:11,  6.67subsets/s]
#
# Kernel Inception Distance:  22%|██▏       | 22/100 [00:03<00:12,  6.29subsets/s]
#
# Kernel Inception Distance:  23%|██▎       | 23/100 [00:03<00:12,  6.07subsets/s]
#
# Kernel Inception Distance:  24%|██▍       | 24/100 [00:03<00:12,  5.91subsets/s]
#
# Kernel Inception Distance:  25%|██▌       | 25/100 [00:04<00:12,  6.21subsets/s]
#
# Kernel Inception Distance:  26%|██▌       | 26/100 [00:04<00:11,  6.51subsets/s]
#
# Kernel Inception Distance:  27%|██▋       | 27/100 [00:04<00:10,  6.72subsets/s]
#
# Kernel Inception Distance:  28%|██▊       | 28/100 [00:04<00:11,  6.44subsets/s]
#
# Kernel Inception Distance:  29%|██▉       | 29/100 [00:04<00:10,  6.48subsets/s]
#
# Kernel Inception Distance:  30%|███       | 30/100 [00:04<00:10,  6.57subsets/s]
#
# Kernel Inception Distance:  31%|███       | 31/100 [00:04<00:10,  6.65subsets/s]
#
# Kernel Inception Distance:  32%|███▏      | 32/100 [00:05<00:10,  6.57subsets/s]
#
# Kernel Inception Distance:  33%|███▎      | 33/100 [00:05<00:09,  6.91subsets/s]
#
# Kernel Inception Distance:  34%|███▍      | 34/100 [00:05<00:09,  6.98subsets/s]
#
# Kernel Inception Distance:  35%|███▌      | 35/100 [00:05<00:09,  6.83subsets/s]
#
# Kernel Inception Distance:  36%|███▌      | 36/100 [00:05<00:10,  6.38subsets/s]
#
# Kernel Inception Distance:  37%|███▋      | 37/100 [00:05<00:09,  6.66subsets/s]
#
# Kernel Inception Distance:  38%|███▊      | 38/100 [00:06<00:09,  6.27subsets/s]
#
# Kernel Inception Distance:  39%|███▉      | 39/100 [00:06<00:09,  6.30subsets/s]
#
# Kernel Inception Distance:  40%|████      | 40/100 [00:06<00:09,  6.09subsets/s]
#
# Kernel Inception Distance:  41%|████      | 41/100 [00:06<00:09,  6.52subsets/s]
#
# Kernel Inception Distance:  42%|████▏     | 42/100 [00:06<00:08,  6.92subsets/s]
#
# Kernel Inception Distance:  43%|████▎     | 43/100 [00:06<00:07,  7.15subsets/s]
#
# Kernel Inception Distance:  44%|████▍     | 44/100 [00:06<00:08,  6.73subsets/s]
#
# Kernel Inception Distance:  45%|████▌     | 45/100 [00:07<00:08,  6.32subsets/s]
#
# Kernel Inception Distance:  46%|████▌     | 46/100 [00:07<00:08,  6.33subsets/s]
#
# Kernel Inception Distance:  47%|████▋     | 47/100 [00:07<00:07,  6.67subsets/s]
#
# Kernel Inception Distance:  48%|████▊     | 48/100 [00:07<00:07,  7.02subsets/s]
#
# Kernel Inception Distance:  49%|████▉     | 49/100 [00:07<00:07,  6.80subsets/s]
#
# Kernel Inception Distance:  50%|█████     | 50/100 [00:07<00:07,  6.56subsets/s]
#
# Kernel Inception Distance:  51%|█████     | 51/100 [00:08<00:07,  6.36subsets/s]
#
# Kernel Inception Distance:  52%|█████▏    | 52/100 [00:08<00:07,  6.21subsets/s]
#
# Kernel Inception Distance:  53%|█████▎    | 53/100 [00:08<00:07,  6.65subsets/s]
#
# Kernel Inception Distance:  54%|█████▍    | 54/100 [00:08<00:07,  6.52subsets/s]
#
# Kernel Inception Distance:  55%|█████▌    | 55/100 [00:08<00:06,  6.93subsets/s]
#
# Kernel Inception Distance:  56%|█████▌    | 56/100 [00:08<00:06,  6.53subsets/s]
#
# Kernel Inception Distance:  57%|█████▋    | 57/100 [00:08<00:06,  6.54subsets/s]
#
# Kernel Inception Distance:  58%|█████▊    | 58/100 [00:09<00:06,  6.83subsets/s]
#
# Kernel Inception Distance:  59%|█████▉    | 59/100 [00:09<00:05,  6.89subsets/s]
#
# Kernel Inception Distance:  60%|██████    | 60/100 [00:09<00:05,  6.93subsets/s]
#
# Kernel Inception Distance:  61%|██████    | 61/100 [00:09<00:05,  6.54subsets/s]
#
# Kernel Inception Distance:  62%|██████▏   | 62/100 [00:09<00:05,  6.54subsets/s]
#
# Kernel Inception Distance:  63%|██████▎   | 63/100 [00:09<00:05,  6.34subsets/s]
#
# Kernel Inception Distance:  64%|██████▍   | 64/100 [00:09<00:05,  6.48subsets/s]
#
# Kernel Inception Distance:  65%|██████▌   | 65/100 [00:10<00:05,  6.11subsets/s]
#
# Kernel Inception Distance:  66%|██████▌   | 66/100 [00:10<00:05,  6.39subsets/s]
#
# Kernel Inception Distance:  67%|██████▋   | 67/100 [00:10<00:05,  6.05subsets/s]
#
# Kernel Inception Distance:  68%|██████▊   | 68/100 [00:10<00:05,  5.89subsets/s]
#
# Kernel Inception Distance:  69%|██████▉   | 69/100 [00:10<00:05,  5.70subsets/s]
#
# Kernel Inception Distance:  70%|███████   | 70/100 [00:10<00:04,  6.14subsets/s]
#
# Kernel Inception Distance:  71%|███████   | 71/100 [00:11<00:04,  5.97subsets/s]
#
# Kernel Inception Distance:  72%|███████▏  | 72/100 [00:11<00:04,  5.75subsets/s]
#
# Kernel Inception Distance:  73%|███████▎  | 73/100 [00:11<00:04,  6.21subsets/s]
#
# Kernel Inception Distance:  74%|███████▍  | 74/100 [00:11<00:04,  6.46subsets/s]
#
# Kernel Inception Distance:  75%|███████▌  | 75/100 [00:11<00:03,  6.30subsets/s]
#
# Kernel Inception Distance:  76%|███████▌  | 76/100 [00:11<00:03,  6.55subsets/s]
#
# Kernel Inception Distance:  77%|███████▋  | 77/100 [00:12<00:03,  6.20subsets/s]
#
# Kernel Inception Distance:  78%|███████▊  | 78/100 [00:12<00:03,  6.41subsets/s]
#
# Kernel Inception Distance:  79%|███████▉  | 79/100 [00:12<00:03,  6.80subsets/s]
#
# Kernel Inception Distance:  80%|████████  | 80/100 [00:12<00:03,  6.63subsets/s]
#
# Kernel Inception Distance:  81%|████████  | 81/100 [00:12<00:02,  6.57subsets/s]
#
# Kernel Inception Distance:  82%|████████▏ | 82/100 [00:12<00:02,  6.14subsets/s]
#
# Kernel Inception Distance:  83%|████████▎ | 83/100 [00:13<00:02,  6.39subsets/s]
#
# Kernel Inception Distance:  84%|████████▍ | 84/100 [00:13<00:02,  5.94subsets/s]
#
# Kernel Inception Distance:  85%|████████▌ | 85/100 [00:13<00:02,  5.98subsets/s]
#
# Kernel Inception Distance:  86%|████████▌ | 86/100 [00:13<00:02,  5.95subsets/s]
#
# Kernel Inception Distance:  87%|████████▋ | 87/100 [00:13<00:02,  5.95subsets/s]
#
# Kernel Inception Distance:  88%|████████▊ | 88/100 [00:13<00:02,  5.95subsets/s]
#
# Kernel Inception Distance:  89%|████████▉ | 89/100 [00:14<00:01,  6.01subsets/s]
#
# Kernel Inception Distance:  90%|█████████ | 90/100 [00:14<00:01,  5.69subsets/s]
#
# Kernel Inception Distance:  91%|█████████ | 91/100 [00:14<00:01,  5.74subsets/s]
#
# Kernel Inception Distance:  92%|█████████▏| 92/100 [00:14<00:01,  5.85subsets/s]
#
# Kernel Inception Distance:  93%|█████████▎| 93/100 [00:14<00:01,  6.02subsets/s]
#
# Kernel Inception Distance:  94%|█████████▍| 94/100 [00:14<00:01,  5.83subsets/s]
#
# Kernel Inception Distance:  95%|█████████▌| 95/100 [00:15<00:00,  5.81subsets/s]
#
# Kernel Inception Distance:  96%|█████████▌| 96/100 [00:15<00:00,  5.73subsets/s]
#
# Kernel Inception Distance:  97%|█████████▋| 97/100 [00:15<00:00,  5.99subsets/s]
#
# Kernel Inception Distance:  98%|█████████▊| 98/100 [00:15<00:00,  5.74subsets/s]
#
# Kernel Inception Distance:  99%|█████████▉| 99/100 [00:15<00:00,  6.16subsets/s]
#
# Kernel Inception Distance: 100%|██████████| 100/100 [00:15<00:00,  5.93subsets/s]
#
#                                                                                  Kernel Inception Distance: 0.018557297277277285 ± 0.00144236601916795
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:688: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 271... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 1611.39MB of 1611.39MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, ma…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>FID</td><td>█▅▄▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>IS</td><td>▁▃▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇▇█▇▇▇█▇███████▇</td></tr><tr><td>KID</td><td>█▅▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_discriminator_loss</td><td>██▇█▇▇▇▇▇▆▅▆▆▅▅▅▄▄▄▄▃▄▃▃▄▂▃▃▃▂▃▂▁▂▂▁▂▂▁▂</td></tr><tr><td>train_gen_loss</td><td>█▄▄▃▂▂▁▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>FID</td><td>30.16503</td></tr><tr><td>IS</td><td>7.14834</td></tr><tr><td>KID</td><td>0.01856</td></tr><tr><td>epoch</td><td>317</td></tr><tr><td>train_discriminator_loss</td><td>0.51714</td></tr><tr><td>train_gen_loss</td><td>1.35537</td></tr><tr><td>trainer/global_step</td><td>62327</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 383 media file(s), 63 artifact file(s) and 1 other file(s)
# <br/>Synced <strong style="color:#cdcd00">mild-paper-88</strong>: <a href="https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/8w856w0y" target="_blank">https://wandb.ai/tiencheng/DELE_CA2_GAN/runs/8w856w0y</a><br/>
# Find logs at: <code>./wandb/run-20220206_081836-8w856w0y/logs</code><br/>
